# %% [markdown]
# # 枢纽客流量BP神经网络预测模型
#
#
# ## 1. 研究意义：
#
# 智慧交通是智慧城市的重要组成部分，提高公交车站点客流量预测的准确度是智慧公交的研究内容之一。大型现代化综合交通枢纽站汇集多种交通方式并伴有大规模客流集散、换乘等特点，采用科学的方法研究大型综合交通枢纽站的各个交通方式的客流量预测对公交运营部门的快速决策和综合管理提供及时准确的数据参考具有现实意义。
#
# 本算法模型有效的解决了交通枢纽各个交通方式短期客流量的预测问题， 对未来的小时客流量和5分钟客流量进行短期预测，能够有效的预测客流量爆发点和未来各个时段客流量的走势，为交通枢纽的运力分配策略提供数据支持。模型充分考虑了节假日、天气变化等因素对客流量的影响，能够提高对于特殊节日和天气影响下的客流量预测精度。
#
# 模型首先分析影响客流波动的因素（节假日、天气因素以及时间序列等），然后通过对比各类预测方法的优缺点，设计改进的BP神经网络算法进行短期客流量预测。
#
# ## 2.预期目标和现阶段的成果：
#
# 预测模型将提供对交通枢纽地铁、公交、火车等交通方式的客流量预测，实现客流量爆发预警功能，为枢纽的运力调配提供数据支持。同时，客流量的预测和分析，能够为优化枢纽的空间布置和人力分配提供政策建议。
#
# 目前，基于Keras深度学习库搭建的BP神经网络预测模型目前已完成对上海虹桥地铁进出站的客流量预测，小时客流量预测精度可以达到10%以下。能够有效的实现未来一周的客流量预测。未来通过对预测算法输入特征值的优化以及对部分特殊情况的规则提取和分析（比如特殊的节假日情况，突发事件等），算法的精度将得到进一步提高。
#
# 未来将打造一个完整的交通枢纽客流量预测系统，为交通枢纽的运力决策和综合管理优化提供数据支持和政策建议。该系统可以支持交通枢纽站的地铁、公交、火车等交通方式的客流量预测，届时需要拿到公交刷卡记录和火车站的进出站闸机历史csv数据。
#
#
# ## 3.模型功能：
#
# 模型能够有效预测未来一周枢纽内各个交通方式的客流量大小，提前为枢纽运力分配提供策略。模式采用有监督的机器学习方式，在未来随着训练（历史）数据的不断积累，能够实现自我调整和参数优化，不断提高预测的精度。
#
# 根据给定的输入参数：
# INPUT[日期(eg:20180901)，时段(eg:8)，节假日情况（周末or其他节假日), 天气情况（降雨），最高温度，风力]
#
# 输出未来客流量的预测值：
# OUTPUT[Passenger_flow / h]
#
# ## 4. 网络结构：
#
# 网络采用7维的特征值向量作为输入参数，两层64节点的隐含层，隐含层采用“relu”激活函数，输出层是1维的客流量数值。下面是网络的结构：
#
# INPUT[x1,x2...,x7] ->
# Hiddden layer1[64 Nodes, 'relu' activation function] -> Hidden layer2[64 Nodes,'relu]
# -> OUTPUT[Passenger_flow]
#
#
# ## 5.情景分析-上海虹桥地跌进出站客流分析：
#
# 本章节采用上海虹桥实际的地铁进出站客流数据进行建模和验证，分析算法模型对与客流量预测的可行性。本章详细的介绍了模型的搭建流程，包括运行环境的检查， 输入数据的处理分析以及预测模型的训练和结果预测。 模型构建的目录如下：
#
# 5.1. 环境检查
#     5.1.1 Python版本检查
#     5.1.2  基础包导入检查
#     5.1.3 检查安装版本
#
# 5.2. 客流量数据预处理和特征分析
#     5.2.1 读取数据
#     5.2.2 提取闸机数据，转换为小时的客流量数据
#             绘制 客流量 / 小时 统计图
#             绘制 节假日 / 日期 统计图
#
# 5.3. 搭建神经网络预测模型
#     5.3.1 网络输入数据标准化
#     5.3.2 搭建网络框架
#     5.3.3 训练神经网络
#     5.3.4 预测结果

# %% [markdown]
# ### 5.1 环境检查

# %% [markdown]
# #### 5.1.1 Python版本检查
# python 3 on anaconda

# %%
# !python3 --version
# Out:
# Python 3.7.5

# %% [raw]
# Anaconda 环境配置（mac）
# https://www.jianshu.com/p/b9eac8419c8d
# 需要的环境参数：export PATH=/Users/zhangfujiang/anaconda3/bin:$PATH，
# 配置环境变量：conda env create -f  /Users/zhangfujiang/virtual_platform_mac.yml
# Environment: jp_kernel on mackbook pro

# %% [markdown]
# #### 5.1.2  基础包导入检查

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import OneHotEncoder

# %% [raw]
# 在终端运行
# pip install tensorflow and keras  源： -i https://pypi.tuna.tsinghua.edu.cn/simple

# %%
import tensorflow
import keras
print('tensorflow:', tensorflow.__version__)
print('keras:', keras.__version__)
# !python3 --version
# Out:
# tensorflow: 2.0.0
# keras: 2.3.1
# Python 3.7.5
# Using TensorFlow backend.

# %% [markdown]
# #### 5.1.3 检查安装版本

# %%
import numpy
print('numpy:', numpy.__version__)
import scipy
print("scipy:", scipy.__version__)
#import matplotlib as plt
#print('matplotlib:', matplotlib.__version__)
# Out:
# numpy: 1.17.3
# scipy: 1.2.1

# %% [markdown]
# ### 5.2 客流量数据预处理和特征分析

# %%
from keras.datasets import boston_housing
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import RMSprop
import numpy as np
import csv
import os
import random
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
# 把日期hash计算:"2018/1/1 0:00:26"--> 0=2018010100
# date 指标： 反映时间的变化
# >> date:"20180101" hour:"00"
def transfer_time(str):
    # str: "2018/1/1 0:00:26"
    data = str.split(' ')
    if len(data) == 1:
        date = data[0]
        hour = 0
        #pdb.set_trace()
    else:
        date = data[0]
        hour = data[1]
    try:
        temp_date = date.split('/')
        if len(temp_date[1]) == 1:
            temp_date[1] = '0' + temp_date[1]
        if len(temp_date[2]) == 1:
            temp_date[2] = '0' + temp_date[2]
        date = temp_date[0] + temp_date[1] + temp_date[2]
        temp_hour = hour.split(':')
        hour = temp_hour[0]
        if len(hour) < 2:
            hour = '0' + hour
    # return 日期和时段
    except Exception as e:
        print("Transfer to time exception:",date)
        print(e)
        hour = "00"
    return date, hour

# %% [markdown]
# #### 5.2.1 读取数据

# %%
# 读取data
# (train_data, train_target), (test_data, test_target) 获取
"""
csv_data: passenger flow
"""
csv_data = pd.read_csv('data.csv')

# %%
# data: {datehour: {t},wind, holiday, weather, datehour, hum, week}
with open('data.json', 'r') as f:
    json_data = json.load(f)

# %%
json_data
# Out:
# {'2018010105': {'t': '2℃',
#   'hum': '91%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010105},
#  '2018010106': {'t': '2℃',
#   'hum': '91%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010106},
#  '2018010107': {'t': '2℃',
#   'hum': '94%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010107},
#  '2018010108': {'t': '5℃',
#   'hum': '76%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010108},
#  '2018010109': {'t': '7℃',
#   'hum': '56%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010109},
#  '2018010110': {'t': '9℃',
#   'hum': '36%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010110},
#  '2018010111': {'t': '10℃',
#   'hum': '34%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010111},
#  '2018010112': {'t': '10℃',
#   'hum': '24%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010112},
#  '2018010113': {'t': '11℃',
#   'hum': '29%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010113},
#  '2018010114': {'t': '11℃',
#   'hum': '27%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010114},
#  '2018010115': {'t': '11℃',
#   'hum': '30%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010115},
#  '2018010116': {'t': '9℃',
#   'hum': '41%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010116},
#  '2018010117': {'t': '7℃',
#   'hum': '54%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010117},
#  '2018010118': {'t': '6℃',
#   'hum': '66%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010118},
#  '2018010119': {'t': '5℃',
#   'hum': '72%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010119},
#  '2018010120': {'t': '6℃',
#   'hum': '70%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010120},
#  '2018010121': {'t': '6℃',
#   'hum': '70%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010121},
#  '2018010122': {'t': '7℃',
#   'hum': '70%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010122},
#  '2018010123': {'t': '7℃',
#   'hum': '70%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010123},
#  '2018010205': {'t': '10℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010205},
#  '2018010206': {'t': '10℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010206},
#  '2018010207': {'t': '10℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010207},
#  '2018010208': {'t': '10℃',
#   'hum': '71%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010208},
#  '2018010209': {'t': '11℃',
#   'hum': '67%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010209},
#  '2018010210': {'t': '12℃',
#   'hum': '61%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010210},
#  '2018010211': {'t': '13℃',
#   'hum': '61%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010211},
#  '2018010212': {'t': '13℃',
#   'hum': '62%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010212},
#  '2018010213': {'t': '12℃',
#   'hum': '64%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010213},
#  '2018010214': {'t': '12℃',
#   'hum': '67%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010214},
#  '2018010215': {'t': '12℃',
#   'hum': '71%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010215},
#  '2018010216': {'t': '12℃',
#   'hum': '74%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010216},
#  '2018010217': {'t': '12℃',
#   'hum': '75%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010217},
#  '2018010218': {'t': '11℃',
#   'hum': '77%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010218},
#  '2018010219': {'t': '11℃',
#   'hum': '77%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010219},
#  '2018010220': {'t': '11℃',
#   'hum': '89%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010220},
#  '2018010221': {'t': '11℃',
#   'hum': '89%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010221},
#  '2018010222': {'t': '10℃',
#   'hum': '95%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010222},
#  '2018010223': {'t': '10℃',
#   'hum': '95%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010223},
#  '2018010305': {'t': '7℃',
#   'hum': '92%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010305},
#  '2018010306': {'t': '7℃',
#   'hum': '92%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010306},
#  '2018010307': {'t': '8℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010307},
#  '2018010308': {'t': '8℃',
#   'hum': '89%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010308},
#  '2018010309': {'t': '8℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010309},
#  '2018010310': {'t': '8℃',
#   'hum': '92%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010310},
#  '2018010311': {'t': '8℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010311},
#  '2018010312': {'t': '8℃',
#   'hum': '80%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010312},
#  '2018010313': {'t': '8℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010313},
#  '2018010314': {'t': '7℃',
#   'hum': '81%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010314},
#  '2018010315': {'t': '7℃',
#   'hum': '77%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010315},
#  '2018010316': {'t': '7℃',
#   'hum': '78%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010316},
#  '2018010317': {'t': '6℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010317},
#  '2018010318': {'t': '5℃',
#   'hum': '89%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010318},
#  '2018010319': {'t': '5℃',
#   'hum': '90%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010319},
#  '2018010320': {'t': '5℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010320},
#  '2018010321': {'t': '5℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010321},
#  '2018010322': {'t': '4℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010322},
#  '2018010323': {'t': '4℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010323},
#  '2018010405': {'t': '4℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010405},
#  '2018010406': {'t': '4℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010406},
#  '2018010407': {'t': '4℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010407},
#  '2018010408': {'t': '4℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010408},
#  '2018010409': {'t': '4℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010409},
#  '2018010410': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010410},
#  '2018010411': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010411},
#  '2018010412': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010412},
#  '2018010413': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010413},
#  '2018010414': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010414},
#  '2018010415': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010415},
#  '2018010416': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010416},
#  '2018010417': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010417},
#  '2018010418': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010418},
#  '2018010419': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010419},
#  '2018010420': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010420},
#  '2018010421': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010421},
#  '2018010422': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010422},
#  '2018010423': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010423},
#  '2018010505': {'t': '3℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010505},
#  '2018010506': {'t': '3℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010506},
#  '2018010507': {'t': '3℃',
#   'hum': '92%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010507},
#  '2018010508': {'t': '4℃',
#   'hum': '88%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010508},
#  '2018010509': {'t': '4℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010509},
#  '2018010510': {'t': '5℃',
#   'hum': '74%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010510},
#  '2018010511': {'t': '5℃',
#   'hum': '73%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010511},
#  '2018010512': {'t': '5℃',
#   'hum': '66%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010512},
#  '2018010513': {'t': '5℃',
#   'hum': '64%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010513},
#  '2018010514': {'t': '5℃',
#   'hum': '66%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010514},
#  '2018010515': {'t': '4℃',
#   'hum': '67%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010515},
#  '2018010516': {'t': '4℃',
#   'hum': '67%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010516},
#  '2018010517': {'t': '4℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010517},
#  '2018010518': {'t': '3℃',
#   'hum': '69%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010518},
#  '2018010519': {'t': '3℃',
#   'hum': '69%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010519},
#  '2018010520': {'t': '2℃',
#   'hum': '79%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010520},
#  '2018010521': {'t': '2℃',
#   'hum': '79%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010521},
#  '2018010522': {'t': '1℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010522},
#  '2018010523': {'t': '1℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010523},
#  '2018010605': {'t': '0℃',
#   'hum': '89%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010605},
#  '2018010606': {'t': '0℃',
#   'hum': '89%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010606},
#  '2018010607': {'t': '1℃',
#   'hum': '85%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010607},
#  '2018010608': {'t': '2℃',
#   'hum': '81%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010608},
#  '2018010609': {'t': '4℃',
#   'hum': '74%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010609},
#  '2018010610': {'t': '5℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010610},
#  '2018010611': {'t': '7℃',
#   'hum': '58%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010611},
#  '2018010612': {'t': '7℃',
#   'hum': '60%',
#   'weather': '阴',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010612},
#  '2018010613': {'t': '7℃',
#   'hum': '59%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010613},
#  '2018010614': {'t': '8℃',
#   'hum': '59%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010614},
#  '2018010615': {'t': '7℃',
#   'hum': '63%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010615},
#  '2018010616': {'t': '7℃',
#   'hum': '67%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010616},
#  '2018010617': {'t': '6℃',
#   'hum': '69%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010617},
#  '2018010618': {'t': '6℃',
#   'hum': '71%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010618},
#  '2018010619': {'t': '6℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010619},
#  '2018010620': {'t': '6℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010620},
#  '2018010621': {'t': '6℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010621},
#  '2018010622': {'t': '6℃',
#   'hum': '94%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010622},
#  '2018010623': {'t': '6℃',
#   'hum': '94%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010623},
#  '2018010705': {'t': '8℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010705},
#  '2018010706': {'t': '8℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010706},
#  '2018010707': {'t': '8℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010707},
#  '2018010708': {'t': '8℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010708},
#  '2018010709': {'t': '9℃',
#   'hum': '98%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010709},
#  '2018010710': {'t': '9℃',
#   'hum': '98%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010710},
#  '2018010711': {'t': '10℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010711},
#  '2018010712': {'t': '10℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010712},
#  '2018010713': {'t': '10℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010713},
#  '2018010714': {'t': '9℃',
#   'hum': '96%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010714},
#  '2018010715': {'t': '8℃',
#   'hum': '96%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010715},
#  '2018010716': {'t': '6℃',
#   'hum': '95%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010716},
#  '2018010717': {'t': '6℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '3级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010717},
#  '2018010718': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010718},
#  '2018010719': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010719},
#  '2018010720': {'t': '5℃',
#   'hum': '89%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010720},
#  '2018010721': {'t': '5℃',
#   'hum': '89%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010721},
#  '2018010722': {'t': '4℃',
#   'hum': '88%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010722},
#  '2018010723': {'t': '4℃',
#   'hum': '88%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010723},
#  '2018010805': {'t': '3℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010805},
#  '2018010806': {'t': '3℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010806},
#  '2018010807': {'t': '3℃',
#   'hum': '83%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010807},
#  '2018010808': {'t': '3℃',
#   'hum': '82%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010808},
#  '2018010809': {'t': '3℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010809},
#  '2018010810': {'t': '3℃',
#   'hum': '78%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010810},
#  '2018010811': {'t': '3℃',
#   'hum': '71%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010811},
#  '2018010812': {'t': '3℃',
#   'hum': '70%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010812},
#  '2018010813': {'t': '3℃',
#   'hum': '67%',
#   'weather': '多云',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010813},
#  '2018010814': {'t': '3℃',
#   'hum': '65%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010814},
#  '2018010815': {'t': '3℃',
#   'hum': '64%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010815},
#  '2018010816': {'t': '4℃',
#   'hum': '65%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010816},
#  '2018010817': {'t': '3℃',
#   'hum': '63%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010817},
#  '2018010818': {'t': '3℃',
#   'hum': '66%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010818},
#  '2018010819': {'t': '2℃',
#   'hum': '53%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010819},
#  '2018010820': {'t': '1℃',
#   'hum': '54%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010820},
#  '2018010821': {'t': '1℃',
#   'hum': '54%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010821},
#  '2018010822': {'t': '0℃',
#   'hum': '49%',
#   'weather': '多云',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010822},
#  '2018010823': {'t': '0℃',
#   'hum': '49%',
#   'weather': '多云',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010823},
#  '2018010905': {'t': '0℃',
#   'hum': '57%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010905},
#  '2018010906': {'t': '0℃',
#   'hum': '57%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010906},
#  '2018010907': {'t': '0℃',
#   'hum': '57%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010907},
#  '2018010908': {'t': '2℃',
#   'hum': '47%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010908},
#  '2018010909': {'t': '3℃',
#   'hum': '42%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010909},
#  '2018010910': {'t': '4℃',
#   'hum': '38%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010910},
#  '2018010911': {'t': '5℃',
#   'hum': '33%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010911},
#  '2018010912': {'t': '5℃',
#   'hum': '30%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010912},
#  '2018010913': {'t': '5℃',
#   'hum': '27%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010913},
#  '2018010914': {'t': '5℃',
#   'hum': '27%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010914},
#  '2018010915': {'t': '6℃',
#   'hum': '28%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010915},
#  '2018010916': {'t': '5℃',
#   'hum': '33%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010916},
#  '2018010917': {'t': '4℃',
#   'hum': '36%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010917},
#  '2018010918': {'t': '4℃',
#   'hum': '39%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010918},
#  '2018010919': {'t': '3℃',
#   'hum': '45%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010919},
#  '2018010920': {'t': '1℃',
#   'hum': '57%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010920},
#  '2018010921': {'t': '1℃',
#   'hum': '57%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010921},
#  '2018010922': {'t': '3℃',
#   'hum': '48%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010922},
#  '2018010923': {'t': '3℃',
#   'hum': '48%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010923},
#  '2018011005': {'t': '1℃',
#   'hum': '59%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011005},
#  '2018011006': {'t': '1℃',
#   'hum': '59%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011006},
#  '2018011007': {'t': '2℃',
#   'hum': '54%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011007},
#  '2018011008': {'t': '2℃',
#   'hum': '51%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011008},
#  '2018011009': {'t': '3℃',
#   'hum': '43%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011009},
#  '2018011010': {'t': '4℃',
#   'hum': '36%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011010},
#  '2018011011': {'t': '5℃',
#   'hum': '30%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011011},
#  '2018011012': {'t': '5℃',
#   'hum': '24%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011012},
#  '2018011013': {'t': '5℃',
#   'hum': '21%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011013},
#  '2018011014': {'t': '5℃',
#   'hum': '23%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011014},
#  '2018011015': {'t': '5℃',
#   'hum': '26%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011015},
#  '2018011016': {'t': '5℃',
#   'hum': '28%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011016},
#  '2018011017': {'t': '4℃',
#   'hum': '36%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011017},
#  '2018011018': {'t': '3℃',
#   'hum': '38%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011018},
#  '2018011019': {'t': '1℃',
#   'hum': '50%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011019},
#  '2018011020': {'t': '2℃',
#   'hum': '37%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011020},
#  '2018011021': {'t': '2℃',
#   'hum': '37%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011021},
#  '2018011022': {'t': '1℃',
#   'hum': '43%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011022},
#  '2018011023': {'t': '1℃',
#   'hum': '43%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011023},
#  '2018011105': {'t': '-3℃',
#   'hum': '80%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011105},
#  '2018011106': {'t': '-3℃',
#   'hum': '80%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011106},
#  '2018011107': {'t': '-3℃',
#   'hum': '79%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011107},
#  '2018011108': {'t': '1℃',
#   'hum': '49%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011108},
#  '2018011109': {'t': '3℃',
#   'hum': '37%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011109},
#  '2018011110': {'t': '3℃',
#   'hum': '27%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011110},
#  '2018011111': {'t': '4℃',
#   'hum': '24%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011111},
#  '2018011112': {'t': '5℃',
#   'hum': '25%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011112},
#  '2018011113': {'t': '5℃',
#   'hum': '23%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011113},
#  '2018011114': {'t': '5℃',
#   'hum': '25%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011114},
#  '2018011115': {'t': '5℃',
#   'hum': '33%',
#   'weather': '晴',
#   'wind': '5级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011115},
#  '2018011116': {'t': '5℃',
#   'hum': '24%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011116},
#  '2018011117': {'t': '4℃',
#   'hum': '31%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011117},
#  '2018011118': {'t': '3℃',
#   'hum': '39%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011118},
#  '2018011119': {'t': '3℃',
#   'hum': '39%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011119},
#  '2018011120': {'t': '1℃',
#   'hum': '52%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011120},
#  '2018011121': {'t': '1℃',
#   'hum': '52%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011121},
#  '2018011122': {'t': '0℃',
#   'hum': '58%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011122},
#  '2018011123': {'t': '0℃',
#   'hum': '58%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011123},
#  '2018011205': {'t': '-3℃',
#   'hum': '53%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011205},
#  '2018011206': {'t': '-3℃',
#   'hum': '53%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011206},
#  '2018011207': {'t': '-3℃',
#   'hum': '53%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011207},
#  '2018011208': {'t': '-1℃',
#   'hum': '45%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011208},
#  '2018011209': {'t': '0℃',
#   'hum': '41%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011209},
#  '2018011210': {'t': '0℃',
#   'hum': '37%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011210},
#  '2018011211': {'t': '1℃',
#   'hum': '28%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011211},
#  '2018011212': {'t': '2℃',
#   'hum': '29%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011212},
#  '2018011213': {'t': '2℃',
#   'hum': '25%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011213},
#  '2018011214': {'t': '3℃',
#   'hum': '24%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011214},
#  '2018011215': {'t': '3℃',
#   'hum': '23%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011215},
#  '2018011216': {'t': '2℃',
#   'hum': '24%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011216},
#  '2018011217': {'t': '0℃',
#   'hum': '26%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011217},
#  '2018011218': {'t': '0℃',
#   'hum': '34%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011218},
#  '2018011219': {'t': '-1℃',
#   'hum': '42%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011219},
#  '2018011220': {'t': '-3℃',
#   'hum': '60%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011220},
#  '2018011221': {'t': '-3℃',
#   'hum': '60%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011221},
#  '2018011222': {'t': '-4℃',
#   'hum': '72%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011222},
#  '2018011223': {'t': '-4℃',
#   'hum': '72%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011223},
#  '2018011305': {'t': '-6℃',
#   'hum': '88%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011305},
#  '2018011306': {'t': '-6℃',
#   'hum': '88%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011306},
#  '2018011307': {'t': '-5℃',
#   'hum': '89%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011307},
#  '2018011308': {'t': '0℃',
#   'hum': '56%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011308},
#  '2018011309': {'t': '2℃',
#   'hum': '40%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011309},
#  '2018011310': {'t': '4℃',
#   'hum': '32%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011310},
#  '2018011311': {'t': '5℃',
#   'hum': '30%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011311},
#  '2018011312': {'t': '5℃',
#   'hum': '39%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011312},
#  '2018011313': {'t': '5℃',
#   'hum': '37%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011313},
#  '2018011314': {'t': '6℃',
#   'hum': '35%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011314},
#  '2018011315': {'t': '5℃',
#   'hum': '36%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011315},
#  '2018011316': {'t': '4℃',
#   'hum': '38%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011316},
#  '2018011317': {'t': '3℃',
#   'hum': '46%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011317},
#  '2018011318': {'t': '3℃',
#   'hum': '56%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011318},
#  '2018011319': {'t': '3℃',
#   'hum': '60%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011319},
#  '2018011320': {'t': '2℃',
#   'hum': '57%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011320},
#  '2018011321': {'t': '2℃',
#   'hum': '57%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011321},
#  '2018011322': {'t': '2℃',
#   'hum': '62%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011322},
#  '2018011323': {'t': '2℃',
#   'hum': '62%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011323},
#  '2018011405': {'t': '3℃',
#   'hum': '77%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011405},
#  '2018011406': {'t': '3℃',
#   'hum': '77%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011406},
#  '2018011407': {'t': '3℃',
#   'hum': '83%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011407},
#  '2018011408': {'t': '5℃',
#   'hum': '75%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011408},
#  '2018011409': {'t': '7℃',
#   'hum': '68%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011409},
#  '2018011410': {'t': '10℃',
#   'hum': '56%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011410},
#  '2018011411': {'t': '11℃',
#   'hum': '49%',
#   'weather': '多云',
#   'wind': '3级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011411},
#  '2018011412': {'t': '11℃',
#   'hum': '50%',
#   'weather': '多云',
#   'wind': '3级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011412},
#  '2018011413': {'t': '12℃',
#   'hum': '50%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011413},
#  '2018011414': {'t': '11℃',
#   'hum': '50%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011414},
#  '2018011415': {'t': '11℃',
#   'hum': '50%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011415},
#  '2018011416': {'t': '10℃',
#   'hum': '52%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011416},
#  '2018011417': {'t': '8℃',
#   'hum': '65%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011417},
#  '2018011418': {'t': '5℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011418},
#  '2018011419': {'t': '4℃',
#   'hum': '88%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011419},
#  '2018011420': {'t': '3℃',
#   'hum': '94%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011420},
#  '2018011421': {'t': '3℃',
#   'hum': '94%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011421},
#  '2018011422': {'t': '2℃',
#   'hum': '96%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011422},
#  '2018011423': {'t': '2℃',
#   'hum': '96%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011423},
#  '2018011505': {'t': '0℃',
#   'hum': '97%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011505},
#  '2018011506': {'t': '0℃',
#   'hum': '97%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011506},
#  '2018011507': {'t': '1℃',
#   'hum': '98%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011507},
#  '2018011508': {'t': '6℃',
#   'hum': '98%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011508},
#  '2018011509': {'t': '10℃',
#   'hum': '68%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011509},
#  '2018011510': {'t': '13℃',
#   'hum': '47%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011510},
#  '2018011511': {'t': '15℃',
#   'hum': '38%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011511},
#  '2018011512': {'t': '15℃',
#   'hum': '37%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011512},
#  '2018011513': {'t': '16℃',
#   'hum': '36%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011513},
#  '2018011514': {'t': '16℃',
#   'hum': '43%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011514},
#  '2018011515': {'t': '15℃',
#   'hum': '52%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011515},
#  '2018011516': {'t': '14℃',
#   'hum': '68%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011516},
#  '2018011517': {'t': '12℃',
#   'hum': '75%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011517},
#  '2018011518': {'t': '11℃',
#   'hum': '86%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011518},
#  '2018011519': {'t': '10℃',
#   'hum': '91%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011519},
#  '2018011520': {'t': '9℃',
#   'hum': '94%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011520},
#  '2018011521': {'t': '9℃',
#   'hum': '94%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011521},
#  '2018011522': {'t': '9℃',
#   'hum': '96%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011522},
#  '2018011523': {'t': '9℃',
#   'hum': '96%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011523},
#  '2018011605': {'t': '11℃',
#   'hum': '98%',
#   'weather': '雾',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011605},
#  '2018011606': {'t': '11℃',
#   'hum': '98%',
#   'weather': '雾',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011606},
#  '2018011607': {'t': '11℃',
#   'hum': '98%',
#   'weather': '雾',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011607},
#  '2018011608': {'t': '11℃',
#   'hum': '98%',
#   'weather': '雾',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011608},
#  '2018011609': {'t': '12℃',
#   'hum': '98%',
#   'weather': '雾',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011609},
#  '2018011610': {'t': '12℃',
#   'hum': '98%',
#   'weather': '雾',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011610},
#  '2018011611': {'t': '13℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011611},
#  '2018011612': {'t': '14℃',
#   'hum': '69%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011612},
#  '2018011613': {'t': '14℃',
#   'hum': '66%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011613},
#  '2018011614': {'t': '13℃',
#   'hum': '73%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011614},
#  '2018011615': {'t': '13℃',
#   'hum': '71%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011615},
#  '2018011616': {'t': '13℃',
#   'hum': '66%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011616},
#  '2018011617': {'t': '12℃',
#   'hum': '75%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011617},
#  '2018011618': {'t': '12℃',
#   'hum': '78%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011618},
#  '2018011619': {'t': '11℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011619},
#  '2018011620': {'t': '10℃',
#   'hum': '85%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011620},
#  '2018011621': {'t': '10℃',
#   'hum': '85%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011621},
#  '2018011622': {'t': '10℃',
#   'hum': '86%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011622},
#  '2018011623': {'t': '10℃',
#   'hum': '86%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011623},
#  '2018011705': {'t': '8℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011705},
#  '2018011706': {'t': '8℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011706},
#  '2018011707': {'t': '8℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011707},
#  '2018011708': {'t': '8℃',
#   'hum': '77%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011708},
#  '2018011709': {'t': '9℃',
#   'hum': '74%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011709},
#  '2018011710': {'t': '11℃',
#   'hum': '65%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011710},
#  '2018011711': {'t': '11℃',
#   'hum': '63%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011711},
#  '2018011712': {'t': '12℃',
#   'hum': '58%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011712},
#  '2018011713': {'t': '12℃',
#   'hum': '56%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011713},
#  '2018011714': {'t': '12℃',
#   'hum': '57%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011714},
#  '2018011715': {'t': '12℃',
#   'hum': '59%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011715},
#  '2018011716': {'t': '11℃',
#   'hum': '62%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011716},
#  '2018011717': {'t': '10℃',
#   'hum': '68%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011717},
#  '2018011718': {'t': '9℃',
#   'hum': '72%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011718},
#  '2018011719': {'t': '8℃',
#   'hum': '83%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011719},
#  '2018011720': {'t': '7℃',
#   'hum': '84%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011720},
#  '2018011721': {'t': '7℃',
#   'hum': '84%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011721},
#  '2018011722': {'t': '7℃',
#   'hum': '83%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011722},
#  '2018011723': {'t': '7℃',
#   'hum': '83%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011723},
#  '2018011805': {'t': '7℃',
#   'hum': '86%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011805},
#  '2018011806': {'t': '7℃',
#   'hum': '86%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011806},
#  '2018011807': {'t': '7℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011807},
#  '2018011808': {'t': '8℃',
#   'hum': '72%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011808},
#  '2018011809': {'t': '8℃',
#   'hum': '71%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011809},
#  '2018011810': {'t': '9℃',
#   'hum': '67%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011810},
#  '2018011811': {'t': '10℃',
#   'hum': '61%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011811},
#  '2018011812': {'t': '10℃',
#   'hum': '59%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011812},
#  '2018011813': {'t': '10℃',
#   'hum': '64%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011813},
#  '2018011814': {'t': '9℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011814},
#  '2018011815': {'t': '9℃',
#   'hum': '72%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011815},
#  '2018011816': {'t': '8℃',
#   'hum': '72%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011816},
#  '2018011817': {'t': '8℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011817},
#  '2018011818': {'t': '8℃',
#   'hum': '68%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011818},
#  '2018011819': {'t': '8℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011819},
#  '2018011820': {'t': '8℃',
#   'hum': '70%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011820},
#  '2018011821': {'t': '8℃',
#   'hum': '70%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011821},
#  '2018011822': {'t': '8℃',
#   'hum': '68%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011822},
#  '2018011823': {'t': '8℃',
#   'hum': '68%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011823},
#  '2018011905': {'t': '8℃',
#   'hum': '76%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011905},
#  '2018011906': {'t': '8℃',
#   'hum': '76%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011906},
#  '2018011907': {'t': '8℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011907},
#  '2018011908': {'t': '7℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011908},
#  '2018011909': {'t': '8℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011909},
#  '2018011910': {'t': '8℃',
#   'hum': '73%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011910},
#  '2018011911': {'t': '9℃',
#   'hum': '74%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011911},
#  '2018011912': {'t': '8℃',
#   'hum': '83%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011912},
#  '2018011913': {'t': '8℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011913},
#  '2018011914': {'t': '8℃',
#   'hum': '81%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011914},
#  '2018011915': {'t': '8℃',
#   'hum': '81%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011915},
#  '2018011916': {'t': '8℃',
#   'hum': '81%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011916},
#  '2018011917': {'t': '8℃',
#   'hum': '81%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011917},
#  '2018011918': {'t': '8℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011918},
#  '2018011919': {'t': '8℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011919},
#  '2018011920': {'t': '8℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011920},
#  '2018011921': {'t': '8℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011921},
#  '2018011922': {'t': '8℃',
#   'hum': '79%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011922},
#  '2018011923': {'t': '8℃',
#   'hum': '79%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011923},
#  '2018012005': {'t': '7℃',
#   'hum': '75%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012005},
#  '2018012006': {'t': '7℃',
#   'hum': '75%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012006},
#  '2018012007': {'t': '7℃',
#   'hum': '71%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012007},
#  '2018012008': {'t': '7℃',
#   'hum': '67%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012008},
#  '2018012009': {'t': '7℃',
#   'hum': '71%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012009},
#  '2018012010': {'t': '7℃',
#   'hum': '74%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012010},
#  '2018012011': {'t': '7℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012011},
#  '2018012012': {'t': '6℃',
#   'hum': '84%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012012},
#  '2018012013': {'t': '6℃',
#   'hum': '85%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012013},
#  '2018012014': {'t': '6℃',
# ...
#   'wind': '2级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021607},
#  '2018021608': {'t': '4℃',
#   'hum': '92%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021608},
#  '2018021609': {'t': '4℃',
#   'hum': '90%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021609},
#  '2018021610': {'t': '4℃',
#   'hum': '88%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021610},
#  '2018021611': {'t': '4℃',
#   'hum': '87%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021611},
#  '2018021612': {'t': '5℃',
#   'hum': '87%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021612},
#  '2018021613': {'t': '6℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021613},
#  '2018021614': {'t': '5℃',
#   'hum': '83%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021614},
#  '2018021615': {'t': '5℃',
#   'hum': '79%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021615},
#  '2018021616': {'t': '6℃',
#   'hum': '78%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021616},
#  '2018021617': {'t': '5℃',
#   'hum': '81%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021617},
#  '2018021618': {'t': '5℃',
#   'hum': '83%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021618},
#  '2018021619': {'t': '5℃',
#   'hum': '83%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021619},
#  '2018021620': {'t': '5℃',
#   'hum': '77%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021620},
#  '2018021621': {'t': '5℃',
#   'hum': '77%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021621},
#  '2018021622': {'t': '4℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021622},
#  '2018021623': {'t': '4℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021623},
#  '2018021705': {'t': '0℃',
#   'hum': '97%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021705},
#  '2018021706': {'t': '0℃',
#   'hum': '97%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021706},
#  '2018021707': {'t': '1℃',
#   'hum': '97%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021707},
#  '2018021708': {'t': '5℃',
#   'hum': '77%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021708},
#  '2018021709': {'t': '6℃',
#   'hum': '62%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021709},
#  '2018021710': {'t': '8℃',
#   'hum': '61%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021710},
#  '2018021711': {'t': '9℃',
#   'hum': '59%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021711},
#  '2018021712': {'t': '10℃',
#   'hum': '50%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021712},
#  '2018021713': {'t': '10℃',
#   'hum': '52%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021713},
#  '2018021714': {'t': '10℃',
#   'hum': '51%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021714},
#  '2018021715': {'t': '10℃',
#   'hum': '51%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021715},
#  '2018021716': {'t': '8℃',
#   'hum': '55%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021716},
#  '2018021717': {'t': '7℃',
#   'hum': '65%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021717},
#  '2018021718': {'t': '6℃',
#   'hum': '70%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021718},
#  '2018021719': {'t': '5℃',
#   'hum': '74%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021719},
#  '2018021720': {'t': '5℃',
#   'hum': '74%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021720},
#  '2018021721': {'t': '5℃',
#   'hum': '74%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021721},
#  '2018021722': {'t': '5℃',
#   'hum': '80%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021722},
#  '2018021723': {'t': '5℃',
#   'hum': '80%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021723},
#  '2018021805': {'t': '7℃',
#   'hum': '78%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021805},
#  '2018021806': {'t': '7℃',
#   'hum': '78%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021806},
#  '2018021807': {'t': '7℃',
#   'hum': '83%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021807},
#  '2018021808': {'t': '8℃',
#   'hum': '78%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021808},
#  '2018021809': {'t': '8℃',
#   'hum': '79%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021809},
#  '2018021810': {'t': '10℃',
#   'hum': '73%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021810},
#  '2018021811': {'t': '10℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021811},
#  '2018021812': {'t': '11℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021812},
#  '2018021813': {'t': '10℃',
#   'hum': '75%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021813},
#  '2018021814': {'t': '10℃',
#   'hum': '77%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021814},
#  '2018021815': {'t': '9℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021815},
#  '2018021816': {'t': '8℃',
#   'hum': '88%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021816},
#  '2018021817': {'t': '8℃',
#   'hum': '88%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021817},
#  '2018021818': {'t': '7℃',
#   'hum': '92%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021818},
#  '2018021819': {'t': '7℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021819},
#  '2018021820': {'t': '7℃',
#   'hum': '95%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021820},
#  '2018021821': {'t': '7℃',
#   'hum': '95%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021821},
#  '2018021822': {'t': '7℃',
#   'hum': '96%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021822},
#  '2018021823': {'t': '7℃',
#   'hum': '96%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021823},
#  '2018021905': {'t': '6℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021905},
#  '2018021906': {'t': '6℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021906},
#  '2018021907': {'t': '7℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021907},
#  '2018021908': {'t': '7℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021908},
#  '2018021909': {'t': '7℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021909},
#  '2018021910': {'t': '7℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021910},
#  '2018021911': {'t': '8℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021911},
#  '2018021912': {'t': '8℃',
#   'hum': '96%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021912},
#  '2018021913': {'t': '7℃',
#   'hum': '96%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021913},
#  '2018021914': {'t': '7℃',
#   'hum': '95%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021914},
#  '2018021915': {'t': '7℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021915},
#  '2018021916': {'t': '6℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021916},
#  '2018021917': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021917},
#  '2018021918': {'t': '5℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021918},
#  '2018021919': {'t': '5℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021919},
#  '2018021920': {'t': '6℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021920},
#  '2018021921': {'t': '6℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021921},
#  '2018021922': {'t': '6℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021922},
#  '2018021923': {'t': '6℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021923},
#  '2018022005': {'t': '6℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022005},
#  '2018022006': {'t': '6℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022006},
#  '2018022007': {'t': '6℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022007},
#  '2018022008': {'t': '6℃',
#   'hum': '76%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022008},
#  '2018022009': {'t': '8℃',
#   'hum': '69%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022009},
#  '2018022010': {'t': '8℃',
#   'hum': '69%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022010},
#  '2018022011': {'t': '8℃',
#   'hum': '75%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022011},
#  '2018022012': {'t': '8℃',
#   'hum': '74%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022012},
#  '2018022013': {'t': '8℃',
#   'hum': '79%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022013},
#  '2018022014': {'t': '7℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022014},
#  '2018022015': {'t': '7℃',
#   'hum': '91%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022015},
#  '2018022016': {'t': '6℃',
#   'hum': '85%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022016},
#  '2018022017': {'t': '5℃',
#   'hum': '91%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022017},
#  '2018022018': {'t': '4℃',
#   'hum': '90%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022018},
#  '2018022019': {'t': '4℃',
#   'hum': '91%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022019},
#  '2018022020': {'t': '4℃',
#   'hum': '92%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022020},
#  '2018022021': {'t': '4℃',
#   'hum': '92%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022021},
#  '2018022022': {'t': '4℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022022},
#  '2018022023': {'t': '4℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022023},
#  '2018022105': {'t': '4℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022105},
#  '2018022106': {'t': '4℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022106},
#  '2018022107': {'t': '5℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022107},
#  '2018022108': {'t': '6℃',
#   'hum': '86%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022108},
#  '2018022109': {'t': '6℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022109},
#  '2018022110': {'t': '7℃',
#   'hum': '73%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022110},
#  '2018022111': {'t': '8℃',
#   'hum': '68%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022111},
#  '2018022112': {'t': '8℃',
#   'hum': '70%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022112},
#  '2018022113': {'t': '8℃',
#   'hum': '67%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022113},
#  '2018022114': {'t': '7℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022114},
#  '2018022115': {'t': '7℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022115},
#  '2018022116': {'t': '6℃',
#   'hum': '73%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022116},
#  '2018022117': {'t': '6℃',
#   'hum': '76%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022117},
#  '2018022118': {'t': '5℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '0级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022118},
#  '2018022119': {'t': '5℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022119},
#  '2018022120': {'t': '5℃',
#   'hum': '83%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022120},
#  '2018022121': {'t': '5℃',
#   'hum': '83%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022121},
#  '2018022122': {'t': '5℃',
#   'hum': '82%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022122},
#  '2018022123': {'t': '5℃',
#   'hum': '82%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022123},
#  '2018022205': {'t': '4℃',
#   'hum': '89%',
#   'weather': '阴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022205},
#  '2018022206': {'t': '4℃',
#   'hum': '89%',
#   'weather': '阴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022206},
#  '2018022207': {'t': '5℃',
#   'hum': '85%',
#   'weather': '阴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022207},
#  '2018022208': {'t': '6℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022208},
#  '2018022209': {'t': '8℃',
#   'hum': '64%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022209},
#  '2018022210': {'t': '8℃',
#   'hum': '62%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022210},
#  '2018022211': {'t': '8℃',
#   'hum': '59%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022211},
#  '2018022212': {'t': '8℃',
#   'hum': '65%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022212},
#  '2018022213': {'t': '9℃',
#   'hum': '57%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022213},
#  '2018022214': {'t': '9℃',
#   'hum': '53%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022214},
#  '2018022215': {'t': '9℃',
#   'hum': '55%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022215},
#  '2018022216': {'t': '9℃',
#   'hum': '56%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022216},
#  ...}

# %%
# 看是否存在缺失值
csv_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 7 columns):
# ID                  65538 non-null int64
# W_C_AREA_CODE       65538 non-null object
# TJ_TIME             65538 non-null object
# IN_TOTAL            65538 non-null int64
# OUT_TOTAL           65538 non-null int64
# REMARK              65538 non-null int64
# W_M_WAYKIND_NAME    65538 non-null object
# dtypes: int64(4), object(3)
# memory usage: 3.5+ MB

# %%
# 将数据整理成date -> data 的字典
# dataFrame: read data 2018/01/01-2018/04/25
csv_batch_data = csv_data
# values dataFrame->array  Transfer array data to dictionary:
print('csv_data shape:', csv_batch_data.shape)
# train_batch_data = csv_batch_data[list(range(3, 6))]  取3:5列
# dataFrame 取行
train_batch_data = csv_batch_data[1:]
#  按照机器类型，将数据分为两组
# 314684 row 之后只有machine1 数据
machine1_data = []
machine2_data = []
# data 为list： ID 0 , W_C_AREA_CODE 1, Time 2, In_total 3, Out_total 4.  DataFrame.values -> array
for data in train_batch_data.values:  
    if data[1] == '05-19-10':
        # list of array -> [ID 0 , W_C_AREA_CODE 1, Time 2, In_total 3, Out_total 4]
        machine1_data.append(data)
    elif data[1] == '04-17-03':
        machine2_data.append(data)
    else:
        print("machine type error!")
# Passenger flow =  In_total + Out_total
print('machine1_data shape:', len(machine1_data))
print('machine2_data shape:', len(machine2_data))
# Out:
# csv_data shape: (65538, 7)
# machine1_data shape: 32599
# machine2_data shape: 32938

# %% [markdown]
# ### 5.2.2 提取闸机数据，转换为小时的客流量数据

# %%
"""
统计小时划分的客流量数据 > data_set1({datehour:[date,weather,week,holiday,high_tmp,low_tmp,wind]}) and target_set1:{datehour:flow} 
"""
import pdb
# [Time 2, In_total 3, Out_total 4] -> machine_data: [Date 0, hour 1, In_total 3, Out_total 4] 
# data_set and target_set 按照日期-时段为key进行划分
# 小时统计算法：记录第一个点record = record(h0), 遍历，if date-hour not changed, update flow, else: dict[date-h_pre] = flow - record, update record = flow.
data_set1 = {}
data_set2= {}
target_set1 = {}
target_set2 = {}

# print(machine1_data) : [Date 0, hour 1, In_total 3, Out_total 4]

# %%
def get_hour_data(machine1_data, data_set1, target_set1):
    record = 0
    flow = 0
    flag_start = True
    date_start = True
    pre_date = 0
    for i in range(len(machine1_data)):
        machine1_data[i][0], machine1_data[i][1] = transfer_time(machine1_data[i][2])
        in_total = machine1_data[i][3]
        out_total = machine1_data[i][4]
        date = machine1_data[i][0]
        hour = machine1_data[i][1]
        if int(hour)>=0 and int(hour)<=4:
            continue
        if flag_start:
            key_start = date + hour
            flag_start = False
        if date_start:
            pre_date = date
            date_start = False
        key = date + hour #2019010100
        # In the same hour: update flow
        if key == key_start:
            flow = (in_total + out_total)
        else:
        # change to next hour:
            # change to next day: record --> 0
            if date != pre_date:
                pre_date = date
                target_set1[key_start] = flow - record
                data_set1[key_start] = json_data[key_start]   # key_start: pre key
                record = 0
                flow = in_total + out_total
            else:
                target_set1[key_start] = flow - record
                data_set1[key_start] = json_data[key_start]
                record = flow
            key_start = key

# %%
get_hour_data(machine1_data, data_set1, target_set1)
get_hour_data(machine2_data, data_set2, target_set2)
print(len(target_set1),len(target_set2))
# Out:
# 2184 2184

# %%
# Traversal data_set1 and Add Passenger-flow in target_set1 and target_set2 with same date-hour
# Use data_set1 and target_set as Input and Output raw data
target_set = {}
for key in target_set1:
    if key in target_set2:
        target_set[key] = target_set1[key] + target_set2[key]
print(len(target_set))
# Out:
# 2184

# %%
def plot_week(target_set):
    fig= plt.figure(figsize=(12,5))
    y = []
    x_data = list(target_set.keys())
    x = x_data[19:153]
    for key in x:
        y.append(target_set[key])
    y = np.array(y)
    x_data = np.linspace(0, 135, len(y))
    #x_data = np.array(x_data)
    plt.plot(x_data,y,'b-',lw=1)

# %%
# 输出一天Passenger Flow / h 实际值   --> machine 1
plot_week(target_set1)
plot_week(target_set2)
plot_week(target_set)

# %%
"""
Plot hour_flow figure:
"""
# 输出一天Passenger Flow / h 实际值  --> machine 2
fig= plt.figure(figsize=(12,5))
y = []
x_data = list(target_set.keys())
x = x_data[0:600]
for key in x:
    y.append(target_set[key])
y = np.array(y)
x_data = np.linspace(0, 500, len(y))
#x_data = np.array(x_data)
plt.plot(x_data,y,'g-',lw=1)

# %%
"""
Plot dict_holiday figure: 节假日情况分布 
"week day 0, holiday in law 1, make up for working 2，weekend 3 "
"""
# 输出一天Passenger Flow / h 实际值  --> machine 2
holiday = []
for value in json_data.values():
    holiday.append(value['holiday'])
fig= plt.figure(figsize=(12,5))
y = []
y = holiday
y = np.array(y)
x_data = np.linspace(0, 115, len(y))
#x_data = np.array(x_data)
plt.scatter(x_data,y)

# %%
# 两个machine的数据不对称，先放弃machine2， 对machine1的数据进行分析

# %% [markdown]
# 标准化： $X_t = \frac {X - mean} {std}$
# 计算客流量累加值为/1 hour 的时段值

# %% [markdown]
# ### 5.3 搭建神经网络预测模型

# %% [markdown]
# #### 5.3.1 网络输入数据标准化

# %%
data_set1.values()
# Out:
# dict_values([{'t': '2℃', 'hum': '91%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010105}, {'t': '2℃', 'hum': '91%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010106}, {'t': '2℃', 'hum': '94%', 'weather': '晴', 'wind': '0级', 'holiday': 1, 'week': 1, 'date': 2018010107}, {'t': '5℃', 'hum': '76%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010108}, {'t': '7℃', 'hum': '56%', 'weather': '晴', 'wind': '2级', 'holiday': 1, 'week': 1, 'date': 2018010109}, {'t': '9℃', 'hum': '36%', 'weather': '晴', 'wind': '2级', 'holiday': 1, 'week': 1, 'date': 2018010110}, {'t': '10℃', 'hum': '34%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010111}, {'t': '10℃', 'hum': '24%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010112}, {'t': '11℃', 'hum': '29%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010113}, {'t': '11℃', 'hum': '27%', 'weather': '晴', 'wind': '2级', 'holiday': 1, 'week': 1, 'date': 2018010114}, {'t': '11℃', 'hum': '30%', 'weather': '晴', 'wind': '2级', 'holiday': 1, 'week': 1, 'date': 2018010115}, {'t': '9℃', 'hum': '41%', 'weather': '晴', 'wind': '2级', 'holiday': 1, 'week': 1, 'date': 2018010116}, {'t': '7℃', 'hum': '54%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010117}, {'t': '6℃', 'hum': '66%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010118}, {'t': '5℃', 'hum': '72%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010119}, {'t': '6℃', 'hum': '70%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010120}, {'t': '6℃', 'hum': '70%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010121}, {'t': '7℃', 'hum': '70%', 'weather': '多云', 'wind': '2级', 'holiday': 1, 'week': 1, 'date': 2018010122}, {'t': '7℃', 'hum': '70%', 'weather': '多云', 'wind': '2级', 'holiday': 1, 'week': 1, 'date': 2018010123}, {'t': '10℃', 'hum': '69%', 'weather': '多云', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010205}, {'t': '10℃', 'hum': '69%', 'weather': '多云', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010206}, {'t': '10℃', 'hum': '69%', 'weather': '多云', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010207}, {'t': '10℃', 'hum': '71%', 'weather': '多云', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010208}, {'t': '11℃', 'hum': '67%', 'weather': '多云', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010209}, {'t': '12℃', 'hum': '61%', 'weather': '多云', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010210}, {'t': '13℃', 'hum': '61%', 'weather': '多云', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010211}, {'t': '13℃', 'hum': '62%', 'weather': '多云', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010212}, {'t': '12℃', 'hum': '64%', 'weather': '多云', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010213}, {'t': '12℃', 'hum': '67%', 'weather': '阴', 'wind': '1级', 'holiday': 0, 'week': 2, 'date': 2018010214}, {'t': '12℃', 'hum': '71%', 'weather': '阴', 'wind': '1级', 'holiday': 0, 'week': 2, 'date': 2018010215}, {'t': '12℃', 'hum': '74%', 'weather': '阴', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010216}, {'t': '12℃', 'hum': '75%', 'weather': '阴', 'wind': '1级', 'holiday': 0, 'week': 2, 'date': 2018010217}, {'t': '11℃', 'hum': '77%', 'weather': '阴', 'wind': '1级', 'holiday': 0, 'week': 2, 'date': 2018010218}, {'t': '11℃', 'hum': '77%', 'weather': '阴', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010219}, {'t': '11℃', 'hum': '89%', 'weather': '阴', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010220}, {'t': '11℃', 'hum': '89%', 'weather': '阴', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010221}, {'t': '10℃', 'hum': '95%', 'weather': '阵雨', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010222}, {'t': '10℃', 'hum': '95%', 'weather': '阵雨', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010223}, {'t': '7℃', 'hum': '92%', 'weather': '阴', 'wind': '2级', 'holiday': 0, 'wee ...

# %%
# data_set{datehour: {t:{int}, hum:{int}, weather:{label_encoder}, wind:{int}, holiday:{int}, week:{int}, date:{int},hour:{int}}}
# target_set{datehour: flow}
# dict_values -> obj -> list -> array
# >> data, target
x = []
dict_x = []
#enc.categories_ [array(['多云', '晴', '阴', '阵雨', '阵雪', '雨夹雪', '雾'], dtype='<U3')]
dict_weather={'晴':0, '多云':1,'阴':2, '雾':3,'阵雪':4,'阵雨':5,'雨夹雪':6}
weather = []
for value in data_set1.values():
    dict_x.append(value)
for value in dict_x:
    x.append(np.array(list(value.values())))
for value in x:
    weather.append(value[2])
weather = np.array(weather)
weather = weather.reshape(-1,1)
enc = OneHotEncoder(handle_unknown='ignore')
enc.fit(weather)
category = enc.categories_
weather = enc.transform(weather).toarray()
for i in range(len(x)):   
    x0 = int(x[i][0][:-1])# wind
    x1 = int(x[i][1][:-1])
    #     category = 0
    #     for j in range(len(weather[i])):
    #         category += j * weather[i][j]
    x2 = dict_weather[x[i][2]]
    x3 = int(x[i][3][:-1])
    x4 = int(x[i][4])
    x5 = int(x[i][5])
    x6 = int(x[i][6])
    x7 = int(x[i][6][-2:])
    x[i] = [x0,x1,x2,x3,x4,x5,x6,x7]
y = list(target_set.values())
data = np.array(x)
target = np.array(y)
mean = data.mean(axis=0)
# pdb.set_trace()
std = data.std(axis = 0)
# 数组中的每一个element都会减mean
data = (data - mean) / std
# target_set = (target_set - mean_y) / std_y

# %%
# 两个machine的数据不对称，先放弃machine2， 对machine1的数据进行分析
print(data.shape)
print(target.shape)
# Out:
# (2184, 8)
# (2184,)

# %% [markdown]
# ### Target variable
# Some analysis on target variable

# %%
plt.subplots(figsize=(12,9))
sns.distplot(target, fit=stats.norm)

# Get the fitted parameters used by the function

(mu, sigma) = stats.norm.fit(target)

# plot with the distribution

plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
plt.ylabel('Frequency')

#Probablity plot

fig = plt.figure()
stats.probplot(target, plot=plt)
plt.show()

# %%
## Filter out the

# %% [markdown]
# This target varibale is right skewed. Now, we need to tranform this variable and make it normal distribution.
#
# For more information about that [click here](http://whatis.techtarget.com/definition/skewness)

# %% [markdown]
# #### Here we use log for target variable to make more normal distribution

# %% [markdown]
# #### 5.3.2 搭建网络框架

# %%
# input: data  Output: target

# %%
def build_model():
    model = Sequential()
    # 先将维度放大， 在高维空间中抽取特征  
    # Input: week, hour, date, weather
    model.add(Dense(64, input_shape = (8,),activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1))
    # 输出偏差矩阵 correspond to train_target
    model.compile(optimizer = RMSprop(), loss="mse", metrics=['mae'])
    return model

# %% [raw]
#  交叉检验，将数据分成n个集合 1 个验证， n-1个训练集
#  fold n = 5 / 10
#  求的模型的平均得分
#  防止一次训练产生过拟合
#  评价模型综合的情况
#  构造交叉检验的模型

# %%
num_epochs = 5000
all_scores = []

# %%
train_size = int(len(target) * 0.9)
train_data = data[ : train_size]
#print(train_data)
train_target = target[ : train_size]
test_data = data[train_size : ]
test_target = target[train_size : ]
print(len(train_data),len(test_data))
# Out:
# 1965 219

# %%
plt.figure(figsize=(10,8))    
x = np.linspace(0,135,len(target))
plt.plot(x,target,'b-',lw=1)

# %% [markdown]
# # Correlation Analysis
# select features with correlation over 0.5

# %%
# t:{int}, hum:{int}, weather:{label_encoder}, wind:{int}, holiday:{int}, week:{int}, date:{int}
train = pd.DataFrame(np.c_[train_data,train_target],columns=['t','hum','weather','wind','holiday','week','date','hour','target'])

train.columns[train.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
plt.figure(figsize=(12,6))
sns.heatmap(train.isnull())
plt.show()

# %%
train_corr = train.select_dtypes(include = [np.number])
train_corr.shape
# Out:
# (1965, 9)

# %%
corr = train_corr.corr()
plt.subplots(figsize=(20,9))
sns.heatmap(corr,annot=True)

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
from scipy import stats

# %% [markdown]
# #### 5.3.3 训练神经网络

# %%
model = build_model()
# batch_size 训练进入的数据大小为1， verbose = 0 不输出训练数据
model.fit(train_data, train_target, epochs = num_epochs, batch_size = 16 , verbose = 2)
val_mse, val_mae = model.evaluate(test_data, test_target, verbose = 0)
all_scores.append(val_mae)
print("MSE:", val_mse,"MAE:",val_mae)
# Out:
# Epoch 1/5000
#  - 0s - loss: 588033740.6046 - mae: 21137.1445
# Epoch 2/5000
#  - 0s - loss: 585087134.6646 - mae: 21066.9766
# Epoch 3/5000
#  - 0s - loss: 578134400.1628 - mae: 20902.8262
# Epoch 4/5000
#  - 0s - loss: 565493476.6087 - mae: 20613.7695
# Epoch 5/5000
#  - 0s - loss: 545930122.9761 - mae: 20179.5684
# Epoch 6/5000
#  - 0s - loss: 518658206.7786 - mae: 19571.3438
# Epoch 7/5000
#  - 0s - loss: 482499124.8448 - mae: 18756.0312
# Epoch 8/5000
#  - 0s - loss: 438498436.8366 - mae: 17735.1973
# Epoch 9/5000
#  - 0s - loss: 387929768.6148 - mae: 16485.8105
# Epoch 10/5000
#  - 0s - loss: 333049999.9430 - mae: 15055.7080
# Epoch 11/5000
#  - 0s - loss: 277886767.9756 - mae: 13486.4824
# Epoch 12/5000
#  - 0s - loss: 226515943.9226 - mae: 11779.1279
# Epoch 13/5000
#  - 0s - loss: 185737220.6331 - mae: 10268.2236
# Epoch 14/5000
#  - 0s - loss: 160343154.8580 - mae: 9196.2168
# Epoch 15/5000
#  - 0s - loss: 149027785.1684 - mae: 8721.7656
# Epoch 16/5000
#  - 0s - loss: 144308568.8875 - mae: 8503.0029
# Epoch 17/5000
#  - 0s - loss: 141671762.5812 - mae: 8372.8604
# Epoch 18/5000
#  - 0s - loss: 139780433.7059 - mae: 8295.4785
# Epoch 19/5000
#  - 0s - loss: 138264368.3746 - mae: 8220.5156
# Epoch 20/5000
#  - 0s - loss: 136896351.8290 - mae: 8159.0776
# Epoch 21/5000
#  - 0s - loss: 135836806.6036 - mae: 8097.2646
# Epoch 22/5000
#  - 0s - loss: 134822488.9975 - mae: 8042.9126
# Epoch 23/5000
#  - 0s - loss: 133931737.6529 - mae: 8005.2139
# Epoch 24/5000
#  - 0s - loss: 133134221.9399 - mae: 7967.7725
# Epoch 25/5000
#  - 0s - loss: 132418024.7817 - mae: 7922.1099
# Epoch 26/5000
#  - 0s - loss: 131820170.1048 - mae: 7887.2896
# Epoch 27/5000
#  - 0s - loss: 131226990.4896 - mae: 7851.9214
# Epoch 28/5000
#  - 0s - loss: 130693889.6855 - mae: 7819.4263
# Epoch 29/5000
#  - 0s - loss: 130211064.0570 - mae: 7793.6689
# Epoch 30/5000
#  - 0s - loss: 129765175.2916 - mae: 7771.3213
# Epoch 31/5000
#  - 0s - loss: 129340712.9018 - mae: 7743.2046
# Epoch 32/5000
#  - 0s - loss: 128961777.1074 - mae: 7726.8564
# Epoch 33/5000
#  - 0s - loss: 128595276.7511 - mae: 7705.5356
# Epoch 34/5000
#  - 0s - loss: 128341519.1573 - mae: 7686.1011
# Epoch 35/5000
#  - 0s - loss: 128000900.6209 - mae: 7673.0879
# Epoch 36/5000
#  - 0s - loss: 127700067.2651 - mae: 7657.7422
# Epoch 37/5000
#  - 0s - loss: 127402264.8183 - mae: 7648.6094
# Epoch 38/5000
#  - 0s - loss: 127168568.1547 - mae: 7632.4946
# Epoch 39/5000
#  - 0s - loss: 126965682.5323 - mae: 7607.1484
# Epoch 40/5000
#  - 0s - loss: 126781055.9165 - mae: 7594.8394
# Epoch 41/5000
#  - 0s - loss: 126607047.0799 - mae: 7586.3901
# Epoch 42/5000
#  - 0s - loss: 126410623.7517 - mae: 7577.0605
# Epoch 43/5000
#  - 0s - loss: 126144611.1674 - mae: 7571.5312
# Epoch 44/5000
#  - 0s - loss: 125991755.2774 - mae: 7559.1792
# Epoch 45/5000
#  - 0s - loss: 125875359.7924 - mae: 7541.4434
# Epoch 46/5000
#  - 0s - loss: 125651032.6758 - mae: 7551.6138
# Epoch 47/5000
#  - 0s - loss: 125498347.5583 - mae: 7534.8770
# Epoch 48/5000
#  - 0s - loss: 125430691.1104 - mae: 7518.6997
# Epoch 49/5000
#  - 0s - loss: 125323444.8814 - mae: 7535.6782
# Epoch 50/5000
#  - 0s - loss: 125187957.3191 - mae: 7519.1274
# Epoch 51/5000
#  - 0s - loss: 124973362.7522 - mae: 7508.5303
# Epoch 52/5000
#  - 0s - loss: 124944549.8300 - mae: 7499.3291
# Epoch 53/5000
#  - 0s - loss: 124781846.4855 - mae: 7498.3867
# Epoch 54/5000
#  - 0s - loss: 124769766.5303 - mae: 7487.1797
# Epoch 55/5000
#  - 0s - loss: 124648645.4351 - mae: 7489.0791
# Epoch 56/5000
#  - 0s - loss: 124536677.9277 - mae: 7478.6431
# Epoch 57/5000
#  - 0s - loss: 124465729.6936 - mae: 7478.1055
# Epoch 58/5000
#  - 0s - loss: 124301546.8173 - mae: 7471.6440
# Epoch 59/5000
#  - 0s - loss: 124305048.4682 - mae: 7470.3613
# Epoch 60/5000
#  - 0s - loss: 124221060.5639 - mae: 7468.1855
# Epoch 61/5000
#  - 0s - loss: 124118523.1715 - mae: 7458.6689
# Epoch 62/5000
#  - 0s - loss: 124049782.0906 - mae: 7455.9253
# Epoch 63/5000
#  - 0s - loss: 123886627.6845 - mae: 7453.2324
# Epoch 64/5000
#  - 0s - loss: 123868177.5186 - mae: 7448.0024
# Epoch 65/5000
#  - 0s - loss: 123739652.9344 - mae: 7447.6680
# Epoch 66/5000
#  - 0s - loss: 123746508.4865 - mae: 7435.3809
# Epoch 67/5000
#  - 0s - loss: 123651599.2977 - mae: 7440.7192
# Epoch 68/5000
#  - 0s - loss: 123641517.0524 - mae: 7434.2080
# Epoch 69/5000
#  - 0s - loss: 123520350.5364 - mae: 7433.5562
# Epoch 70/5000
#  - 0s - loss: 123443893.4188 - mae: 7426.3462
# Epoch 71/5000
#  - 0s - loss: 123391749.8260 - mae: 7434.2427
# Epoch 72/5000
#  - 0s - loss: 123477284.5435 - mae: 7419.0503
# Epoch 73/5000
#  - 0s - loss: 123291233.6733 - mae: 7425.0591
# Epoch 74/5000
#  - 0s - loss: 123186012.5089 - mae: 7424.6387
# Epoch 75/5000
#  - 0s - loss: 123086686.0173 - mae: 7418.3921
# Epoch 76/5000
#  - 0s - loss: 123196874.5690 - mae: 7413.6704
# Epoch 77/5000
#  - 0s - loss: 123101344.4356 - mae: 7407.1030
# Epoch 78/5000
#  - 0s - loss: 122951769.2254 - mae: 7418.5713
# Epoch 79/5000
#  - 0s - loss: 123043035.7089 - mae: 7399.6753
# Epoch 80/5000
#  - 0s - loss: 122937429.1176 - mae: 7409.9082
# Epoch 81/5000
#  - 0s - loss: 122815258.6992 - mae: 7416.8618
# Epoch 82/5000
#  - 0s - loss: 122768780.9995 - mae: 7407.5781
# Epoch 83/5000
#  - 0s - loss: 122782464.1028 - mae: 7406.2803
# Epoch 84/5000
#  - 0s - loss: 122813799.7476 - mae: 7396.4951
# Epoch 85/5000
#  - 0s - loss: 122710123.0779 - mae: 7395.9487
# Epoch 86/5000
#  - 0s - loss: 122738586.1618 - mae: 7400.4839
# Epoch 87/5000
#  - 0s - loss: 122688336.5537 - mae: 7396.0122
# Epoch 88/5000
#  - 0s - loss: 122599426.0234 - mae: 7392.3970
# Epoch 89/5000
#  - 0s - loss: 122559040.6066 - mae: 7387.1069
# Epoch 90/5000
#  - 0s - loss: 122545442.9069 - mae: 7379.2080
# Epoch 91/5000
#  - 0s - loss: 122462065.3924 - mae: 7389.7866
# Epoch 92/5000
#  - 0s - loss: 122416970.4753 - mae: 7395.1294
# Epoch 93/5000
#  - 0s - loss: 122353131.2875 - mae: 7385.9526
# Epoch 94/5000
#  - 0s - loss: 122411445.5573 - mae: 7376.3149
# Epoch 95/5000
#  - 0s - loss: 122380368.0611 - mae: 7378.5879
# Epoch 96/5000
#  - 0s - loss: 122271934.4651 - mae: 7389.2280
# Epoch 97/5000
#  - 0s - loss: 122294371.1593 - mae: 7375.1519
# Epoch 98/5000
#  - 0s - loss: 122201880.1628 - mae: 7376.4888
# Epoch 99/5000
#  - 0s - loss: 122227998.7868 - mae: 7371.5981
# Epoch 100/5000
#  - 0s - loss: 122078664.8712 - mae: 7379.8828
# Epoch 101/5000
#  - 0s - loss: 122124474.2718 - mae: 7373.2007
# Epoch 102/5000
#  - 0s - loss: 122142058.1781 - mae: 7364.4414
# Epoch 103/5000
#  - 0s - loss: 121991294.5262 - mae: 7370.3936
# Epoch 104/5000
#  - 0s - loss: 122019048.2239 - mae: 7364.3350
# Epoch 105/5000
#  - 0s - loss: 122011909.6346 - mae: 7351.9751
# Epoch 106/5000
#  - 0s - loss: 121945775.5929 - mae: 7364.8755
# Epoch 107/5000
#  - 0s - loss: 121941773.2824 - mae: 7360.4980
# Epoch 108/5000
#  - 0s - loss: 121894132.1669 - mae: 7362.6011
# Epoch 109/5000
#  - 0s - loss: 121931756.9506 - mae: 7354.4282
# Epoch 110/5000
#  - 0s - loss: 121865785.3069 - mae: 7357.4839
# Epoch 111/5000
#  - 0s - loss: 121781951.9186 - mae: 7364.2695
# Epoch 112/5000
#  - 0s - loss: 121796588.2219 - mae: 7353.2959
# Epoch 113/5000
#  - 0s - loss: 121791598.2595 - mae: 7342.3286
# Epoch 114/5000
#  - 0s - loss: 121732922.6911 - mae: 7362.6147
# Epoch 115/5000
#  - 0s - loss: 121666647.3323 - mae: 7351.6304
# Epoch 116/5000
#  - 0s - loss: 121673408.6392 - mae: 7350.3721
# Epoch 117/5000
#  - 0s - loss: 121644535.2753 - mae: 7349.8350
# Epoch 118/5000
#  - 0s - loss: 121561108.1975 - mae: 7356.0474
# Epoch 119/5000
#  - 0s - loss: 121543821.2478 - mae: 7346.6143
# Epoch 120/5000
#  - 0s - loss: 121507801.0422 - mae: 7351.9644
# Epoch 121/5000
#  - 0s - loss: 121533986.5893 - mae: 7335.9912
# Epoch 122/5000
#  - 0s - loss: 121475902.0560 - mae: 7344.9429
# Epoch 123/5000
#  - 0s - loss: 121486850.4183 - mae: 7337.8794
# Epoch 124/5000
#  - 0s - loss: 121465760.7573 - mae: 7334.6309
# Epoch 125/5000
#  - 0s - loss: 121450507.7537 - mae: 7340.2642
# Epoch 126/5000
#  - 0s - loss: 121331771.2733 - mae: 7336.1611
# Epoch 127/5000
#  - 0s - loss: 121425433.5919 - mae: 7338.9814
# Epoch 128/5000
#  - 0s - loss: 121343675.4687 - mae: 7328.3540
# Epoch 129/5000
#  - 0s - loss: 121296559.4809 - mae: 7333.5889
# Epoch 130/5000
#  - 0s - loss: 121265632.5252 - mae: 7332.6328
# Epoch 131/5000
#  - 0s - loss: 121240603.3242 - mae: 7334.6187
# Epoch 132/5000
#  - 0s - loss: 121260242.1211 - mae: 7326.2036
# Epoch 133/5000
#  - 0s - loss: 121246087.9267 - mae: 7323.5977
# Epoch 134/5000
#  - 0s - loss: 121181314.4550 - mae: 7328.5894
# Epoch 135/5000
#  - 0s - loss: 121175084.5211 - mae: 7329.5894
# Epoch 136/5000
#  - 0s - loss: 121123036.6453 - mae: 7327.6875
# Epoch 137/5000
#  - 0s - loss: 121184166.6178 - mae: 7315.0342
# Epoch 138/5000
#  - 0s - loss: 121110414.0580 - mae: 7321.4302
# Epoch 139/5000
#  - 0s - loss: 121091215.3567 - mae: 7334.0850
# Epoch 140/5000
#  - 0s - loss: 121045961.9298 - mae: 7315.1138
# Epoch 141/5000
#  - 0s - loss: 120996559.6438 - mae: 7325.8022
# Epoch 142/5000
#  - 0s - loss: 120946784.2219 - mae: 7323.6421
# Epoch 143/5000
#  - 0s - loss: 120959706.0417 - mae: 7321.7070
# Epoch 144/5000
#  - 0s - loss: 121011387.2936 - mae: 7310.9409
# Epoch 145/5000
#  - 0s - loss: 120923866.8987 - mae: 7316.5977
# Epoch 146/5000
#  - 0s - loss: 120887475.4565 - mae: 7321.5513
# Epoch 147/5000
#  - 0s - loss: 120868681.2295 - mae: 7309.3242
# Epoch 148/5000
#  - 0s - loss: 120874209.9094 - mae: 7305.6235
# Epoch 149/5000
#  - 0s - loss: 120734267.2529 - mae: 7317.1553
# Epoch 150/5000
#  - 0s - loss: 120757861.3659 - mae: 7313.9224
# Epoch 151/5000
#  - 0s - loss: 120826213.3679 - mae: 7309.3633
# Epoch 152/5000
#  - 0s - loss: 120725658.9476 - mae: 7312.0825
# Epoch 153/5000
#  - 0s - loss: 120702107.7313 - mae: 7320.0522
# Epoch 154/5000
#  - 0s - loss: 120684424.8957 - mae: 7314.0703
# Epoch 155/5000
#  - 0s - loss: 120659850.7684 - mae: 7306.5684
# Epoch 156/5000
#  - 0s - loss: 120602349.5776 - mae: 7301.1323
# Epoch 157/5000
#  - 0s - loss: 120622326.5995 - mae: 7311.7441
# Epoch 158/5000
#  - 0s - loss: 120620402.8499 - mae: 7294.6138
# Epoch 159/5000
#  - 0s - loss: 120548064.1384 - mae: 7308.9946
# Epoch 160/5000
#  - 0s - loss: 120625802.3471 - mae: 7290.9043
# Epoch 161/5000
#  - 0s - loss: 120620463.2733 - mae: 7297.8330
# Epoch 162/5000
#  - 0s - loss: 120534289.9868 - mae: 7292.4189
# Epoch 163/5000
#  - 0s - loss: 120376039.6723 - mae: 7301.7930
# Epoch 164/5000
#  - 0s - loss: 120559328.8102 - mae: 7287.5015
# Epoch 165/5000
#  - 0s - loss: 120510112.9934 - mae: 7296.7632
# Epoch 166/5000
#  - 0s - loss: 120491809.9216 - mae: 7299.0283
# Epoch 167/5000
#  - 0s - loss: 120455875.9613 - mae: 7294.1367
# Epoch 168/5000
#  - 0s - loss: 120407736.7817 - mae: 7294.4805
# Epoch 169/5000
#  - 0s - loss: 120376212.5109 - mae: 7296.5405
# Epoch 170/5000
#  - 0s - loss: 120387304.1486 - mae: 7296.1982
# Epoch 171/5000
#  - 0s - loss: 120379666.6687 - mae: 7287.4917
# Epoch 172/5000
#  - 0s - loss: 120337551.6132 - mae: 7281.5771
# Epoch 173/5000
#  - 0s - loss: 120340923.7578 - mae: 7284.5044
# Epoch 174/5000
#  - 0s - loss: 120249464.6473 - mae: 7286.1567
# Epoch 175/5000
#  - 0s - loss: 120291191.1165 - mae: 7287.4067
# Epoch 176/5000
#  - 0s - loss: 120288423.8697 - mae: 7276.9165
# Epoch 177/5000
#  - 0s - loss: 120236656.2524 - mae: 7284.7100
# Epoch 178/5000
#  - 0s - loss: 120233521.2173 - mae: 7283.4209
# Epoch 179/5000
#  - 0s - loss: 120240571.9858 - mae: 7279.6919
# Epoch 180/5000
#  - 0s - loss: 120179035.3506 - mae: 7281.2773
# Epoch 181/5000
#  - 0s - loss: 120088088.5537 - mae: 7281.3438
# Epoch 182/5000
#  - 0s - loss: 120149215.2142 - mae: 7280.1323
# Epoch 183/5000
#  - 0s - loss: 120082970.8784 - mae: 7277.6118
# Epoch 184/5000
#  - 0s - loss: 120076843.1410 - mae: 7281.1455
# Epoch 185/5000
#  - 0s - loss: 120072235.3588 - mae: 7280.7471
# Epoch 186/5000
#  - 0s - loss: 120025335.2509 - mae: 7273.4658
# Epoch 187/5000
#  - 0s - loss: 120083279.3323 - mae: 7274.6519
# Epoch 188/5000
#  - 0s - loss: 120087930.5567 - mae: 7269.5088
# Epoch 189/5000
#  - 0s - loss: 120089307.7089 - mae: 7271.7285
# Epoch 190/5000
#  - 0s - loss: 120061079.5003 - mae: 7271.2427
# Epoch 191/5000
#  - 0s - loss: 119968920.1466 - mae: 7269.8325
# Epoch 192/5000
#  - 0s - loss: 119998482.1822 - mae: 7266.6699
# Epoch 193/5000
#  - 0s - loss: 119960871.6906 - mae: 7261.7339
# Epoch 194/5000
#  - 0s - loss: 119889421.8504 - mae: 7278.7852
# Epoch 195/5000
#  - 0s - loss: 119874813.6631 - mae: 7273.0718
# Epoch 196/5000
#  - 0s - loss: 119858381.3476 - mae: 7267.3481
# Epoch 197/5000
#  - 0s - loss: 119868655.9715 - mae: 7271.3628
# Epoch 198/5000
#  - 0s - loss: 119776374.5791 - mae: 7276.9839
# Epoch 199/5000
#  - 0s - loss: 119797272.2687 - mae: 7262.0908
# Epoch 200/5000
#  - 0s - loss: 119760215.1165 - mae: 7265.2065
# Epoch 201/5000
#  - 0s - loss: 119763375.6458 - mae: 7265.7085
# Epoch 202/5000
#  - 0s - loss: 119770009.9257 - mae: 7261.1372
# Epoch 203/5000
#  - 0s - loss: 119707680.6758 - mae: 7252.6108
# Epoch 204/5000
#  - 0s - loss: 119677938.3328 - mae: 7264.3604
# Epoch 205/5000
#  - 0s - loss: 119699895.3099 - mae: 7261.4624
# Epoch 206/5000
#  - 0s - loss: 119720391.4992 - mae: 7256.5840
# Epoch 207/5000
#  - 0s - loss: 119630848.2931 - mae: 7251.6621
# Epoch 208/5000
#  - 0s - loss: 119607336.9608 - mae: 7251.8623
# Epoch 209/5000
#  - 0s - loss: 119581510.7176 - mae: 7257.1538
# Epoch 210/5000
#  - 0s - loss: 119604432.8244 - mae: 7247.8647
# Epoch 211/5000
#  - 0s - loss: 119559552.8875 - mae: 7257.6440
# Epoch 212/5000
#  - 0s - loss: 119569056.7084 - mae: 7248.7754
# Epoch 213/5000
#  - 0s - loss: 119537111.9837 - mae: 7246.9863
# Epoch 214/5000
#  - 0s - loss: 119524343.5664 - mae: 7242.7539
# Epoch 215/5000
#  - 0s - loss: 119579198.5038 - mae: 7240.1343
# Epoch 216/5000
#  - 0s - loss: 119505115.2774 - mae: 7242.6509
# Epoch 217/5000
#  - 0s - loss: 119471208.7206 - mae: 7247.4541
# Epoch 218/5000
#  - 0s - loss: 119425459.1145 - mae: 7247.1152
# Epoch 219/5000
#  - 0s - loss: 119444765.7445 - mae: 7242.0366
# Epoch 220/5000
#  - 0s - loss: 119341712.3094 - mae: 7247.6396
# Epoch 221/5000
#  - 0s - loss: 119410745.5430 - mae: 7237.5176
# Epoch 222/5000
#  - 0s - loss: 119400552.0936 - mae: 7239.1138
# Epoch 223/5000
#  - 0s - loss: 119312923.9980 - mae: 7245.0679
# Epoch 224/5000
#  - 0s - loss: 119302671.2142 - mae: 7241.0962
# Epoch 225/5000
#  - 0s - loss: 119324902.1313 - mae: 7234.2075
# Epoch 226/5000
#  - 0s - loss: 119240857.2244 - mae: 7228.9326
# Epoch 227/5000
#  - 0s - loss: 119283240.0855 - mae: 7230.7788
# Epoch 228/5000
#  - 0s - loss: 119199450.5282 - mae: 7233.4136
# Epoch 229/5000
#  - 0s - loss: 119213702.8926 - mae: 7229.9082
# Epoch 230/5000
#  - 0s - loss: 119128380.5313 - mae: 7231.0371
# Epoch 231/5000
#  - 0s - loss: 119220493.8422 - mae: 7229.1621
# Epoch 232/5000
#  - 0s - loss: 119158699.1206 - mae: 7228.8257
# Epoch 233/5000
#  - 0s - loss: 119100834.1170 - mae: 7227.9175
# Epoch 234/5000
#  - 0s - loss: 119222936.9242 - mae: 7213.1709
# Epoch 235/5000
#  - 0s - loss: 119141941.9440 - mae: 7219.3140
# Epoch 236/5000
#  - 0s - loss: 119068806.9232 - mae: 7222.7007
# Epoch 237/5000
#  - 0s - loss: 119028394.4346 - mae: 7227.6553
# Epoch 238/5000
#  - 0s - loss: 119050124.5679 - mae: 7228.6846
# Epoch 239/5000
#  - 0s - loss: 119017548.7145 - mae: 7216.1191
# Epoch 240/5000
#  - 0s - loss: 118972973.1338 - mae: 7221.3750
# Epoch 241/5000
#  - 0s - loss: 118955974.3308 - mae: 7226.0791
# Epoch 242/5000
#  - 0s - loss: 118917562.6585 - mae: 7213.9575
# Epoch 243/5000
#  - 0s - loss: 118842219.0738 - mae: 7223.3047
# Epoch 244/5000
#  - 0s - loss: 118885714.5730 - mae: 7216.6050
# Epoch 245/5000
#  - 0s - loss: 118881497.4127 - mae: 7211.8232
# Epoch 246/5000
#  - 0s - loss: 118840933.9359 - mae: 7217.8345
# Epoch 247/5000
#  - 0s - loss: 118797785.3761 - mae: 7208.3789
# Epoch 248/5000
#  - 0s - loss: 118802276.4112 - mae: 7217.5469
# Epoch 249/5000
#  - 0s - loss: 118778249.2539 - mae: 7201.2290
# Epoch 250/5000
#  - 0s - loss: 118685202.6382 - mae: 7208.4072
# Epoch 251/5000
#  - 0s - loss: 118702679.1125 - mae: 7207.6221
# Epoch 252/5000
#  - 0s - loss: 118706287.8249 - mae: 7198.0288
# Epoch 253/5000
#  - 0s - loss: 118723492.8896 - mae: 7208.7124
# Epoch 254/5000
#  - 0s - loss: 118732829.5613 - mae: 7192.4897
# Epoch 255/5000
#  - 0s - loss: 118650517.0972 - mae: 7203.6982
# Epoch 256/5000
#  - 0s - loss: 118575808.1486 - mae: 7201.2261
# Epoch 257/5000
#  - 0s - loss: 118664977.9420 - mae: 7197.7969
# Epoch 258/5000
#  - 0s - loss: 118642692.4702 - mae: 7198.2334
# Epoch 259/5000
#  - 0s - loss: 118640274.3959 - mae: 7189.7676
# Epoch 260/5000
#  - 0s - loss: 118605121.1399 - mae: 7192.9619
# Epoch 261/5000
#  - 0s - loss: 118588637.7506 - mae: 7183.6758
# Epoch 262/5000
#  - 0s - loss: 118484649.5186 - mae: 7200.9849
# Epoch 263/5000
#  - 0s - loss: 118434436.1384 - mae: 7192.2588
# Epoch 264/5000
#  - 0s - loss: 118522933.7282 - mae: 7176.0669
# Epoch 265/5000
#  - 0s - loss: 118451096.0774 - mae: 7174.3701
# Epoch 266/5000
#  - 0s - loss: 118355565.0830 - mae: 7190.8413
# Epoch 267/5000
#  - 0s - loss: 118418243.8514 - mae: 7181.5864
# Epoch 268/5000
#  - 0s - loss: 118408039.5074 - mae: 7177.9736
# Epoch 269/5000
#  - 0s - loss: 118353374.3898 - mae: 7173.4116
# Epoch 270/5000
#  - 0s - loss: 118309258.9211 - mae: 7169.2837
# Epoch 271/5000
#  - 0s - loss: 118248458.1455 - mae: 7177.8423
# Epoch 272/5000
#  - 0s - loss: 118275256.2483 - mae: 7174.3618
# Epoch 273/5000
#  - 0s - loss: 118248603.0168 - mae: 7177.8716
# Epoch 274/5000
#  - 0s - loss: 118170378.7807 - mae: 7183.6147
# Epoch 275/5000
#  - 0s - loss: 118144152.2646 - mae: 7168.7749
# Epoch 276/5000
#  - 0s - loss: 118161806.0580 - mae: 7171.1709
# Epoch 277/5000
#  - 0s - loss: 118154507.8636 - mae: 7162.9526
# Epoch 278/5000
#  - 0s - loss: 118097973.6875 - mae: 7161.7944
# Epoch 279/5000
#  - 0s - loss: 118036185.6122 - mae: 7166.8579
# Epoch 280/5000
#  - 0s - loss: 118036731.0046 - mae: 7163.7573
# Epoch 281/5000
#  - 0s - loss: 117949331.5664 - mae: 7163.0146
# Epoch 282/5000
#  - 0s - loss: 118085433.6163 - mae: 7153.0693
# Epoch 283/5000
#  - 0s - loss: 117961359.5562 - mae: 7153.2925
# Epoch 284/5000
#  - 0s - loss: 117947405.3089 - mae: 7149.7817
# Epoch 285/5000
#  - 0s - loss: 117932862.6158 - mae: 7156.6562
# Epoch 286/5000
#  - 0s - loss: 117838970.3043 - mae: 7159.9390
# Epoch 287/5000
#  - 0s - loss: 117806487.5399 - mae: 7152.8501
# Epoch 288/5000
#  - 0s - loss: 117839578.3410 - mae: 7149.1636
# Epoch 289/5000
#  - 0s - loss: 117750947.7150 - mae: 7151.1406
# Epoch 290/5000
#  - 0s - loss: 117799502.6300 - mae: 7147.6284
# Epoch 291/5000
#  - 0s - loss: 117722041.7913 - mae: 7145.4971
# Epoch 292/5000
#  - 0s - loss: 117767824.9405 - mae: 7140.8394
# Epoch 293/5000
#  - 0s - loss: 117697291.3954 - mae: 7135.6162
# Epoch 294/5000
#  - 0s - loss: 117592339.6926 - mae: 7137.1567
# Epoch 295/5000
#  - 0s - loss: 117565439.6387 - mae: 7136.5864
# Epoch 296/5000
#  - 0s - loss: 117438282.6748 - mae: 7144.0376
# Epoch 297/5000
#  - 0s - loss: 117513652.1649 - mae: 7130.9971
# Epoch 298/5000
#  - 0s - loss: 117488301.2275 - mae: 7127.9224
# Epoch 299/5000
#  - 0s - loss: 117417201.6000 - mae: 7131.2588
# Epoch 300/5000
#  - 0s - loss: 117372140.7715 - mae: 7126.0293
# Epoch 301/5000
#  - 0s - loss: 117340791.4626 - mae: 7113.8130
# Epoch 302/5000
#  - 0s - loss: 117242631.8494 - mae: 7120.7573
# Epoch 303/5000
#  - 0s - loss: 117330432.4621 - mae: 7118.6289
# Epoch 304/5000
#  - 0s - loss: 117288321.5186 - mae: 7112.9707
# Epoch 305/5000
#  - 0s - loss: 117149965.2438 - mae: 7112.7378
# Epoch 306/5000
#  - 0s - loss: 117220171.8310 - mae: 7101.5381
# Epoch 307/5000
#  - 0s - loss: 117119026.0845 - mae: 7115.7720
# Epoch 308/5000
#  - 0s - loss: 116980367.6336 - mae: 7113.6338
# Epoch 309/5000
#  - 0s - loss: 116978732.7186 - mae: 7097.7104
# Epoch 310/5000
#  - 0s - loss: 116884819.4911 - mae: 7111.8799
# Epoch 311/5000
#  - 0s - loss: 116884776.0000 - mae: 7092.8706
# Epoch 312/5000
#  - 0s - loss: 116859634.3003 - mae: 7095.9399
# Epoch 313/5000
#  - 0s - loss: 116807318.2779 - mae: 7082.6284
# Epoch 314/5000
#  - 0s - loss: 116757753.6774 - mae: 7083.8730
# Epoch 315/5000
#  - 0s - loss: 116718953.9461 - mae: 7082.0464
# Epoch 316/5000
#  - 0s - loss: 116596289.1115 - mae: 7076.0522
# Epoch 317/5000
#  - 0s - loss: 116569518.7929 - mae: 7084.3843
# Epoch 318/5000
#  - 0s - loss: 116510010.6789 - mae: 7076.9761
# Epoch 319/5000
#  - 0s - loss: 116427492.5028 - mae: 7072.0063
# Epoch 320/5000
#  - 0s - loss: 116333633.9298 - mae: 7071.7656
# Epoch 321/5000
#  - 0s - loss: 116281161.0911 - mae: 7056.1753
# Epoch 322/5000
#  - 0s - loss: 116278304.8896 - mae: 7053.1050
# Epoch 323/5000
#  - 0s - loss: 116124905.6122 - mae: 7045.7056
# Epoch 324/5000
#  - 0s - loss: 116103587.1654 - mae: 7050.4551
# Epoch 325/5000
#  - 0s - loss: 115980277.9359 - mae: 7054.5063
# Epoch 326/5000
#  - 0s - loss: 115961152.5964 - mae: 7031.4624
# Epoch 327/5000
#  - 0s - loss: 115779764.8020 - mae: 7046.1274
# Epoch 328/5000
#  - 0s - loss: 115839234.3349 - mae: 7023.6362
# Epoch 329/5000
#  - 0s - loss: 115664294.1201 - mae: 7025.8379
# Epoch 330/5000
#  - 0s - loss: 115606084.5496 - mae: 7019.7178
# Epoch 331/5000
#  - 0s - loss: 115555671.6275 - mae: 7015.6802
# Epoch 332/5000
#  - 0s - loss: 115471315.2081 - mae: 7006.3350
# Epoch 333/5000
#  - 0s - loss: 115272091.4545 - mae: 7012.8652
# Epoch 334/5000
#  - 0s - loss: 115218373.1959 - mae: 7005.0103
# Epoch 335/5000
#  - 0s - loss: 115167096.8183 - mae: 6993.7842
# Epoch 336/5000
#  - 0s - loss: 115111433.9074 - mae: 6993.2773
# Epoch 337/5000
#  - 0s - loss: 114879614.1863 - mae: 6987.3784
# Epoch 338/5000
#  - 0s - loss: 114773740.8366 - mae: 6975.8652
# Epoch 339/5000
#  - 0s - loss: 114725996.1893 - mae: 6961.0239
# Epoch 340/5000
#  - 0s - loss: 114505420.1812 - mae: 6965.9849
# Epoch 341/5000
#  - 0s - loss: 114521212.8407 - mae: 6951.7803
# Epoch 342/5000
#  - 0s - loss: 114386614.9618 - mae: 6942.3320
# Epoch 343/5000
#  - 0s - loss: 114199904.7125 - mae: 6937.2324
# Epoch 344/5000
#  - 0s - loss: 114079305.7384 - mae: 6937.6602
# Epoch 345/5000
#  - 0s - loss: 113866296.2565 - mae: 6927.4214
# Epoch 346/5000
#  - 0s - loss: 113747973.5776 - mae: 6909.7158
# Epoch 347/5000
#  - 0s - loss: 113476252.3644 - mae: 6915.2183
# Epoch 348/5000
#  - 0s - loss: 113403283.4076 - mae: 6900.9058
# Epoch 349/5000
#  - 0s - loss: 113177565.6244 - mae: 6889.1021
# Epoch 350/5000
#  - 0s - loss: 113050623.0901 - mae: 6884.0933
# Epoch 351/5000
#  - 0s - loss: 112833920.6575 - mae: 6873.2563
# Epoch 352/5000
#  - 0s - loss: 112670298.3186 - mae: 6854.1558
# Epoch 353/5000
#  - 0s - loss: 112448879.5318 - mae: 6840.8047
# Epoch 354/5000
#  - 0s - loss: 112221813.2824 - mae: 6840.9824
# Epoch 355/5000
#  - 0s - loss: 111947739.5746 - mae: 6832.2266
# Epoch 356/5000
#  - 0s - loss: 111772810.8702 - mae: 6817.3115
# Epoch 357/5000
#  - 0s - loss: 111509585.6305 - mae: 6807.1304
# Epoch 358/5000
#  - 0s - loss: 111300285.3903 - mae: 6785.6738
# Epoch 359/5000
#  - 0s - loss: 111012628.3929 - mae: 6781.0186
# Epoch 360/5000
#  - 0s - loss: 110686807.1613 - mae: 6768.8652
# Epoch 361/5000
#  - 0s - loss: 110294490.0845 - mae: 6758.3691
# Epoch 362/5000
#  - 0s - loss: 110208035.8270 - mae: 6730.4053
# Epoch 363/5000
#  - 0s - loss: 109831735.1328 - mae: 6716.7129
# Epoch 364/5000
#  - 0s - loss: 109519407.6743 - mae: 6700.5649
# Epoch 365/5000
#  - 0s - loss: 109200951.0270 - mae: 6685.0430
# Epoch 366/5000
#  - 0s - loss: 108795634.7766 - mae: 6672.6523
# Epoch 367/5000
#  - 0s - loss: 108448872.9466 - mae: 6656.1206
# Epoch 368/5000
#  - 0s - loss: 108125316.1445 - mae: 6635.3237
# Epoch 369/5000
#  - 0s - loss: 107784957.0728 - mae: 6601.3184
# Epoch 370/5000
#  - 0s - loss: 107440694.7257 - mae: 6590.6509
# Epoch 371/5000
#  - 0s - loss: 106944524.2952 - mae: 6572.1191
# Epoch 372/5000
#  - 0s - loss: 106547452.4295 - mae: 6562.6309
# Epoch 373/5000
#  - 0s - loss: 106108716.3338 - mae: 6540.5479
# Epoch 374/5000
#  - 0s - loss: 105686067.9084 - mae: 6510.4116
# Epoch 375/5000
#  - 0s - loss: 105238254.5751 - mae: 6489.1045
# Epoch 376/5000
#  - 0s - loss: 104787120.3705 - mae: 6467.4141
# Epoch 377/5000
#  - 0s - loss: 104324436.8916 - mae: 6443.9180
# Epoch 378/5000
#  - 0s - loss: 103805705.7873 - mae: 6420.5488
# Epoch 379/5000
#  - 0s - loss: 103347153.3354 - mae: 6398.8369
# Epoch 380/5000
#  - 0s - loss: 102821781.4270 - mae: 6367.4683
# Epoch 381/5000
#  - 0s - loss: 102341383.9756 - mae: 6351.4922
# Epoch 382/5000
#  - 0s - loss: 101914174.7583 - mae: 6321.1782
# Epoch 383/5000
#  - 0s - loss: 101317328.5293 - mae: 6298.3149
# Epoch 384/5000
#  - 0s - loss: 100894133.7303 - mae: 6273.9531
# Epoch 385/5000
#  - 0s - loss: 100431207.6987 - mae: 6256.4614
# Epoch 386/5000
#  - 0s - loss: 99856184.0651 - mae: 6227.4258
# Epoch 387/5000
#  - 0s - loss: 99432414.3023 - mae: 6191.5698
# Epoch 388/5000
#  - 0s - loss: 98858737.2275 - mae: 6173.2661
# Epoch 389/5000
#  - 0s - loss: 98315937.9746 - mae: 6147.8027
# Epoch 390/5000
#  - 0s - loss: 97708621.1094 - mae: 6131.4526
# Epoch 391/5000
#  - 0s - loss: 97258497.3476 - mae: 6102.1060
# Epoch 392/5000
#  - 0s - loss: 96646859.2163 - mae: 6081.4351
# Epoch 393/5000
#  - 0s - loss: 96147580.2361 - mae: 6052.2158
# Epoch 394/5000
#  - 0s - loss: 95587690.5242 - mae: 6027.8018
# Epoch 395/5000
#  - 0s - loss: 95095840.8672 - mae: 6003.5781
# Epoch 396/5000
#  - 0s - loss: 94552071.4015 - mae: 5978.9717
# Epoch 397/5000
#  - 0s - loss: 93974434.0601 - mae: 5952.2163
# Epoch 398/5000
#  - 0s - loss: 93639612.9415 - mae: 5928.7109
# Epoch 399/5000
#  - 0s - loss: 93076900.4621 - mae: 5905.1704
# Epoch 400/5000
#  - 0s - loss: 92474574.2758 - mae: 5878.2681
# Epoch 401/5000
#  - 0s - loss: 92047466.4387 - mae: 5847.4590
# Epoch 402/5000
#  - 0s - loss: 91440488.8081 - mae: 5827.8774
# Epoch 403/5000
#  - 0s - loss: 90917315.5216 - mae: 5798.6973
# Epoch 404/5000
#  - 0s - loss: 90329786.7440 - mae: 5773.1206
# Epoch 405/5000
#  - 0s - loss: 89783294.5812 - mae: 5744.0684
# Epoch 406/5000
#  - 0s - loss: 89342707.7964 - mae: 5720.2192
# Epoch 407/5000
#  - 0s - loss: 88774798.6260 - mae: 5698.5098
# Epoch 408/5000
#  - 0s - loss: 88257584.8835 - mae: 5668.3882
# Epoch 409/5000
#  - 0s - loss: 87754224.5924 - mae: 5644.8936
# Epoch 410/5000
#  - 0s - loss: 87183794.3043 - mae: 5620.0488
# Epoch 411/5000
#  - 0s - loss: 86686781.9369 - mae: 5594.3247
# Epoch 412/5000
#  - 0s - loss: 86068067.6621 - mae: 5565.5801
# Epoch 413/5000
#  - 0s - loss: 85596962.8224 - mae: 5547.3438
# Epoch 414/5000
#  - 0s - loss: 85202951.8972 - mae: 5518.5688
# Epoch 415/5000
#  - 0s - loss: 84633878.1807 - mae: 5490.4829
# Epoch 416/5000
#  - 0s - loss: 84096544.0244 - mae: 5463.1904
# Epoch 417/5000
#  - 0s - loss: 83674193.3293 - mae: 5444.2871
# Epoch 418/5000
#  - 0s - loss: 83316386.7807 - mae: 5421.2524
# Epoch 419/5000
#  - 0s - loss: 82698750.7603 - mae: 5392.8838
# Epoch 420/5000
#  - 0s - loss: 82224968.5028 - mae: 5370.7656
# Epoch 421/5000
#  - 0s - loss: 81696315.3079 - mae: 5346.3477
# Epoch 422/5000
#  - 0s - loss: 81139762.0539 - mae: 5313.9497
# Epoch 423/5000
#  - 0s - loss: 80730541.7934 - mae: 5300.3496
# Epoch 424/5000
#  - 0s - loss: 80210943.9959 - mae: 5274.2007
# Epoch 425/5000
#  - 0s - loss: 79800371.0046 - mae: 5245.7051
# Epoch 426/5000
#  - 0s - loss: 79326195.7374 - mae: 5223.8418
# Epoch 427/5000
#  - 0s - loss: 78861827.0117 - mae: 5202.8862
# Epoch 428/5000
#  - 0s - loss: 78456682.6504 - mae: 5175.8853
# Epoch 429/5000
#  - 0s - loss: 77885064.6906 - mae: 5157.3262
# Epoch 430/5000
#  - 0s - loss: 77516925.8382 - mae: 5126.9126
# Epoch 431/5000
#  - 0s - loss: 77210700.8244 - mae: 5116.5850
# Epoch 432/5000
#  - 0s - loss: 76756666.0641 - mae: 5088.7720
# Epoch 433/5000
#  - 0s - loss: 76314460.0702 - mae: 5063.2524
# Epoch 434/5000
#  - 0s - loss: 75954099.1410 - mae: 5046.5459
# Epoch 435/5000
#  - 0s - loss: 75555256.2382 - mae: 5029.3726
# Epoch 436/5000
#  - 0s - loss: 75154578.1211 - mae: 5006.9839
# Epoch 437/5000
#  - 0s - loss: 74742085.6931 - mae: 4986.4214
# Epoch 438/5000
#  - 0s - loss: 74384154.2295 - mae: 4965.1665
# Epoch 439/5000
#  - 0s - loss: 74108106.8387 - mae: 4935.0356
# Epoch 440/5000
#  - 0s - loss: 73730032.1191 - mae: 4924.2290
# Epoch 441/5000
#  - 0s - loss: 73428242.1964 - mae: 4904.1924
# Epoch 442/5000
#  - 0s - loss: 73080175.7659 - mae: 4882.7729
# Epoch 443/5000
#  - 0s - loss: 72673810.2331 - mae: 4866.3203
# Epoch 444/5000
#  - 0s - loss: 72389650.4407 - mae: 4857.4736
# Epoch 445/5000
#  - 0s - loss: 72085820.4397 - mae: 4831.2881
# Epoch 446/5000
#  - 0s - loss: 71861480.8122 - mae: 4821.3740
# Epoch 447/5000
#  - 0s - loss: 71494978.6117 - mae: 4797.4380
# Epoch 448/5000
#  - 0s - loss: 71238493.7038 - mae: 4787.5229
# Epoch 449/5000
#  - 0s - loss: 70967316.3644 - mae: 4766.9326
# Epoch 450/5000
#  - 0s - loss: 70756955.2804 - mae: 4763.9565
# Epoch 451/5000
#  - 0s - loss: 70321569.9562 - mae: 4731.9541
# Epoch 452/5000
#  - 0s - loss: 70102002.7440 - mae: 4720.8687
# Epoch 453/5000
#  - 0s - loss: 69769065.4137 - mae: 4722.2036
# Epoch 454/5000
#  - 0s - loss: 69647030.3980 - mae: 4692.1880
# Epoch 455/5000
#  - 0s - loss: 69326191.3140 - mae: 4676.9717
# Epoch 456/5000
#  - 0s - loss: 69087922.6748 - mae: 4660.4463
# Epoch 457/5000
#  - 0s - loss: 68836376.4397 - mae: 4645.1943
# Epoch 458/5000
#  - 0s - loss: 68680493.7201 - mae: 4643.5142
# Epoch 459/5000
#  - 0s - loss: 68400487.1145 - mae: 4614.4272
# Epoch 460/5000
#  - 0s - loss: 68103429.0321 - mae: 4602.4873
# Epoch 461/5000
#  - 0s - loss: 67896680.8061 - mae: 4585.7329
# Epoch 462/5000
#  - 0s - loss: 67691373.2723 - mae: 4582.2427
# Epoch 463/5000
#  - 0s - loss: 67299891.2092 - mae: 4561.4097
# Epoch 464/5000
#  - 0s - loss: 67304195.1552 - mae: 4562.8687
# Epoch 465/5000
#  - 0s - loss: 67035230.9802 - mae: 4530.1123
# Epoch 466/5000
#  - 0s - loss: 66892266.6707 - mae: 4520.0239
# Epoch 467/5000
#  - 0s - loss: 66541956.5313 - mae: 4509.8950
# Epoch 468/5000
#  - 0s - loss: 66308933.8667 - mae: 4488.5469
# Epoch 469/5000
#  - 0s - loss: 66232103.2494 - mae: 4487.1924
# Epoch 470/5000
#  - 0s - loss: 66010090.1089 - mae: 4469.2920
# Epoch 471/5000
#  - 0s - loss: 65725583.1186 - mae: 4456.1694
# Epoch 472/5000
#  - 0s - loss: 65565351.1725 - mae: 4443.4312
# Epoch 473/5000
#  - 0s - loss: 65404087.0768 - mae: 4428.9971
# Epoch 474/5000
#  - 0s - loss: 65173571.9827 - mae: 4413.9858
# Epoch 475/5000
#  - 0s - loss: 64973786.4326 - mae: 4397.1455
# Epoch 476/5000
#  - 0s - loss: 64858104.8448 - mae: 4379.8262
# Epoch 477/5000
#  - 0s - loss: 64714085.6468 - mae: 4385.3706
# Epoch 478/5000
#  - 0s - loss: 64456453.7802 - mae: 4374.5234
# Epoch 479/5000
#  - 0s - loss: 64257297.6804 - mae: 4339.7871
# Epoch 480/5000
#  - 0s - loss: 64246229.2377 - mae: 4341.8540
# Epoch 481/5000
#  - 0s - loss: 64091592.9537 - mae: 4329.2251
# Epoch 482/5000
#  - 0s - loss: 63846215.4117 - mae: 4317.8442
# Epoch 483/5000
#  - 0s - loss: 63733263.1349 - mae: 4294.4907
# Epoch 484/5000
#  - 0s - loss: 63528673.2244 - mae: 4280.9937
# Epoch 485/5000
#  - 0s - loss: 63375492.8305 - mae: 4279.0234
# Epoch 486/5000
#  - 0s - loss: 63253043.8209 - mae: 4255.6074
# Epoch 487/5000
#  - 0s - loss: 63046647.3832 - mae: 4247.8467
# Epoch 488/5000
#  - 0s - loss: 62909846.0906 - mae: 4226.2803
# Epoch 489/5000
#  - 0s - loss: 62728186.8865 - mae: 4225.5332
# Epoch 490/5000
#  - 0s - loss: 62638356.8529 - mae: 4200.5605
# Epoch 491/5000
#  - 0s - loss: 62356332.6351 - mae: 4181.4873
# Epoch 492/5000
#  - 0s - loss: 62332268.8570 - mae: 4187.3198
# Epoch 493/5000
#  - 0s - loss: 62138140.0539 - mae: 4178.1226
# Epoch 494/5000
#  - 0s - loss: 62039753.9145 - mae: 4159.5352
# Epoch 495/5000
#  - 0s - loss: 61816172.2117 - mae: 4147.4272
# Epoch 496/5000
#  - 0s - loss: 61645565.0962 - mae: 4138.7676
# Epoch 497/5000
#  - 0s - loss: 61528226.4723 - mae: 4111.8081
# Epoch 498/5000
#  - 0s - loss: 61325657.0483 - mae: 4107.4434
# Epoch 499/5000
#  - 0s - loss: 61316902.5913 - mae: 4083.7642
# Epoch 500/5000
#  - 0s - loss: 61073594.2494 - mae: 4096.2324
# Epoch 501/5000
#  - 0s - loss: 60981638.9300 - mae: 4088.8066
# Epoch 502/5000
#  - 0s - loss: 60729420.5455 - mae: 4036.0566
# Epoch 503/5000
#  - 0s - loss: 60678813.0361 - mae: 4066.8057
# Epoch 504/5000
#  - 0s - loss: 60536318.9924 - mae: 4043.3196
# Epoch 505/5000
#  - 0s - loss: 60428383.7150 - mae: 4032.4692
# Epoch 506/5000
#  - 0s - loss: 60194196.7104 - mae: 4029.3806
# Epoch 507/5000
#  - 0s - loss: 60101915.5277 - mae: 4003.1992
# Epoch 508/5000
#  - 0s - loss: 60062774.9130 - mae: 4014.0952
# Epoch 509/5000
#  - 0s - loss: 59780068.1486 - mae: 4004.2156
# Epoch 510/5000
#  - 0s - loss: 59780603.2061 - mae: 3970.6709
# Epoch 511/5000
#  - 0s - loss: 59702587.1868 - mae: 3990.5852
# Epoch 512/5000
#  - 0s - loss: 59508790.8000 - mae: 3963.1555
# Epoch 513/5000
#  - 0s - loss: 59483041.7425 - mae: 3968.6494
# Epoch 514/5000
#  - 0s - loss: 59392523.5542 - mae: 3965.2603
# Epoch 515/5000
#  - 0s - loss: 59359677.0193 - mae: 3959.9895
# Epoch 516/5000
#  - 0s - loss: 59223175.9298 - mae: 3941.0996
# Epoch 517/5000
#  - 0s - loss: 59196422.1835 - mae: 3925.9475
# Epoch 518/5000
#  - 0s - loss: 58935662.6982 - mae: 3934.2888
# Epoch 519/5000
#  - 0s - loss: 58816221.1262 - mae: 3904.4375
# Epoch 520/5000
#  - 0s - loss: 58852063.3038 - mae: 3912.6294
# Epoch 521/5000
#  - 0s - loss: 58641499.2224 - mae: 3892.0042
# Epoch 522/5000
#  - 0s - loss: 58701110.1646 - mae: 3914.4751
# Epoch 523/5000
#  - 0s - loss: 58590620.0987 - mae: 3903.5603
# Epoch 524/5000
#  - 0s - loss: 58534054.1466 - mae: 3884.3948
# Epoch 525/5000
#  - 0s - loss: 58419399.3150 - mae: 3879.3132
# Epoch 526/5000
#  - 0s - loss: 58358698.1211 - mae: 3877.4092
# Epoch 527/5000
#  - 0s - loss: 58193023.0962 - mae: 3854.8110
# Epoch 528/5000
#  - 0s - loss: 58216455.7893 - mae: 3872.9607
# Epoch 529/5000
#  - 0s - loss: 58127281.9033 - mae: 3857.1841
# Epoch 530/5000
#  - 0s - loss: 58030677.2285 - mae: 3864.0989
# Epoch 531/5000
#  - 0s - loss: 57816192.0560 - mae: 3854.4863
# Epoch 532/5000
#  - 0s - loss: 57638071.1260 - mae: 3835.6628
# Epoch 533/5000
#  - 0s - loss: 57797112.5232 - mae: 3841.2229
# Epoch 534/5000
#  - 0s - loss: 57765328.9242 - mae: 3824.6968
# Epoch 535/5000
#  - 0s - loss: 57713666.2819 - mae: 3830.9731
# Epoch 536/5000
#  - 0s - loss: 57610867.9471 - mae: 3820.7300
# Epoch 537/5000
#  - 0s - loss: 57573901.1053 - mae: 3812.8452
# Epoch 538/5000
#  - 0s - loss: 57425655.7455 - mae: 3793.8083
# Epoch 539/5000
#  - 0s - loss: 57435994.5461 - mae: 3830.9805
# Epoch 540/5000
#  - 0s - loss: 57301380.2524 - mae: 3796.6357
# Epoch 541/5000
#  - 0s - loss: 57191499.4758 - mae: 3792.9612
# Epoch 542/5000
#  - 0s - loss: 57151295.6377 - mae: 3774.8789
# Epoch 543/5000
#  - 0s - loss: 57048755.4972 - mae: 3795.1006
# Epoch 544/5000
#  - 0s - loss: 56988146.5913 - mae: 3775.6748
# Epoch 545/5000
#  - 0s - loss: 56946965.2804 - mae: 3784.4077
# Epoch 546/5000
#  - 0s - loss: 56910112.4733 - mae: 3785.6270
# Epoch 547/5000
#  - 0s - loss: 56833631.4402 - mae: 3751.2610
# Epoch 548/5000
#  - 0s - loss: 56791808.1944 - mae: 3767.7107
# Epoch 549/5000
#  - 0s - loss: 56724662.8967 - mae: 3753.1921
# Epoch 550/5000
#  - 0s - loss: 56680120.1170 - mae: 3768.2512
# Epoch 551/5000
#  - 0s - loss: 56465928.4224 - mae: 3745.8967
# Epoch 552/5000
#  - 0s - loss: 56607072.7735 - mae: 3734.3752
# Epoch 553/5000
#  - 0s - loss: 56459407.2509 - mae: 3736.1611
# Epoch 554/5000
#  - 0s - loss: 56339569.6611 - mae: 3731.0957
# Epoch 555/5000
#  - 0s - loss: 56356602.4326 - mae: 3744.3508
# Epoch 556/5000
#  - 0s - loss: 56303701.3221 - mae: 3730.4016
# Epoch 557/5000
#  - 0s - loss: 56277439.6774 - mae: 3725.1309
# Epoch 558/5000
#  - 0s - loss: 56176997.9155 - mae: 3716.8005
# Epoch 559/5000
#  - 0s - loss: 56147235.0860 - mae: 3720.5430
# Epoch 560/5000
#  - 0s - loss: 56015466.5995 - mae: 3703.5474
# Epoch 561/5000
#  - 0s - loss: 56102902.6153 - mae: 3704.2292
# Epoch 562/5000
#  - 0s - loss: 55953801.6626 - mae: 3695.7673
# Epoch 563/5000
#  - 0s - loss: 55998442.2636 - mae: 3699.5735
# Epoch 564/5000
#  - 0s - loss: 55904032.7756 - mae: 3698.7161
# Epoch 565/5000
#  - 0s - loss: 55804199.0651 - mae: 3684.2012
# Epoch 566/5000
#  - 0s - loss: 55787683.8336 - mae: 3704.2129
# Epoch 567/5000
#  - 0s - loss: 55765598.8310 - mae: 3672.5820
# Epoch 568/5000
#  - 0s - loss: 55703264.7613 - mae: 3667.1523
# Epoch 569/5000
#  - 0s - loss: 55535181.3924 - mae: 3668.2568
# Epoch 570/5000
#  - 0s - loss: 55567594.6763 - mae: 3670.4976
# Epoch 571/5000
#  - 0s - loss: 55441107.9003 - mae: 3660.3738
# Epoch 572/5000
#  - 0s - loss: 55428290.2397 - mae: 3662.2576
# Epoch 573/5000
#  - 0s - loss: 55545463.0626 - mae: 3663.0547
# Epoch 574/5000
#  - 0s - loss: 55398263.7934 - mae: 3646.8467
# Epoch 575/5000
#  - 0s - loss: 55302176.1066 - mae: 3655.4871
# Epoch 576/5000
#  - 0s - loss: 55164743.7781 - mae: 3639.3474
# Epoch 577/5000
#  - 0s - loss: 55192938.2936 - mae: 3645.6079
# Epoch 578/5000
#  - 0s - loss: 55289746.8580 - mae: 3641.0254
# Epoch 579/5000
#  - 0s - loss: 55100822.0000 - mae: 3628.2820
# Epoch 580/5000
#  - 0s - loss: 55109678.1038 - mae: 3633.4897
# Epoch 581/5000
#  - 0s - loss: 55040652.4967 - mae: 3632.3525
# Epoch 582/5000
#  - 0s - loss: 55031206.9646 - mae: 3629.0122
# Epoch 583/5000
#  - 0s - loss: 54931031.3751 - mae: 3603.0388
# Epoch 584/5000
#  - 0s - loss: 54842634.2168 - mae: 3628.7859
# Epoch 585/5000
#  - 0s - loss: 54869506.5975 - mae: 3607.1035
# Epoch 586/5000
#  - 0s - loss: 54819939.8433 - mae: 3617.4656
# Epoch 587/5000
#  - 0s - loss: 54623375.3089 - mae: 3598.5920
# Epoch 588/5000
#  - 0s - loss: 54560601.0748 - mae: 3602.7173
# Epoch 589/5000
#  - 0s - loss: 54523745.5033 - mae: 3589.3767
# Epoch 590/5000
#  - 0s - loss: 54660977.9461 - mae: 3596.3115
# Epoch 591/5000
#  - 0s - loss: 54580436.1364 - mae: 3600.6472
# Epoch 592/5000
#  - 0s - loss: 54444042.1903 - mae: 3588.2400
# Epoch 593/5000
#  - 0s - loss: 54375081.4952 - mae: 3571.4692
# Epoch 594/5000
#  - 0s - loss: 54481248.7354 - mae: 3581.1328
# Epoch 595/5000
#  - 0s - loss: 54339929.8494 - mae: 3565.4363
# Epoch 596/5000
#  - 0s - loss: 54384011.0483 - mae: 3590.1169
# Epoch 597/5000
#  - 0s - loss: 54245065.4221 - mae: 3567.4531
# Epoch 598/5000
#  - 0s - loss: 54187298.9751 - mae: 3564.0708
# Epoch 599/5000
#  - 0s - loss: 54158028.5802 - mae: 3582.3413
# Epoch 600/5000
#  - 0s - loss: 54248421.6537 - mae: 3544.5251
# Epoch 601/5000
#  - 0s - loss: 54162675.8280 - mae: 3565.1001
# Epoch 602/5000
#  - 0s - loss: 54058501.2234 - mae: 3555.3901
# Epoch 603/5000
#  - 0s - loss: 54101780.2443 - mae: 3547.6167
# Epoch 604/5000
#  - 0s - loss: 54007141.2982 - mae: 3542.5205
# Epoch 605/5000
#  - 0s - loss: 53985616.2585 - mae: 3544.0520
# Epoch 606/5000
#  - 0s - loss: 53857468.0875 - mae: 3531.8376
# Epoch 607/5000
#  - 0s - loss: 53860202.3552 - mae: 3536.1694
# Epoch 608/5000
#  - 0s - loss: 53945715.8056 - mae: 3544.3518
# Epoch 609/5000
#  - 0s - loss: 53788838.4153 - mae: 3526.4138
# Epoch 610/5000
#  - 0s - loss: 53800400.3842 - mae: 3524.1050
# Epoch 611/5000
#  - 0s - loss: 53712214.6483 - mae: 3518.4458
# Epoch 612/5000
#  - 0s - loss: 53628137.1746 - mae: 3517.8049
# Epoch 613/5000
#  - 0s - loss: 53696194.8053 - mae: 3516.1582
# Epoch 614/5000
#  - 0s - loss: 53765621.8621 - mae: 3514.2363
# Epoch 615/5000
#  - 0s - loss: 53564366.5232 - mae: 3512.9343
# Epoch 616/5000
#  - 0s - loss: 53595034.4712 - mae: 3517.9480
# Epoch 617/5000
#  - 0s - loss: 53625446.2738 - mae: 3492.6223
# Epoch 618/5000
#  - 0s - loss: 53526294.1522 - mae: 3492.5996
# Epoch 619/5000
#  - 0s - loss: 53530091.1695 - mae: 3490.5037
# Epoch 620/5000
#  - 0s - loss: 53569012.4081 - mae: 3501.2827
# Epoch 621/5000
#  - 0s - loss: 53356512.3359 - mae: 3483.5464
# Epoch 622/5000
#  - 0s - loss: 53309219.2967 - mae: 3489.6157
# Epoch 623/5000
#  - 0s - loss: 53185964.7583 - mae: 3480.7141
# Epoch 624/5000
#  - 0s - loss: 53277901.5084 - mae: 3481.0625
# Epoch 625/5000
#  - 0s - loss: 53199555.1369 - mae: 3466.1445
# Epoch 626/5000
#  - 0s - loss: 53193718.1023 - mae: 3483.9890
# Epoch 627/5000
#  - 0s - loss: 53185223.8473 - mae: 3480.0361
# Epoch 628/5000
#  - 0s - loss: 53092290.8453 - mae: 3471.0315
# Epoch 629/5000
#  - 0s - loss: 53016346.9053 - mae: 3452.4216
# Epoch 630/5000
#  - 0s - loss: 53010231.4891 - mae: 3461.3823
# Epoch 631/5000
#  - 0s - loss: 53006311.7410 - mae: 3451.5974
# Epoch 632/5000
#  - 0s - loss: 53032606.4753 - mae: 3472.6108
# Epoch 633/5000
#  - 0s - loss: 52879766.3919 - mae: 3453.2629
# Epoch 634/5000
#  - 0s - loss: 52830366.5903 - mae: 3447.7092
# Epoch 635/5000
#  - 0s - loss: 52915933.0565 - mae: 3452.9570
# Epoch 636/5000
#  - 0s - loss: 52873587.4987 - mae: 3439.3713
# Epoch 637/5000
#  - 0s - loss: 52734543.7318 - mae: 3440.9424
# Epoch 638/5000
#  - 0s - loss: 52796665.2702 - mae: 3436.9370
# Epoch 639/5000
#  - 0s - loss: 52697564.0407 - mae: 3436.7498
# Epoch 640/5000
#  - 0s - loss: 52663360.8835 - mae: 3430.4207
# Epoch 641/5000
#  - 0s - loss: 52655997.9664 - mae: 3429.9114
# Epoch 642/5000
#  - 0s - loss: 52637896.6168 - mae: 3422.0039
# Epoch 643/5000
#  - 0s - loss: 52607486.6265 - mae: 3432.0659
# Epoch 644/5000
#  - 0s - loss: 52583839.6621 - mae: 3422.8164
# Epoch 645/5000
#  - 0s - loss: 52419875.9267 - mae: 3411.6201
# Epoch 646/5000
#  - 0s - loss: 52484188.3949 - mae: 3413.1472
# Epoch 647/5000
#  - 0s - loss: 52438008.5557 - mae: 3423.7974
# Epoch 648/5000
#  - 0s - loss: 52457012.1794 - mae: 3404.9985
# Epoch 649/5000
#  - 0s - loss: 52352863.6366 - mae: 3401.9851
# Epoch 650/5000
#  - 0s - loss: 52354513.4697 - mae: 3407.2898
# Epoch 651/5000
#  - 0s - loss: 52357488.1120 - mae: 3408.4763
# Epoch 652/5000
#  - 0s - loss: 52343576.2962 - mae: 3393.0154
# Epoch 653/5000
#  - 0s - loss: 52211039.1359 - mae: 3400.7239
# Epoch 654/5000
#  - 0s - loss: 52241305.5201 - mae: 3395.0063
# Epoch 655/5000
#  - 0s - loss: 52280306.4672 - mae: 3390.9917
# Epoch 656/5000
#  - 0s - loss: 52169549.1461 - mae: 3374.8740
# Epoch 657/5000
#  - 0s - loss: 52034529.9338 - mae: 3384.2891
# Epoch 658/5000
#  - 0s - loss: 52144906.5079 - mae: 3377.8982
# Epoch 659/5000
#  - 0s - loss: 52042671.5522 - mae: 3386.1001
# Epoch 660/5000
#  - 0s - loss: 51891509.5588 - mae: 3361.4158
# Epoch 661/5000
#  - 0s - loss: 51989491.1837 - mae: 3389.5044
# Epoch 662/5000
#  - 0s - loss: 52031882.8478 - mae: 3378.0703
# Epoch 663/5000
#  - 0s - loss: 51976232.7226 - mae: 3362.9021
# Epoch 664/5000
#  - 0s - loss: 51992498.2280 - mae: 3370.7324
# Epoch 665/5000
#  - 0s - loss: 51935632.8183 - mae: 3367.7124
# Epoch 666/5000
#  - 0s - loss: 51917998.8427 - mae: 3363.4656
# Epoch 667/5000
#  - 0s - loss: 51855113.6641 - mae: 3364.1758
# Epoch 668/5000
#  - 0s - loss: 51820723.8941 - mae: 3359.8892
# Epoch 669/5000
#  - 0s - loss: 51743721.8341 - mae: 3357.0283
# Epoch 670/5000
#  - 0s - loss: 51749777.5491 - mae: 3364.4619
# Epoch 671/5000
#  - 0s - loss: 51838930.0550 - mae: 3354.7866
# Epoch 672/5000
#  - 0s - loss: 51582383.3573 - mae: 3337.5745
# Epoch 673/5000
#  - 0s - loss: 51731542.6321 - mae: 3360.9556
# Epoch 674/5000
#  - 0s - loss: 51533370.3858 - mae: 3343.9177
# Epoch 675/5000
#  - 0s - loss: 51768986.2870 - mae: 3343.7827
# Epoch 676/5000
#  - 0s - loss: 51656964.8214 - mae: 3339.6875
# Epoch 677/5000
#  - 0s - loss: 51564097.5211 - mae: 3345.6248
# Epoch 678/5000
#  - 0s - loss: 51622393.8509 - mae: 3331.5706
# Epoch 679/5000
#  - 0s - loss: 51480805.0249 - mae: 3326.7622
# Epoch 680/5000
#  - 0s - loss: 51508169.0402 - mae: 3327.6624
# Epoch 681/5000
#  - 0s - loss: 51520885.5237 - mae: 3324.1472
# Epoch 682/5000
#  - 0s - loss: 51504804.1155 - mae: 3323.2092
# Epoch 683/5000
#  - 0s - loss: 51385545.2967 - mae: 3327.3416
# Epoch 684/5000
#  - 0s - loss: 51500137.5481 - mae: 3313.6736
# Epoch 685/5000
#  - 0s - loss: 51375659.6814 - mae: 3322.8406
# Epoch 686/5000
#  - 0s - loss: 51418445.6448 - mae: 3315.3040
# Epoch 687/5000
#  - 0s - loss: 51293052.0328 - mae: 3303.9521
# Epoch 688/5000
#  - 0s - loss: 51296023.5527 - mae: 3316.4258
# Epoch 689/5000
#  - 0s - loss: 51367000.1471 - mae: 3313.5789
# Epoch 690/5000
#  - 0s - loss: 51289276.5440 - mae: 3315.2261
# Epoch 691/5000
#  - 0s - loss: 51251977.0453 - mae: 3298.0710
# Epoch 692/5000
#  - 0s - loss: 51224856.0692 - mae: 3308.7844
# Epoch 693/5000
#  - 0s - loss: 51282518.4366 - mae: 3301.8379
# Epoch 694/5000
#  - 0s - loss: 51158319.7455 - mae: 3293.1450
# Epoch 695/5000
#  - 0s - loss: 51159511.6031 - mae: 3297.1199
# Epoch 696/5000
#  - 0s - loss: 51148180.6921 - mae: 3288.7092
# Epoch 697/5000
#  - 0s - loss: 51082647.3293 - mae: 3285.2603
# Epoch 698/5000
#  - 0s - loss: 51087955.7089 - mae: 3297.4907
# Epoch 699/5000
#  - 0s - loss: 50943894.5735 - mae: 3279.2615
# Epoch 700/5000
#  - 0s - loss: 51044578.6921 - mae: 3292.7407
# Epoch 701/5000
#  - 0s - loss: 51025057.7303 - mae: 3281.9517
# Epoch 702/5000
#  - 0s - loss: 51008832.3288 - mae: 3270.0408
# Epoch 703/5000
#  - 0s - loss: 50959569.8158 - mae: 3274.7283
# Epoch 704/5000
#  - 0s - loss: 50865907.5455 - mae: 3277.5796
# Epoch 705/5000
#  - 0s - loss: 51006862.0967 - mae: 3280.5657
# Epoch 706/5000
#  - 0s - loss: 50895866.8377 - mae: 3267.9705
# Epoch 707/5000
#  - 0s - loss: 50748612.8275 - mae: 3272.5925
# Epoch 708/5000
#  - 0s - loss: 50790185.8906 - mae: 3269.4302
# Epoch 709/5000
#  - 0s - loss: 50774308.2209 - mae: 3270.7266
# Epoch 710/5000
#  - 0s - loss: 50836830.8728 - mae: 3265.9258
# Epoch 711/5000
#  - 0s - loss: 50814195.0097 - mae: 3258.4949
# Epoch 712/5000
#  - 0s - loss: 50883958.3532 - mae: 3272.2344
# Epoch 713/5000
#  - 0s - loss: 50754372.7481 - mae: 3251.5334
# Epoch 714/5000
#  - 0s - loss: 50728448.2677 - mae: 3249.0100
# Epoch 715/5000
#  - 0s - loss: 50677141.3659 - mae: 3248.7388
# Epoch 716/5000
#  - 0s - loss: 50801031.2173 - mae: 3257.6545
# Epoch 717/5000
#  - 0s - loss: 50698065.4061 - mae: 3249.9114
# Epoch 718/5000
#  - 0s - loss: 50695414.3303 - mae: 3245.9021
# Epoch 719/5000
#  - 0s - loss: 50714261.1094 - mae: 3240.0371
# Epoch 720/5000
#  - 0s - loss: 50521010.7827 - mae: 3241.3801
# Epoch 721/5000
#  - 0s - loss: 50630430.2176 - mae: 3253.1731
# Epoch 722/5000
#  - 0s - loss: 50487372.3868 - mae: 3240.6621
# Epoch 723/5000
#  - 0s - loss: 50567877.3644 - mae: 3238.0854
# Epoch 724/5000
#  - 0s - loss: 50555804.4896 - mae: 3235.4495
# Epoch 725/5000
#  - 0s - loss: 50394509.8695 - mae: 3221.4285
# Epoch 726/5000
#  - 0s - loss: 50444040.1064 - mae: 3227.6804
# Epoch 727/5000
#  - 0s - loss: 50506247.3903 - mae: 3221.4651
# Epoch 728/5000
#  - 0s - loss: 50504472.9636 - mae: 3230.7307
# Epoch 729/5000
#  - 0s - loss: 50334041.8433 - mae: 3223.1606
# Epoch 730/5000
#  - 0s - loss: 50358305.5206 - mae: 3225.4316
# Epoch 731/5000
#  - 0s - loss: 50378436.3008 - mae: 3205.5942
# Epoch 732/5000
#  - 0s - loss: 50328453.9751 - mae: 3219.8176
# Epoch 733/5000
#  - 0s - loss: 50402629.1338 - mae: 3206.2625
# Epoch 734/5000
#  - 0s - loss: 50265207.9517 - mae: 3216.0676
# Epoch 735/5000
#  - 0s - loss: 50349589.3104 - mae: 3203.4053
# Epoch 736/5000
#  - 0s - loss: 50218051.0173 - mae: 3199.7312
# Epoch 737/5000
#  - 0s - loss: 50221462.8763 - mae: 3184.2656
# Epoch 738/5000
#  - 0s - loss: 50110269.7903 - mae: 3199.6965
# Epoch 739/5000
#  - 0s - loss: 50162681.6377 - mae: 3195.4756
# Epoch 740/5000
#  - 0s - loss: 50122910.7369 - mae: 3193.1914
# Epoch 741/5000
#  - 0s - loss: 50147598.0550 - mae: 3196.7927
# Epoch 742/5000
#  - 0s - loss: 50131538.5354 - mae: 3171.1035
# Epoch 743/5000
#  - 0s - loss: 49997147.4969 - mae: 3196.8408
# Epoch 744/5000
#  - 0s - loss: 50030933.6402 - mae: 3185.7092
# Epoch 745/5000
#  - 0s - loss: 49988827.5827 - mae: 3181.9163
# Epoch 746/5000
#  - 0s - loss: 49885290.5776 - mae: 3179.8154
# Epoch 747/5000
#  - 0s - loss: 49833701.8982 - mae: 3183.1494
# Epoch 748/5000
#  - 0s - loss: 50025861.4300 - mae: 3181.9829
# Epoch 749/5000
#  - 0s - loss: 49884990.9593 - mae: 3178.2161
# Epoch 750/5000
#  - 0s - loss: 49960049.9491 - mae: 3170.5425
# Epoch 751/5000
#  - 0s - loss: 49898575.8473 - mae: 3165.6860
# Epoch 752/5000
#  - 0s - loss: 49766593.4656 - mae: 3164.0845
# Epoch 753/5000
#  - 0s - loss: 49790334.9761 - mae: 3160.3896
# Epoch 754/5000
#  - 0s - loss: 49738987.3003 - mae: 3155.3582
# Epoch 755/5000
#  - 0s - loss: 49611440.3837 - mae: 3143.6753
# Epoch 756/5000
#  - 0s - loss: 49639181.2682 - mae: 3153.2141
# Epoch 757/5000
#  - 0s - loss: 49652827.7796 - mae: 3161.0596
# Epoch 758/5000
#  - 0s - loss: 49696414.8316 - mae: 3158.8079
# Epoch 759/5000
#  - 0s - loss: 49619598.2173 - mae: 3147.9844
# Epoch 760/5000
#  - 0s - loss: 49648926.5967 - mae: 3158.7632
# Epoch 761/5000
#  - 0s - loss: 49552859.1903 - mae: 3137.0784
# Epoch 762/5000
#  - 0s - loss: 49580224.3969 - mae: 3136.8357
# Epoch 763/5000
#  - 0s - loss: 49566737.6300 - mae: 3146.1489
# Epoch 764/5000
#  - 0s - loss: 49488015.2377 - mae: 3130.3674
# Epoch 765/5000
#  - 0s - loss: 49431201.1593 - mae: 3129.3416
# Epoch 766/5000
#  - 0s - loss: 49435079.8992 - mae: 3126.2986
# Epoch 767/5000
#  - 0s - loss: 49347224.8809 - mae: 3116.0728
# Epoch 768/5000
#  - 0s - loss: 49298585.0962 - mae: 3121.0596
# Epoch 769/5000
#  - 0s - loss: 49278856.1761 - mae: 3110.8921
# Epoch 770/5000
#  - 0s - loss: 49225895.2310 - mae: 3122.2898
# Epoch 771/5000
#  - 0s - loss: 49179275.9415 - mae: 3106.6475
# Epoch 772/5000
#  - 0s - loss: 49351997.9786 - mae: 3105.9771
# Epoch 773/5000
#  - 0s - loss: 49130851.4941 - mae: 3103.9993
# Epoch 774/5000
#  - 0s - loss: 49218001.8646 - mae: 3107.9150
# Epoch 775/5000
#  - 0s - loss: 49060626.7977 - mae: 3096.1572
# Epoch 776/5000
#  - 0s - loss: 49244517.7893 - mae: 3105.0212
# Epoch 777/5000
#  - 0s - loss: 49116162.0041 - mae: 3093.2383
# Epoch 778/5000
#  - 0s - loss: 48973216.4916 - mae: 3082.2068
# Epoch 779/5000
#  - 0s - loss: 48931833.1455 - mae: 3079.9392
# Epoch 780/5000
#  - 0s - loss: 49044655.9888 - mae: 3080.9333
# Epoch 781/5000
#  - 0s - loss: 49050914.7186 - mae: 3077.3867
# Epoch 782/5000
#  - 0s - loss: 48897103.0707 - mae: 3074.6260
# Epoch 783/5000
#  - 0s - loss: 48869725.1003 - mae: 3065.8328
# Epoch 784/5000
#  - 0s - loss: 48865667.0779 - mae: 3076.3926
# Epoch 785/5000
#  - 0s - loss: 48871889.4198 - mae: 3069.0032
# Epoch 786/5000
#  - 0s - loss: 48736004.5700 - mae: 3078.9214
# Epoch 787/5000
#  - 0s - loss: 48727248.5781 - mae: 3062.5554
# Epoch 788/5000
#  - 0s - loss: 48796521.2723 - mae: 3066.1372
# Epoch 789/5000
#  - 0s - loss: 48797241.6254 - mae: 3050.4028
# Epoch 790/5000
#  - 0s - loss: 48686768.9553 - mae: 3057.4507
# Epoch 791/5000
#  - 0s - loss: 48738153.6165 - mae: 3053.1846
# Epoch 792/5000
#  - 0s - loss: 48647939.9664 - mae: 3054.7451
# Epoch 793/5000
#  - 0s - loss: 48838085.7211 - mae: 3058.1755
# Epoch 794/5000
#  - 0s - loss: 48694444.2926 - mae: 3053.8992
# Epoch 795/5000
#  - 0s - loss: 48636717.2712 - mae: 3049.0811
# ...
# Epoch 4740/5000
#  - 0s - loss: 31511099.7813 - mae: 1643.4489
# Epoch 4741/5000
#  - 0s - loss: 31671736.6516 - mae: 1640.1666
# Epoch 4742/5000
#  - 0s - loss: 31606789.5252 - mae: 1627.5822
# Epoch 4743/5000
#  - 0s - loss: 31649132.8681 - mae: 1639.5095
# Epoch 4744/5000
#  - 0s - loss: 31730365.2789 - mae: 1620.7460
# Epoch 4745/5000
#  - 0s - loss: 31591362.7162 - mae: 1621.5558
# Epoch 4746/5000
#  - 0s - loss: 31666216.1248 - mae: 1632.0657
# Epoch 4747/5000
#  - 0s - loss: 31567541.5205 - mae: 1630.9722
# Epoch 4748/5000
#  - 0s - loss: 31674083.3888 - mae: 1628.0024
# Epoch 4749/5000
#  - 0s - loss: 31550280.6531 - mae: 1636.1306
# Epoch 4750/5000
#  - 0s - loss: 31556066.4053 - mae: 1622.2291
# Epoch 4751/5000
#  - 0s - loss: 31623564.1117 - mae: 1627.4307
# Epoch 4752/5000
#  - 0s - loss: 31477005.0293 - mae: 1624.3856
# Epoch 4753/5000
#  - 0s - loss: 31564745.3921 - mae: 1632.1827
# Epoch 4754/5000
#  - 0s - loss: 31692955.2333 - mae: 1627.3344
# Epoch 4755/5000
#  - 0s - loss: 31380853.9211 - mae: 1639.4169
# Epoch 4756/5000
#  - 0s - loss: 31718694.3387 - mae: 1624.9384
# Epoch 4757/5000
#  - 0s - loss: 31616668.1420 - mae: 1628.5551
# Epoch 4758/5000
#  - 0s - loss: 31615156.6487 - mae: 1625.2363
# Epoch 4759/5000
#  - 0s - loss: 31574580.0774 - mae: 1624.8652
# Epoch 4760/5000
#  - 0s - loss: 31519405.9893 - mae: 1633.9161
# Epoch 4761/5000
#  - 0s - loss: 31877061.9391 - mae: 1624.7729
# Epoch 4762/5000
#  - 0s - loss: 31836129.5706 - mae: 1623.5591
# Epoch 4763/5000
#  - 0s - loss: 31621529.7695 - mae: 1627.0717
# Epoch 4764/5000
#  - 0s - loss: 31768396.1794 - mae: 1620.9672
# Epoch 4765/5000
#  - 0s - loss: 31555554.3898 - mae: 1631.0608
# Epoch 4766/5000
#  - 0s - loss: 31374730.5723 - mae: 1624.6932
# Epoch 4767/5000
#  - 0s - loss: 31790091.7775 - mae: 1622.0753
# Epoch 4768/5000
#  - 0s - loss: 31424084.2421 - mae: 1627.9501
# Epoch 4769/5000
#  - 0s - loss: 31567287.1566 - mae: 1625.8884
# Epoch 4770/5000
#  - 0s - loss: 31797807.5971 - mae: 1621.3254
# Epoch 4771/5000
#  - 0s - loss: 31518179.1430 - mae: 1629.5653
# Epoch 4772/5000
#  - 0s - loss: 31545611.6641 - mae: 1620.1084
# Epoch 4773/5000
#  - 0s - loss: 31574016.8761 - mae: 1630.1554
# Epoch 4774/5000
#  - 0s - loss: 31669848.0963 - mae: 1622.9661
# Epoch 4775/5000
#  - 0s - loss: 31537172.1908 - mae: 1620.5894
# Epoch 4776/5000
#  - 0s - loss: 31384341.3578 - mae: 1631.2957
# Epoch 4777/5000
#  - 0s - loss: 31626046.8631 - mae: 1634.1251
# Epoch 4778/5000
#  - 0s - loss: 31411654.9514 - mae: 1622.5967
# Epoch 4779/5000
#  - 0s - loss: 31635751.4964 - mae: 1625.6866
# Epoch 4780/5000
#  - 0s - loss: 31701280.3247 - mae: 1629.4263
# Epoch 4781/5000
#  - 0s - loss: 31629093.8361 - mae: 1619.5032
# Epoch 4782/5000
#  - 0s - loss: 31387360.8821 - mae: 1623.9531
# Epoch 4783/5000
#  - 0s - loss: 31537198.9791 - mae: 1619.4036
# Epoch 4784/5000
#  - 0s - loss: 31683142.7910 - mae: 1619.7322
# Epoch 4785/5000
#  - 0s - loss: 31498228.0405 - mae: 1620.9607
# Epoch 4786/5000
#  - 0s - loss: 31523632.7779 - mae: 1634.3224
# Epoch 4787/5000
#  - 0s - loss: 31549801.6570 - mae: 1616.2073
# Epoch 4788/5000
#  - 0s - loss: 31593983.8290 - mae: 1621.7677
# Epoch 4789/5000
#  - 0s - loss: 31590238.6763 - mae: 1624.9398
# Epoch 4790/5000
#  - 0s - loss: 31751094.0184 - mae: 1613.4922
# Epoch 4791/5000
#  - 0s - loss: 31762477.4583 - mae: 1624.0706
# Epoch 4792/5000
#  - 0s - loss: 31481388.5288 - mae: 1616.3707
# Epoch 4793/5000
#  - 0s - loss: 31599715.3364 - mae: 1624.1833
# Epoch 4794/5000
#  - 0s - loss: 31452762.9683 - mae: 1615.1727
# Epoch 4795/5000
#  - 0s - loss: 31572056.1055 - mae: 1622.6198
# Epoch 4796/5000
#  - 0s - loss: 31571270.1515 - mae: 1621.9755
# Epoch 4797/5000
#  - 0s - loss: 31588460.6118 - mae: 1615.2604
# Epoch 4798/5000
#  - 0s - loss: 31462610.1099 - mae: 1619.7059
# Epoch 4799/5000
#  - 0s - loss: 31558959.5662 - mae: 1618.8108
# Epoch 4800/5000
#  - 0s - loss: 31667056.5471 - mae: 1622.5433
# Epoch 4801/5000
#  - 0s - loss: 31653885.2684 - mae: 1612.8794
# Epoch 4802/5000
#  - 0s - loss: 31826075.3542 - mae: 1610.3411
# Epoch 4803/5000
#  - 0s - loss: 31686874.0483 - mae: 1618.1605
# Epoch 4804/5000
#  - 0s - loss: 31512389.2155 - mae: 1617.5071
# Epoch 4805/5000
#  - 0s - loss: 31484631.6443 - mae: 1628.2340
# Epoch 4806/5000
#  - 0s - loss: 31501867.0753 - mae: 1631.0471
# Epoch 4807/5000
#  - 0s - loss: 31524814.4936 - mae: 1621.7054
# Epoch 4808/5000
#  - 0s - loss: 31529883.8556 - mae: 1623.2412
# Epoch 4809/5000
#  - 0s - loss: 31379736.0835 - mae: 1619.4692
# Epoch 4810/5000
#  - 0s - loss: 31564143.4639 - mae: 1620.1365
# Epoch 4811/5000
#  - 0s - loss: 31315834.4449 - mae: 1622.8701
# Epoch 4812/5000
#  - 0s - loss: 31531387.6260 - mae: 1622.5525
# Epoch 4813/5000
#  - 0s - loss: 31750306.5776 - mae: 1609.8147
# Epoch 4814/5000
#  - 0s - loss: 31526319.1015 - mae: 1622.4927
# Epoch 4815/5000
#  - 0s - loss: 31684033.2821 - mae: 1619.3763
# Epoch 4816/5000
#  - 0s - loss: 31761055.7050 - mae: 1604.9036
# Epoch 4817/5000
#  - 0s - loss: 31711361.4621 - mae: 1624.4840
# Epoch 4818/5000
#  - 0s - loss: 31557913.3800 - mae: 1609.0004
# Epoch 4819/5000
#  - 0s - loss: 31460055.9226 - mae: 1604.3055
# Epoch 4820/5000
#  - 0s - loss: 31703229.9039 - mae: 1621.7965
# Epoch 4821/5000
#  - 0s - loss: 31375577.9683 - mae: 1610.4150
# Epoch 4822/5000
#  - 0s - loss: 31587962.2809 - mae: 1616.9386
# Epoch 4823/5000
#  - 0s - loss: 31699151.9831 - mae: 1623.1610
# Epoch 4824/5000
#  - 0s - loss: 31263588.4615 - mae: 1619.5314
# Epoch 4825/5000
#  - 0s - loss: 31623305.1272 - mae: 1621.4586
# Epoch 4826/5000
#  - 0s - loss: 31342050.5519 - mae: 1618.7053
# Epoch 4827/5000
#  - 0s - loss: 31601935.5869 - mae: 1628.2960
# Epoch 4828/5000
#  - 0s - loss: 31222291.8725 - mae: 1618.2623
# Epoch 4829/5000
#  - 0s - loss: 31532750.4735 - mae: 1625.5164
# Epoch 4830/5000
#  - 0s - loss: 31473558.3230 - mae: 1626.0807
# Epoch 4831/5000
#  - 0s - loss: 31308909.6730 - mae: 1618.1173
# Epoch 4832/5000
#  - 0s - loss: 31445513.0990 - mae: 1621.6050
# Epoch 4833/5000
#  - 0s - loss: 31317357.1642 - mae: 1625.8008
# Epoch 4834/5000
#  - 0s - loss: 31601017.1038 - mae: 1617.7791
# Epoch 4835/5000
#  - 0s - loss: 31607998.7499 - mae: 1622.9203
# Epoch 4836/5000
#  - 0s - loss: 31737121.4833 - mae: 1614.5800
# Epoch 4837/5000
#  - 0s - loss: 31607794.0281 - mae: 1609.8838
# Epoch 4838/5000
#  - 0s - loss: 31522311.4173 - mae: 1614.6385
# Epoch 4839/5000
#  - 0s - loss: 31522423.9664 - mae: 1607.3942
# Epoch 4840/5000
#  - 0s - loss: 31524713.3181 - mae: 1618.0354
# Epoch 4841/5000
#  - 0s - loss: 31458762.0235 - mae: 1625.3046
# Epoch 4842/5000
#  - 0s - loss: 31191788.7832 - mae: 1627.3650
# Epoch 4843/5000
#  - 0s - loss: 31704537.8426 - mae: 1604.7262
# Epoch 4844/5000
#  - 0s - loss: 31635599.1057 - mae: 1612.8143
# Epoch 4845/5000
#  - 0s - loss: 31460612.2092 - mae: 1622.5178
# Epoch 4846/5000
#  - 0s - loss: 31542315.2076 - mae: 1625.0298
# Epoch 4847/5000
#  - 0s - loss: 31629316.2854 - mae: 1619.0267
# Epoch 4848/5000
#  - 0s - loss: 31380136.4969 - mae: 1621.7148
# Epoch 4849/5000
#  - 0s - loss: 31490482.4333 - mae: 1616.7368
# Epoch 4850/5000
#  - 0s - loss: 31374031.1786 - mae: 1618.5010
# Epoch 4851/5000
#  - 0s - loss: 31555777.2252 - mae: 1615.1392
# Epoch 4852/5000
#  - 0s - loss: 31473377.7305 - mae: 1627.5602
# Epoch 4853/5000
#  - 0s - loss: 31398527.8115 - mae: 1629.9048
# Epoch 4854/5000
#  - 0s - loss: 31513739.4983 - mae: 1616.0514
# Epoch 4855/5000
#  - 0s - loss: 31743960.5042 - mae: 1616.7316
# Epoch 4856/5000
#  - 0s - loss: 31397039.4941 - mae: 1625.7919
# Epoch 4857/5000
#  - 0s - loss: 31795921.2310 - mae: 1612.9690
# Epoch 4858/5000
#  - 0s - loss: 31446646.9102 - mae: 1600.8109
# Epoch 4859/5000
#  - 0s - loss: 31560645.6214 - mae: 1627.6696
# Epoch 4860/5000
#  - 0s - loss: 31431487.1244 - mae: 1612.3624
# Epoch 4861/5000
#  - 0s - loss: 31592539.7056 - mae: 1610.3037
# Epoch 4862/5000
#  - 0s - loss: 31318598.6000 - mae: 1614.2042
# Epoch 4863/5000
#  - 0s - loss: 31694027.2807 - mae: 1620.5488
# Epoch 4864/5000
#  - 0s - loss: 31376620.5798 - mae: 1617.1252
# Epoch 4865/5000
#  - 0s - loss: 31800983.2056 - mae: 1608.1511
# Epoch 4866/5000
#  - 0s - loss: 31575920.9819 - mae: 1608.5505
# Epoch 4867/5000
#  - 0s - loss: 31374581.1338 - mae: 1615.5217
# Epoch 4868/5000
#  - 0s - loss: 31479886.0448 - mae: 1613.4199
# Epoch 4869/5000
#  - 0s - loss: 31560008.6368 - mae: 1614.2626
# Epoch 4870/5000
#  - 0s - loss: 31628500.9714 - mae: 1620.1729
# Epoch 4871/5000
#  - 0s - loss: 31628676.5128 - mae: 1616.3789
# Epoch 4872/5000
#  - 0s - loss: 31553804.4644 - mae: 1614.5917
# Epoch 4873/5000
#  - 0s - loss: 31461259.8715 - mae: 1616.7523
# Epoch 4874/5000
#  - 0s - loss: 31624134.5337 - mae: 1609.1719
# Epoch 4875/5000
#  - 0s - loss: 31607635.6435 - mae: 1615.7009
# Epoch 4876/5000
#  - 0s - loss: 31552594.6730 - mae: 1609.3123
# Epoch 4877/5000
#  - 0s - loss: 31541652.0172 - mae: 1618.9603
# Epoch 4878/5000
#  - 0s - loss: 31540628.8743 - mae: 1617.0327
# Epoch 4879/5000
#  - 0s - loss: 31243821.0168 - mae: 1614.9310
# Epoch 4880/5000
#  - 0s - loss: 31463226.3623 - mae: 1606.6208
# Epoch 4881/5000
#  - 0s - loss: 31448038.7025 - mae: 1619.5638
# Epoch 4882/5000
#  - 0s - loss: 31549397.1906 - mae: 1612.3322
# Epoch 4883/5000
#  - 0s - loss: 31385374.8260 - mae: 1614.2289
# Epoch 4884/5000
#  - 0s - loss: 31684301.1781 - mae: 1611.9667
# Epoch 4885/5000
#  - 0s - loss: 31164678.8968 - mae: 1612.9855
# Epoch 4886/5000
#  - 0s - loss: 31334974.6562 - mae: 1615.7739
# Epoch 4887/5000
#  - 0s - loss: 31384054.4115 - mae: 1618.2993
# Epoch 4888/5000
#  - 0s - loss: 31435229.4547 - mae: 1637.4279
# Epoch 4889/5000
#  - 0s - loss: 31455841.1715 - mae: 1614.8524
# Epoch 4890/5000
#  - 0s - loss: 31432094.1317 - mae: 1604.4855
# Epoch 4891/5000
#  - 0s - loss: 31643676.1905 - mae: 1613.3572
# Epoch 4892/5000
#  - 0s - loss: 31522890.1026 - mae: 1616.5419
# Epoch 4893/5000
#  - 0s - loss: 31252312.8850 - mae: 1604.5964
# Epoch 4894/5000
#  - 0s - loss: 31605334.4522 - mae: 1606.5288
# Epoch 4895/5000
#  - 0s - loss: 31647278.0887 - mae: 1612.4537
# Epoch 4896/5000
#  - 0s - loss: 31703431.8985 - mae: 1604.7894
# Epoch 4897/5000
#  - 0s - loss: 31699156.6384 - mae: 1610.4719
# Epoch 4898/5000
#  - 0s - loss: 31743740.5730 - mae: 1610.8651
# Epoch 4899/5000
#  - 0s - loss: 31777735.6053 - mae: 1609.0106
# Epoch 4900/5000
#  - 0s - loss: 31545012.2011 - mae: 1611.9529
# Epoch 4901/5000
#  - 0s - loss: 31619236.9064 - mae: 1608.4387
# Epoch 4902/5000
#  - 0s - loss: 31438814.1272 - mae: 1620.0211
# Epoch 4903/5000
#  - 0s - loss: 31461334.1664 - mae: 1617.2936
# Epoch 4904/5000
#  - 0s - loss: 31367738.9690 - mae: 1612.2926
# Epoch 4905/5000
#  - 0s - loss: 31506435.6262 - mae: 1608.7067
# Epoch 4906/5000
#  - 0s - loss: 31448863.5025 - mae: 1608.4929
# Epoch 4907/5000
#  - 0s - loss: 31729094.6513 - mae: 1605.7413
# Epoch 4908/5000
#  - 0s - loss: 31716507.6767 - mae: 1606.4645
# Epoch 4909/5000
#  - 0s - loss: 31320231.9221 - mae: 1616.8052
# Epoch 4910/5000
#  - 0s - loss: 31481035.4416 - mae: 1597.4523
# Epoch 4911/5000
#  - 0s - loss: 31465767.1218 - mae: 1622.1365
# Epoch 4912/5000
#  - 0s - loss: 31388590.5751 - mae: 1612.2079
# Epoch 4913/5000
#  - 0s - loss: 31584330.1878 - mae: 1605.8815
# Epoch 4914/5000
#  - 0s - loss: 31570745.2601 - mae: 1603.0597
# Epoch 4915/5000
#  - 0s - loss: 31451712.9310 - mae: 1606.3589
# Epoch 4916/5000
#  - 0s - loss: 31504960.8174 - mae: 1601.3721
# Epoch 4917/5000
#  - 0s - loss: 31775223.0725 - mae: 1605.2141
# Epoch 4918/5000
#  - 0s - loss: 31362330.7809 - mae: 1608.6506
# Epoch 4919/5000
#  - 0s - loss: 31476333.3541 - mae: 1607.5787
# Epoch 4920/5000
#  - 0s - loss: 31326939.4039 - mae: 1599.6832
# Epoch 4921/5000
#  - 0s - loss: 31767052.9510 - mae: 1609.2601
# Epoch 4922/5000
#  - 0s - loss: 31433881.0959 - mae: 1613.9387
# Epoch 4923/5000
#  - 0s - loss: 31304298.1856 - mae: 1608.8566
# Epoch 4924/5000
#  - 0s - loss: 31381279.6892 - mae: 1615.0679
# Epoch 4925/5000
#  - 0s - loss: 31503050.2379 - mae: 1610.4205
# Epoch 4926/5000
#  - 0s - loss: 31274990.4066 - mae: 1606.7529
# Epoch 4927/5000
#  - 0s - loss: 31514290.6508 - mae: 1614.2621
# Epoch 4928/5000
#  - 0s - loss: 31252141.1355 - mae: 1602.3492
# Epoch 4929/5000
#  - 0s - loss: 31483061.1454 - mae: 1604.6995
# Epoch 4930/5000
#  - 0s - loss: 31595288.5588 - mae: 1609.9012
# Epoch 4931/5000
#  - 0s - loss: 31280391.3405 - mae: 1602.7656
# Epoch 4932/5000
#  - 0s - loss: 31482503.9410 - mae: 1601.4874
# Epoch 4933/5000
#  - 0s - loss: 31482095.4674 - mae: 1606.6536
# Epoch 4934/5000
#  - 0s - loss: 31237287.6789 - mae: 1597.4100
# Epoch 4935/5000
#  - 0s - loss: 31489396.2350 - mae: 1602.4758
# Epoch 4936/5000
#  - 0s - loss: 31422976.6226 - mae: 1596.5060
# Epoch 4937/5000
#  - 0s - loss: 31330641.5618 - mae: 1613.0350
# Epoch 4938/5000
#  - 0s - loss: 31328489.3399 - mae: 1611.3282
# Epoch 4939/5000
#  - 0s - loss: 31384879.3506 - mae: 1607.0033
# Epoch 4940/5000
#  - 0s - loss: 31502716.5586 - mae: 1603.8451
# Epoch 4941/5000
#  - 0s - loss: 31524259.5799 - mae: 1596.1608
# Epoch 4942/5000
#  - 0s - loss: 31322808.8679 - mae: 1605.4485
# Epoch 4943/5000
#  - 0s - loss: 31659446.8583 - mae: 1594.1143
# Epoch 4944/5000
#  - 0s - loss: 31226553.8167 - mae: 1607.7469
# Epoch 4945/5000
#  - 0s - loss: 31426307.9832 - mae: 1609.8147
# Epoch 4946/5000
#  - 0s - loss: 31453093.5539 - mae: 1603.2861
# Epoch 4947/5000
#  - 0s - loss: 31606251.2036 - mae: 1601.1011
# Epoch 4948/5000
#  - 0s - loss: 31313509.0969 - mae: 1596.8633
# Epoch 4949/5000
#  - 0s - loss: 31500098.6293 - mae: 1603.6072
# Epoch 4950/5000
#  - 0s - loss: 31375088.3832 - mae: 1608.7297
# Epoch 4951/5000
#  - 0s - loss: 31503740.7654 - mae: 1605.1265
# Epoch 4952/5000
#  - 0s - loss: 31228831.0687 - mae: 1609.7253
# Epoch 4953/5000
#  - 0s - loss: 31542818.3569 - mae: 1602.4115
# Epoch 4954/5000
#  - 0s - loss: 31416448.0938 - mae: 1597.3772
# Epoch 4955/5000
#  - 0s - loss: 31295351.5705 - mae: 1605.4221
# Epoch 4956/5000
#  - 0s - loss: 31294758.1667 - mae: 1601.8516
# Epoch 4957/5000
#  - 0s - loss: 31446074.3803 - mae: 1599.7592
# Epoch 4958/5000
#  - 0s - loss: 31286503.6906 - mae: 1604.5988
# Epoch 4959/5000
#  - 0s - loss: 31339395.1567 - mae: 1599.3141
# Epoch 4960/5000
#  - 0s - loss: 31524936.2524 - mae: 1595.8303
# Epoch 4961/5000
#  - 0s - loss: 31478538.8822 - mae: 1617.1927
# Epoch 4962/5000
#  - 0s - loss: 31160858.6382 - mae: 1609.4711
# Epoch 4963/5000
#  - 0s - loss: 31520894.7135 - mae: 1606.0387
# Epoch 4964/5000
#  - 0s - loss: 31289439.5442 - mae: 1595.4772
# Epoch 4965/5000
#  - 0s - loss: 31551603.1335 - mae: 1603.1708
# Epoch 4966/5000
#  - 0s - loss: 31620466.5984 - mae: 1600.1910
# Epoch 4967/5000
#  - 0s - loss: 31537658.7296 - mae: 1593.8850
# Epoch 4968/5000
#  - 0s - loss: 31452206.7527 - mae: 1601.8264
# Epoch 4969/5000
#  - 0s - loss: 31520195.0934 - mae: 1599.0918
# Epoch 4970/5000
#  - 0s - loss: 31528552.6443 - mae: 1597.8789
# Epoch 4971/5000
#  - 0s - loss: 31355196.4305 - mae: 1594.3934
# Epoch 4972/5000
#  - 0s - loss: 31543758.2567 - mae: 1606.7889
# Epoch 4973/5000
#  - 0s - loss: 31159790.2253 - mae: 1599.2056
# Epoch 4974/5000
#  - 0s - loss: 31359900.3312 - mae: 1612.2648
# Epoch 4975/5000
#  - 0s - loss: 31543994.7178 - mae: 1596.8756
# Epoch 4976/5000
#  - 0s - loss: 31189458.0901 - mae: 1604.9120
# Epoch 4977/5000
#  - 0s - loss: 31365813.8076 - mae: 1596.8909
# Epoch 4978/5000
#  - 0s - loss: 31434798.2580 - mae: 1602.8907
# Epoch 4979/5000
#  - 0s - loss: 31585306.2351 - mae: 1593.4597
# Epoch 4980/5000
#  - 0s - loss: 31713359.9934 - mae: 1602.6204
# Epoch 4981/5000
#  - 0s - loss: 31272203.5733 - mae: 1593.2526
# Epoch 4982/5000
#  - 0s - loss: 31078983.4662 - mae: 1610.1372
# Epoch 4983/5000
#  - 0s - loss: 31498612.7517 - mae: 1608.5636
# Epoch 4984/5000
#  - 0s - loss: 31319951.6585 - mae: 1598.4430
# Epoch 4985/5000
#  - 0s - loss: 31446327.4352 - mae: 1606.2600
# Epoch 4986/5000
#  - 0s - loss: 31416966.4272 - mae: 1593.3789
# Epoch 4987/5000
#  - 0s - loss: 31186625.4055 - mae: 1610.1204
# Epoch 4988/5000
#  - 0s - loss: 31510640.5817 - mae: 1604.1152
# Epoch 4989/5000
#  - 0s - loss: 31287678.2919 - mae: 1591.2852
# Epoch 4990/5000
#  - 0s - loss: 31540761.9116 - mae: 1603.5883
# Epoch 4991/5000
#  - 0s - loss: 31518354.5626 - mae: 1590.9729
# Epoch 4992/5000
#  - 0s - loss: 31352547.3770 - mae: 1595.4436
# Epoch 4993/5000
#  - 0s - loss: 31436734.1017 - mae: 1607.7549
# Epoch 4994/5000
#  - 0s - loss: 31304611.9560 - mae: 1602.1954
# Epoch 4995/5000
#  - 0s - loss: 31462895.5593 - mae: 1601.7889
# Epoch 4996/5000
#  - 0s - loss: 31657791.2789 - mae: 1590.9143
# Epoch 4997/5000
#  - 0s - loss: 31389959.4641 - mae: 1605.9634
# Epoch 4998/5000
#  - 0s - loss: 31183039.2125 - mae: 1600.7297
# Epoch 4999/5000
#  - 0s - loss: 31555965.1053 - mae: 1595.9332
# Epoch 5000/5000
#  - 0s - loss: 31364266.6774 - mae: 1597.6152
# MSE: 28550421.06849315 MAE: 4017.60498046875

# %%
# 输出一个一天/h的训练值与实际值
fig = plt.figure(figsize=(12,5))
y_pred = model.predict(train_data)
x_data = np.linspace(0,len(train_data),len(y_pred))
plt.scatter(x_data,train_target)
plt.plot(x_data,y_pred,'r-',lw=1)

# %% [markdown]
# #### 5.3.4 预测结果

# %%
# 输出一个客流量 / h 的预测值与实际值
fig = plt.figure(figsize=(12, 5))
y_pred = model.predict(test_data)
x_data = np.linspace(0,len(y_pred)/24 ,len(y_pred))
plt.scatter(x_data[0:200],test_target[0:200])
plt.plot(x_data[0:200],y_pred[0:200],'r-',lw=1)

# %% [markdown]
# ## 6. 结论
#
# 通过对上海虹桥地铁进出站的客流量数据分析，发现客流量受到节假日，天气等因素的影响，本模型综合考虑以上影响因素，建立地铁客流量的预测模型。
#
# 情景分析结果表明，本预测算法能够有效的应用于地铁进出站的客流量预测情景。将来通过进一步对模型的改进和优化，能够支持公交、火车等交通方式的客流量预测。
#
# 届时将打造一个完整的大型交通枢纽客流量预测系统。为交通枢纽的运力决策和综合管理优化提供数据支持和政策建议。
