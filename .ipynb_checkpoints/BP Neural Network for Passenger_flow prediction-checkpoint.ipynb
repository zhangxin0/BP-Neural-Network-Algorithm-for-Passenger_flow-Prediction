# %% [markdown]
# # 枢纽客流量BP神经网络预测模型
#
#
# ## 1. 研究意义：
#
# 智慧交通是智慧城市的重要组成部分，提高公交车站点客流量预测的准确度是智慧公交的研究内容之一。大型现代化综合交通枢纽站汇集多种交通方式并伴有大规模客流集散、换乘等特点，采用科学的方法研究大型综合交通枢纽站的各个交通方式的客流量预测对公交运营部门的快速决策和综合管理提供及时准确的数据参考具有现实意义。
#
# 本算法模型有效的解决了交通枢纽各个交通方式短期客流量的预测问题， 对未来的小时客流量和5分钟客流量进行短期预测，能够有效的预测客流量爆发点和未来各个时段客流量的走势，为交通枢纽的运力分配策略提供数据支持。模型充分考虑了节假日、天气变化等因素对客流量的影响，能够提高对于特殊节日和天气影响下的客流量预测精度。
#
# 模型首先分析影响客流波动的因素（节假日、天气因素以及时间序列等），然后通过对比各类预测方法的优缺点，设计改进的BP神经网络算法进行短期客流量预测。
#
# ## 2.预期目标和现阶段的成果：
#
# 预测模型将提供对交通枢纽地铁、公交、火车等交通方式的客流量预测，实现客流量爆发预警功能，为枢纽的运力调配提供数据支持。同时，客流量的预测和分析，能够为优化枢纽的空间布置和人力分配提供政策建议。
#
# 目前，基于Keras深度学习库搭建的BP神经网络预测模型目前已完成对上海虹桥地铁进出站的客流量预测，小时客流量预测精度可以达到10%以下。能够有效的实现未来一周的客流量预测。未来通过对预测算法输入特征值的优化以及对部分特殊情况的规则提取和分析（比如特殊的节假日情况，突发事件等），算法的精度将得到进一步提高。
#
# 未来将打造一个完整的交通枢纽客流量预测系统，为交通枢纽的运力决策和综合管理优化提供数据支持和政策建议。该系统可以支持交通枢纽站的地铁、公交、火车等交通方式的客流量预测，届时需要拿到公交刷卡记录和火车站的进出站闸机历史csv数据。
#
#
# ## 3.模型功能：
#
# 模型能够有效预测未来一周枢纽内各个交通方式的客流量大小，提前为枢纽运力分配提供策略。模式采用有监督的机器学习方式，在未来随着训练（历史）数据的不断积累，能够实现自我调整和参数优化，不断提高预测的精度。
#
# 根据给定的输入参数：
# INPUT[日期(eg:20180901)，时段(eg:8)，节假日情况（周末or其他节假日), 天气情况（降雨），最高温度，风力]
#
# 输出未来客流量的预测值：
# OUTPUT[Passenger_flow / h]
#
# ## 4. 网络结构：
#
# 网络采用7维的特征值向量作为输入参数，两层64节点的隐含层，隐含层采用“relu”激活函数，输出层是1维的客流量数值。下面是网络的结构：
#
# INPUT[x1,x2...,x7] ->
# Hiddden layer1[64 Nodes, 'relu' activation function] -> Hidden layer2[64 Nodes,'relu]
# -> OUTPUT[Passenger_flow]
#
#
# ## 5.情景分析-上海虹桥地跌进出站客流分析：
#
# 本章节采用上海虹桥实际的地铁进出站客流数据进行建模和验证，分析算法模型对与客流量预测的可行性。本章详细的介绍了模型的搭建流程，包括运行环境的检查， 输入数据的处理分析以及预测模型的训练和结果预测。 模型构建的目录如下：
#
# 5.1. 环境检查
#     5.1.1 Python版本检查
#     5.1.2  基础包导入检查
#     5.1.3 检查安装版本
#
# 5.2. 客流量数据预处理和特征分析
#     5.2.1 读取数据
#     5.2.2 提取闸机数据，转换为小时的客流量数据
#             绘制 客流量 / 小时 统计图
#             绘制 节假日 / 日期 统计图
#
# 5.3. 搭建神经网络预测模型
#     5.3.1 网络输入数据标准化
#     5.3.2 搭建网络框架
#     5.3.3 训练神经网络
#     5.3.4 预测结果

# %% [markdown]
# ### 5.1 环境检查

# %% [markdown]
# #### 5.1.1 Python版本检查
# python 3 on anaconda

# %%
# !python3 --version
# Out:
# Python 3.7.5

# %% [raw]
# Anaconda 环境配置（mac）
# https://www.jianshu.com/p/b9eac8419c8d
# 需要的环境参数：export PATH=/Users/zhangfujiang/anaconda3/bin:$PATH，
# 配置环境变量：conda env create -f  /Users/zhangfujiang/virtual_platform_mac.yml
# Environment: jp_kernel on mackbook pro

# %% [markdown]
# #### 5.1.2  基础包导入检查

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import OneHotEncoder

# %% [raw]
# 在终端运行
# pip install tensorflow and keras  源： -i https://pypi.tuna.tsinghua.edu.cn/simple

# %%
import tensorflow
import keras
print('tensorflow:', tensorflow.__version__)
print('keras:', keras.__version__)
# !python3 --version
# Out:
# tensorflow: 2.0.0
# keras: 2.3.1
# Python 3.7.5
# Using TensorFlow backend.

# %% [markdown]
# #### 5.1.3 检查安装版本

# %%
import numpy
print('numpy:', numpy.__version__)
import scipy
print("scipy:", scipy.__version__)
#import matplotlib as plt
#print('matplotlib:', matplotlib.__version__)
# Out:
# numpy: 1.17.3
# scipy: 1.2.1

# %% [markdown]
# ### 5.2 客流量数据预处理和特征分析

# %%
from keras.datasets import boston_housing
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import RMSprop
import numpy as np
import csv
import os
import random
import pandas as pd
import matplotlib.pyplot as plt
import json
from sklearn import metrics

# %%
# 把日期hash计算:"2018/1/1 0:00:26"--> 0=2018010100
# date 指标： 反映时间的变化
# >> date:"20180101" hour:"00"
def transfer_time(str):
    # str: "2018/1/1 0:00:26"
    data = str.split(' ')
    if len(data) == 1:
        date = data[0]
        hour = 0
        #pdb.set_trace()
    else:
        date = data[0]
        hour = data[1]
    try:
        temp_date = date.split('/')
        if len(temp_date[1]) == 1:
            temp_date[1] = '0' + temp_date[1]
        if len(temp_date[2]) == 1:
            temp_date[2] = '0' + temp_date[2]
        date = temp_date[0] + temp_date[1] + temp_date[2]
        temp_hour = hour.split(':')
        hour = temp_hour[0]
        if len(hour) < 2:
            hour = '0' + hour
    # return 日期和时段
    except Exception as e:
        print("Transfer to time exception:",date)
        print(e)
        hour = "00"
    return date, hour

# %% [markdown]
# #### 5.2.1 读取数据

# %%
# 读取data
# (train_data, train_target), (test_data, test_target) 获取
"""
csv_data: passenger flow
"""
csv_data = pd.read_csv('data.csv')

# %%
# data: {datehour: {t},wind, holiday, weather, datehour, hum, week}
with open('data.json', 'r') as f:
    json_data = json.load(f)

# %%
json_data
# Out:
# {'2018010105': {'t': '2℃',
#   'hum': '91%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010105},
#  '2018010106': {'t': '2℃',
#   'hum': '91%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010106},
#  '2018010107': {'t': '2℃',
#   'hum': '94%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010107},
#  '2018010108': {'t': '5℃',
#   'hum': '76%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010108},
#  '2018010109': {'t': '7℃',
#   'hum': '56%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010109},
#  '2018010110': {'t': '9℃',
#   'hum': '36%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010110},
#  '2018010111': {'t': '10℃',
#   'hum': '34%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010111},
#  '2018010112': {'t': '10℃',
#   'hum': '24%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010112},
#  '2018010113': {'t': '11℃',
#   'hum': '29%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010113},
#  '2018010114': {'t': '11℃',
#   'hum': '27%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010114},
#  '2018010115': {'t': '11℃',
#   'hum': '30%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010115},
#  '2018010116': {'t': '9℃',
#   'hum': '41%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010116},
#  '2018010117': {'t': '7℃',
#   'hum': '54%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010117},
#  '2018010118': {'t': '6℃',
#   'hum': '66%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010118},
#  '2018010119': {'t': '5℃',
#   'hum': '72%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010119},
#  '2018010120': {'t': '6℃',
#   'hum': '70%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010120},
#  '2018010121': {'t': '6℃',
#   'hum': '70%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010121},
#  '2018010122': {'t': '7℃',
#   'hum': '70%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010122},
#  '2018010123': {'t': '7℃',
#   'hum': '70%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010123},
#  '2018010205': {'t': '10℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010205},
#  '2018010206': {'t': '10℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010206},
#  '2018010207': {'t': '10℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010207},
#  '2018010208': {'t': '10℃',
#   'hum': '71%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010208},
#  '2018010209': {'t': '11℃',
#   'hum': '67%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010209},
#  '2018010210': {'t': '12℃',
#   'hum': '61%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010210},
#  '2018010211': {'t': '13℃',
#   'hum': '61%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010211},
#  '2018010212': {'t': '13℃',
#   'hum': '62%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010212},
#  '2018010213': {'t': '12℃',
#   'hum': '64%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010213},
#  '2018010214': {'t': '12℃',
#   'hum': '67%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010214},
#  '2018010215': {'t': '12℃',
#   'hum': '71%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010215},
#  '2018010216': {'t': '12℃',
#   'hum': '74%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010216},
#  '2018010217': {'t': '12℃',
#   'hum': '75%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010217},
#  '2018010218': {'t': '11℃',
#   'hum': '77%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010218},
#  '2018010219': {'t': '11℃',
#   'hum': '77%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010219},
#  '2018010220': {'t': '11℃',
#   'hum': '89%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010220},
#  '2018010221': {'t': '11℃',
#   'hum': '89%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010221},
#  '2018010222': {'t': '10℃',
#   'hum': '95%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010222},
#  '2018010223': {'t': '10℃',
#   'hum': '95%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010223},
#  '2018010305': {'t': '7℃',
#   'hum': '92%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010305},
#  '2018010306': {'t': '7℃',
#   'hum': '92%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010306},
#  '2018010307': {'t': '8℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010307},
#  '2018010308': {'t': '8℃',
#   'hum': '89%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010308},
#  '2018010309': {'t': '8℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010309},
#  '2018010310': {'t': '8℃',
#   'hum': '92%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010310},
#  '2018010311': {'t': '8℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010311},
#  '2018010312': {'t': '8℃',
#   'hum': '80%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010312},
#  '2018010313': {'t': '8℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010313},
#  '2018010314': {'t': '7℃',
#   'hum': '81%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010314},
#  '2018010315': {'t': '7℃',
#   'hum': '77%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010315},
#  '2018010316': {'t': '7℃',
#   'hum': '78%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010316},
#  '2018010317': {'t': '6℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010317},
#  '2018010318': {'t': '5℃',
#   'hum': '89%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010318},
#  '2018010319': {'t': '5℃',
#   'hum': '90%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010319},
#  '2018010320': {'t': '5℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010320},
#  '2018010321': {'t': '5℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010321},
#  '2018010322': {'t': '4℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010322},
#  '2018010323': {'t': '4℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010323},
#  '2018010405': {'t': '4℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010405},
#  '2018010406': {'t': '4℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010406},
#  '2018010407': {'t': '4℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010407},
#  '2018010408': {'t': '4℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010408},
#  '2018010409': {'t': '4℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010409},
#  '2018010410': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010410},
#  '2018010411': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010411},
#  '2018010412': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010412},
#  '2018010413': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010413},
#  '2018010414': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010414},
#  '2018010415': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010415},
#  '2018010416': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010416},
#  '2018010417': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010417},
#  '2018010418': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010418},
#  '2018010419': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010419},
#  '2018010420': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010420},
#  '2018010421': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010421},
#  '2018010422': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010422},
#  '2018010423': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010423},
#  '2018010505': {'t': '3℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010505},
#  '2018010506': {'t': '3℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010506},
#  '2018010507': {'t': '3℃',
#   'hum': '92%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010507},
#  '2018010508': {'t': '4℃',
#   'hum': '88%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010508},
#  '2018010509': {'t': '4℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010509},
#  '2018010510': {'t': '5℃',
#   'hum': '74%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010510},
#  '2018010511': {'t': '5℃',
#   'hum': '73%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010511},
#  '2018010512': {'t': '5℃',
#   'hum': '66%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010512},
#  '2018010513': {'t': '5℃',
#   'hum': '64%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010513},
#  '2018010514': {'t': '5℃',
#   'hum': '66%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010514},
#  '2018010515': {'t': '4℃',
#   'hum': '67%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010515},
#  '2018010516': {'t': '4℃',
#   'hum': '67%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010516},
#  '2018010517': {'t': '4℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010517},
#  '2018010518': {'t': '3℃',
#   'hum': '69%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010518},
#  '2018010519': {'t': '3℃',
#   'hum': '69%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010519},
#  '2018010520': {'t': '2℃',
#   'hum': '79%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010520},
#  '2018010521': {'t': '2℃',
#   'hum': '79%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010521},
#  '2018010522': {'t': '1℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010522},
#  '2018010523': {'t': '1℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010523},
#  '2018010605': {'t': '0℃',
#   'hum': '89%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010605},
#  '2018010606': {'t': '0℃',
#   'hum': '89%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010606},
#  '2018010607': {'t': '1℃',
#   'hum': '85%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010607},
#  '2018010608': {'t': '2℃',
#   'hum': '81%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010608},
#  '2018010609': {'t': '4℃',
#   'hum': '74%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010609},
#  '2018010610': {'t': '5℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010610},
#  '2018010611': {'t': '7℃',
#   'hum': '58%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010611},
#  '2018010612': {'t': '7℃',
#   'hum': '60%',
#   'weather': '阴',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010612},
#  '2018010613': {'t': '7℃',
#   'hum': '59%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010613},
#  '2018010614': {'t': '8℃',
#   'hum': '59%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010614},
#  '2018010615': {'t': '7℃',
#   'hum': '63%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010615},
#  '2018010616': {'t': '7℃',
#   'hum': '67%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010616},
#  '2018010617': {'t': '6℃',
#   'hum': '69%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010617},
#  '2018010618': {'t': '6℃',
#   'hum': '71%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010618},
#  '2018010619': {'t': '6℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010619},
#  '2018010620': {'t': '6℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010620},
#  '2018010621': {'t': '6℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010621},
#  '2018010622': {'t': '6℃',
#   'hum': '94%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010622},
#  '2018010623': {'t': '6℃',
#   'hum': '94%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010623},
#  '2018010705': {'t': '8℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010705},
#  '2018010706': {'t': '8℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010706},
#  '2018010707': {'t': '8℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010707},
#  '2018010708': {'t': '8℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010708},
#  '2018010709': {'t': '9℃',
#   'hum': '98%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010709},
#  '2018010710': {'t': '9℃',
#   'hum': '98%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010710},
#  '2018010711': {'t': '10℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010711},
#  '2018010712': {'t': '10℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010712},
#  '2018010713': {'t': '10℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010713},
#  '2018010714': {'t': '9℃',
#   'hum': '96%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010714},
#  '2018010715': {'t': '8℃',
#   'hum': '96%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010715},
#  '2018010716': {'t': '6℃',
#   'hum': '95%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010716},
#  '2018010717': {'t': '6℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '3级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010717},
#  '2018010718': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010718},
#  '2018010719': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010719},
#  '2018010720': {'t': '5℃',
#   'hum': '89%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010720},
#  '2018010721': {'t': '5℃',
#   'hum': '89%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010721},
#  '2018010722': {'t': '4℃',
#   'hum': '88%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010722},
#  '2018010723': {'t': '4℃',
#   'hum': '88%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010723},
#  '2018010805': {'t': '3℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010805},
#  '2018010806': {'t': '3℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010806},
#  '2018010807': {'t': '3℃',
#   'hum': '83%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010807},
#  '2018010808': {'t': '3℃',
#   'hum': '82%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010808},
#  '2018010809': {'t': '3℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010809},
#  '2018010810': {'t': '3℃',
#   'hum': '78%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010810},
#  '2018010811': {'t': '3℃',
#   'hum': '71%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010811},
#  '2018010812': {'t': '3℃',
#   'hum': '70%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010812},
#  '2018010813': {'t': '3℃',
#   'hum': '67%',
#   'weather': '多云',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010813},
#  '2018010814': {'t': '3℃',
#   'hum': '65%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010814},
#  '2018010815': {'t': '3℃',
#   'hum': '64%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010815},
#  '2018010816': {'t': '4℃',
#   'hum': '65%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010816},
#  '2018010817': {'t': '3℃',
#   'hum': '63%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010817},
#  '2018010818': {'t': '3℃',
#   'hum': '66%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010818},
#  '2018010819': {'t': '2℃',
#   'hum': '53%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010819},
#  '2018010820': {'t': '1℃',
#   'hum': '54%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010820},
#  '2018010821': {'t': '1℃',
#   'hum': '54%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010821},
#  '2018010822': {'t': '0℃',
#   'hum': '49%',
#   'weather': '多云',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010822},
#  '2018010823': {'t': '0℃',
#   'hum': '49%',
#   'weather': '多云',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010823},
#  '2018010905': {'t': '0℃',
#   'hum': '57%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010905},
#  '2018010906': {'t': '0℃',
#   'hum': '57%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010906},
#  '2018010907': {'t': '0℃',
#   'hum': '57%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010907},
#  '2018010908': {'t': '2℃',
#   'hum': '47%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010908},
#  '2018010909': {'t': '3℃',
#   'hum': '42%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010909},
#  '2018010910': {'t': '4℃',
#   'hum': '38%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010910},
#  '2018010911': {'t': '5℃',
#   'hum': '33%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010911},
#  '2018010912': {'t': '5℃',
#   'hum': '30%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010912},
#  '2018010913': {'t': '5℃',
#   'hum': '27%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010913},
#  '2018010914': {'t': '5℃',
#   'hum': '27%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010914},
#  '2018010915': {'t': '6℃',
#   'hum': '28%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010915},
#  '2018010916': {'t': '5℃',
#   'hum': '33%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010916},
#  '2018010917': {'t': '4℃',
#   'hum': '36%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010917},
#  '2018010918': {'t': '4℃',
#   'hum': '39%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010918},
#  '2018010919': {'t': '3℃',
#   'hum': '45%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010919},
#  '2018010920': {'t': '1℃',
#   'hum': '57%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010920},
#  '2018010921': {'t': '1℃',
#   'hum': '57%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010921},
#  '2018010922': {'t': '3℃',
#   'hum': '48%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010922},
#  '2018010923': {'t': '3℃',
#   'hum': '48%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010923},
#  '2018011005': {'t': '1℃',
#   'hum': '59%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011005},
#  '2018011006': {'t': '1℃',
#   'hum': '59%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011006},
#  '2018011007': {'t': '2℃',
#   'hum': '54%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011007},
#  '2018011008': {'t': '2℃',
#   'hum': '51%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011008},
#  '2018011009': {'t': '3℃',
#   'hum': '43%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011009},
#  '2018011010': {'t': '4℃',
#   'hum': '36%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011010},
#  '2018011011': {'t': '5℃',
#   'hum': '30%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011011},
#  '2018011012': {'t': '5℃',
#   'hum': '24%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011012},
#  '2018011013': {'t': '5℃',
#   'hum': '21%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011013},
#  '2018011014': {'t': '5℃',
#   'hum': '23%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011014},
#  '2018011015': {'t': '5℃',
#   'hum': '26%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011015},
#  '2018011016': {'t': '5℃',
#   'hum': '28%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011016},
#  '2018011017': {'t': '4℃',
#   'hum': '36%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011017},
#  '2018011018': {'t': '3℃',
#   'hum': '38%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011018},
#  '2018011019': {'t': '1℃',
#   'hum': '50%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011019},
#  '2018011020': {'t': '2℃',
#   'hum': '37%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011020},
#  '2018011021': {'t': '2℃',
#   'hum': '37%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011021},
#  '2018011022': {'t': '1℃',
#   'hum': '43%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011022},
#  '2018011023': {'t': '1℃',
#   'hum': '43%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011023},
#  '2018011105': {'t': '-3℃',
#   'hum': '80%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011105},
#  '2018011106': {'t': '-3℃',
#   'hum': '80%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011106},
#  '2018011107': {'t': '-3℃',
#   'hum': '79%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011107},
#  '2018011108': {'t': '1℃',
#   'hum': '49%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011108},
#  '2018011109': {'t': '3℃',
#   'hum': '37%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011109},
#  '2018011110': {'t': '3℃',
#   'hum': '27%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011110},
#  '2018011111': {'t': '4℃',
#   'hum': '24%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011111},
#  '2018011112': {'t': '5℃',
#   'hum': '25%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011112},
#  '2018011113': {'t': '5℃',
#   'hum': '23%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011113},
#  '2018011114': {'t': '5℃',
#   'hum': '25%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011114},
#  '2018011115': {'t': '5℃',
#   'hum': '33%',
#   'weather': '晴',
#   'wind': '5级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011115},
#  '2018011116': {'t': '5℃',
#   'hum': '24%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011116},
#  '2018011117': {'t': '4℃',
#   'hum': '31%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011117},
#  '2018011118': {'t': '3℃',
#   'hum': '39%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011118},
#  '2018011119': {'t': '3℃',
#   'hum': '39%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011119},
#  '2018011120': {'t': '1℃',
#   'hum': '52%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011120},
#  '2018011121': {'t': '1℃',
#   'hum': '52%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011121},
#  '2018011122': {'t': '0℃',
#   'hum': '58%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011122},
#  '2018011123': {'t': '0℃',
#   'hum': '58%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011123},
#  '2018011205': {'t': '-3℃',
#   'hum': '53%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011205},
#  '2018011206': {'t': '-3℃',
#   'hum': '53%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011206},
#  '2018011207': {'t': '-3℃',
#   'hum': '53%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011207},
#  '2018011208': {'t': '-1℃',
#   'hum': '45%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011208},
#  '2018011209': {'t': '0℃',
#   'hum': '41%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011209},
#  '2018011210': {'t': '0℃',
#   'hum': '37%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011210},
#  '2018011211': {'t': '1℃',
#   'hum': '28%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011211},
#  '2018011212': {'t': '2℃',
#   'hum': '29%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011212},
#  '2018011213': {'t': '2℃',
#   'hum': '25%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011213},
#  '2018011214': {'t': '3℃',
#   'hum': '24%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011214},
#  '2018011215': {'t': '3℃',
#   'hum': '23%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011215},
#  '2018011216': {'t': '2℃',
#   'hum': '24%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011216},
#  '2018011217': {'t': '0℃',
#   'hum': '26%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011217},
#  '2018011218': {'t': '0℃',
#   'hum': '34%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011218},
#  '2018011219': {'t': '-1℃',
#   'hum': '42%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011219},
#  '2018011220': {'t': '-3℃',
#   'hum': '60%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011220},
#  '2018011221': {'t': '-3℃',
#   'hum': '60%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011221},
#  '2018011222': {'t': '-4℃',
#   'hum': '72%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011222},
#  '2018011223': {'t': '-4℃',
#   'hum': '72%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011223},
#  '2018011305': {'t': '-6℃',
#   'hum': '88%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011305},
#  '2018011306': {'t': '-6℃',
#   'hum': '88%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011306},
#  '2018011307': {'t': '-5℃',
#   'hum': '89%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011307},
#  '2018011308': {'t': '0℃',
#   'hum': '56%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011308},
#  '2018011309': {'t': '2℃',
#   'hum': '40%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011309},
#  '2018011310': {'t': '4℃',
#   'hum': '32%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011310},
#  '2018011311': {'t': '5℃',
#   'hum': '30%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011311},
#  '2018011312': {'t': '5℃',
#   'hum': '39%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011312},
#  '2018011313': {'t': '5℃',
#   'hum': '37%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011313},
#  '2018011314': {'t': '6℃',
#   'hum': '35%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011314},
#  '2018011315': {'t': '5℃',
#   'hum': '36%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011315},
#  '2018011316': {'t': '4℃',
#   'hum': '38%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011316},
#  '2018011317': {'t': '3℃',
#   'hum': '46%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011317},
#  '2018011318': {'t': '3℃',
#   'hum': '56%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011318},
#  '2018011319': {'t': '3℃',
#   'hum': '60%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011319},
#  '2018011320': {'t': '2℃',
#   'hum': '57%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011320},
#  '2018011321': {'t': '2℃',
#   'hum': '57%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011321},
#  '2018011322': {'t': '2℃',
#   'hum': '62%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011322},
#  '2018011323': {'t': '2℃',
#   'hum': '62%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011323},
#  '2018011405': {'t': '3℃',
#   'hum': '77%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011405},
#  '2018011406': {'t': '3℃',
#   'hum': '77%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011406},
#  '2018011407': {'t': '3℃',
#   'hum': '83%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011407},
#  '2018011408': {'t': '5℃',
#   'hum': '75%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011408},
#  '2018011409': {'t': '7℃',
#   'hum': '68%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011409},
#  '2018011410': {'t': '10℃',
#   'hum': '56%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011410},
#  '2018011411': {'t': '11℃',
#   'hum': '49%',
#   'weather': '多云',
#   'wind': '3级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011411},
#  '2018011412': {'t': '11℃',
#   'hum': '50%',
#   'weather': '多云',
#   'wind': '3级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011412},
#  '2018011413': {'t': '12℃',
#   'hum': '50%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011413},
#  '2018011414': {'t': '11℃',
#   'hum': '50%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011414},
#  '2018011415': {'t': '11℃',
#   'hum': '50%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011415},
#  '2018011416': {'t': '10℃',
#   'hum': '52%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011416},
#  '2018011417': {'t': '8℃',
#   'hum': '65%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011417},
#  '2018011418': {'t': '5℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011418},
#  '2018011419': {'t': '4℃',
#   'hum': '88%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011419},
#  '2018011420': {'t': '3℃',
#   'hum': '94%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011420},
#  '2018011421': {'t': '3℃',
#   'hum': '94%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011421},
#  '2018011422': {'t': '2℃',
#   'hum': '96%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011422},
#  '2018011423': {'t': '2℃',
#   'hum': '96%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011423},
#  '2018011505': {'t': '0℃',
#   'hum': '97%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011505},
#  '2018011506': {'t': '0℃',
#   'hum': '97%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011506},
#  '2018011507': {'t': '1℃',
#   'hum': '98%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011507},
#  '2018011508': {'t': '6℃',
#   'hum': '98%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011508},
#  '2018011509': {'t': '10℃',
#   'hum': '68%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011509},
#  '2018011510': {'t': '13℃',
#   'hum': '47%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011510},
#  '2018011511': {'t': '15℃',
#   'hum': '38%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011511},
#  '2018011512': {'t': '15℃',
#   'hum': '37%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011512},
#  '2018011513': {'t': '16℃',
#   'hum': '36%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011513},
#  '2018011514': {'t': '16℃',
#   'hum': '43%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011514},
#  '2018011515': {'t': '15℃',
#   'hum': '52%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011515},
#  '2018011516': {'t': '14℃',
#   'hum': '68%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011516},
#  '2018011517': {'t': '12℃',
#   'hum': '75%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011517},
#  '2018011518': {'t': '11℃',
#   'hum': '86%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011518},
#  '2018011519': {'t': '10℃',
#   'hum': '91%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011519},
#  '2018011520': {'t': '9℃',
#   'hum': '94%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011520},
#  '2018011521': {'t': '9℃',
#   'hum': '94%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011521},
#  '2018011522': {'t': '9℃',
#   'hum': '96%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011522},
#  '2018011523': {'t': '9℃',
#   'hum': '96%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011523},
#  '2018011605': {'t': '11℃',
#   'hum': '98%',
#   'weather': '雾',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011605},
#  '2018011606': {'t': '11℃',
#   'hum': '98%',
#   'weather': '雾',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011606},
#  '2018011607': {'t': '11℃',
#   'hum': '98%',
#   'weather': '雾',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011607},
#  '2018011608': {'t': '11℃',
#   'hum': '98%',
#   'weather': '雾',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011608},
#  '2018011609': {'t': '12℃',
#   'hum': '98%',
#   'weather': '雾',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011609},
#  '2018011610': {'t': '12℃',
#   'hum': '98%',
#   'weather': '雾',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011610},
#  '2018011611': {'t': '13℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011611},
#  '2018011612': {'t': '14℃',
#   'hum': '69%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011612},
#  '2018011613': {'t': '14℃',
#   'hum': '66%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011613},
#  '2018011614': {'t': '13℃',
#   'hum': '73%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011614},
#  '2018011615': {'t': '13℃',
#   'hum': '71%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011615},
#  '2018011616': {'t': '13℃',
#   'hum': '66%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011616},
#  '2018011617': {'t': '12℃',
#   'hum': '75%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011617},
#  '2018011618': {'t': '12℃',
#   'hum': '78%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011618},
#  '2018011619': {'t': '11℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011619},
#  '2018011620': {'t': '10℃',
#   'hum': '85%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011620},
#  '2018011621': {'t': '10℃',
#   'hum': '85%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011621},
#  '2018011622': {'t': '10℃',
#   'hum': '86%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011622},
#  '2018011623': {'t': '10℃',
#   'hum': '86%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011623},
#  '2018011705': {'t': '8℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011705},
#  '2018011706': {'t': '8℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011706},
#  '2018011707': {'t': '8℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011707},
#  '2018011708': {'t': '8℃',
#   'hum': '77%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011708},
#  '2018011709': {'t': '9℃',
#   'hum': '74%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011709},
#  '2018011710': {'t': '11℃',
#   'hum': '65%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011710},
#  '2018011711': {'t': '11℃',
#   'hum': '63%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011711},
#  '2018011712': {'t': '12℃',
#   'hum': '58%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011712},
#  '2018011713': {'t': '12℃',
#   'hum': '56%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011713},
#  '2018011714': {'t': '12℃',
#   'hum': '57%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011714},
#  '2018011715': {'t': '12℃',
#   'hum': '59%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011715},
#  '2018011716': {'t': '11℃',
#   'hum': '62%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011716},
#  '2018011717': {'t': '10℃',
#   'hum': '68%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011717},
#  '2018011718': {'t': '9℃',
#   'hum': '72%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011718},
#  '2018011719': {'t': '8℃',
#   'hum': '83%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011719},
#  '2018011720': {'t': '7℃',
#   'hum': '84%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011720},
#  '2018011721': {'t': '7℃',
#   'hum': '84%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011721},
#  '2018011722': {'t': '7℃',
#   'hum': '83%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011722},
#  '2018011723': {'t': '7℃',
#   'hum': '83%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011723},
#  '2018011805': {'t': '7℃',
#   'hum': '86%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011805},
#  '2018011806': {'t': '7℃',
#   'hum': '86%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011806},
#  '2018011807': {'t': '7℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011807},
#  '2018011808': {'t': '8℃',
#   'hum': '72%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011808},
#  '2018011809': {'t': '8℃',
#   'hum': '71%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011809},
#  '2018011810': {'t': '9℃',
#   'hum': '67%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011810},
#  '2018011811': {'t': '10℃',
#   'hum': '61%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011811},
#  '2018011812': {'t': '10℃',
#   'hum': '59%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011812},
#  '2018011813': {'t': '10℃',
#   'hum': '64%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011813},
#  '2018011814': {'t': '9℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011814},
#  '2018011815': {'t': '9℃',
#   'hum': '72%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011815},
#  '2018011816': {'t': '8℃',
#   'hum': '72%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011816},
#  '2018011817': {'t': '8℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011817},
#  '2018011818': {'t': '8℃',
#   'hum': '68%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011818},
#  '2018011819': {'t': '8℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011819},
#  '2018011820': {'t': '8℃',
#   'hum': '70%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011820},
#  '2018011821': {'t': '8℃',
#   'hum': '70%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011821},
#  '2018011822': {'t': '8℃',
#   'hum': '68%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011822},
#  '2018011823': {'t': '8℃',
#   'hum': '68%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011823},
#  '2018011905': {'t': '8℃',
#   'hum': '76%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011905},
#  '2018011906': {'t': '8℃',
#   'hum': '76%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011906},
#  '2018011907': {'t': '8℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011907},
#  '2018011908': {'t': '7℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011908},
#  '2018011909': {'t': '8℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011909},
#  '2018011910': {'t': '8℃',
#   'hum': '73%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011910},
#  '2018011911': {'t': '9℃',
#   'hum': '74%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011911},
#  '2018011912': {'t': '8℃',
#   'hum': '83%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011912},
#  '2018011913': {'t': '8℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011913},
#  '2018011914': {'t': '8℃',
#   'hum': '81%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011914},
#  '2018011915': {'t': '8℃',
#   'hum': '81%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011915},
#  '2018011916': {'t': '8℃',
#   'hum': '81%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011916},
#  '2018011917': {'t': '8℃',
#   'hum': '81%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011917},
#  '2018011918': {'t': '8℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011918},
#  '2018011919': {'t': '8℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011919},
#  '2018011920': {'t': '8℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011920},
#  '2018011921': {'t': '8℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011921},
#  '2018011922': {'t': '8℃',
#   'hum': '79%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011922},
#  '2018011923': {'t': '8℃',
#   'hum': '79%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011923},
#  '2018012005': {'t': '7℃',
#   'hum': '75%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012005},
#  '2018012006': {'t': '7℃',
#   'hum': '75%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012006},
#  '2018012007': {'t': '7℃',
#   'hum': '71%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012007},
#  '2018012008': {'t': '7℃',
#   'hum': '67%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012008},
#  '2018012009': {'t': '7℃',
#   'hum': '71%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012009},
#  '2018012010': {'t': '7℃',
#   'hum': '74%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012010},
#  '2018012011': {'t': '7℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012011},
#  '2018012012': {'t': '6℃',
#   'hum': '84%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012012},
#  '2018012013': {'t': '6℃',
#   'hum': '85%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012013},
#  '2018012014': {'t': '6℃',
# ...
#   'wind': '2级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021607},
#  '2018021608': {'t': '4℃',
#   'hum': '92%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021608},
#  '2018021609': {'t': '4℃',
#   'hum': '90%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021609},
#  '2018021610': {'t': '4℃',
#   'hum': '88%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021610},
#  '2018021611': {'t': '4℃',
#   'hum': '87%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021611},
#  '2018021612': {'t': '5℃',
#   'hum': '87%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021612},
#  '2018021613': {'t': '6℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021613},
#  '2018021614': {'t': '5℃',
#   'hum': '83%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021614},
#  '2018021615': {'t': '5℃',
#   'hum': '79%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021615},
#  '2018021616': {'t': '6℃',
#   'hum': '78%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021616},
#  '2018021617': {'t': '5℃',
#   'hum': '81%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021617},
#  '2018021618': {'t': '5℃',
#   'hum': '83%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021618},
#  '2018021619': {'t': '5℃',
#   'hum': '83%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021619},
#  '2018021620': {'t': '5℃',
#   'hum': '77%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021620},
#  '2018021621': {'t': '5℃',
#   'hum': '77%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021621},
#  '2018021622': {'t': '4℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021622},
#  '2018021623': {'t': '4℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021623},
#  '2018021705': {'t': '0℃',
#   'hum': '97%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021705},
#  '2018021706': {'t': '0℃',
#   'hum': '97%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021706},
#  '2018021707': {'t': '1℃',
#   'hum': '97%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021707},
#  '2018021708': {'t': '5℃',
#   'hum': '77%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021708},
#  '2018021709': {'t': '6℃',
#   'hum': '62%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021709},
#  '2018021710': {'t': '8℃',
#   'hum': '61%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021710},
#  '2018021711': {'t': '9℃',
#   'hum': '59%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021711},
#  '2018021712': {'t': '10℃',
#   'hum': '50%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021712},
#  '2018021713': {'t': '10℃',
#   'hum': '52%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021713},
#  '2018021714': {'t': '10℃',
#   'hum': '51%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021714},
#  '2018021715': {'t': '10℃',
#   'hum': '51%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021715},
#  '2018021716': {'t': '8℃',
#   'hum': '55%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021716},
#  '2018021717': {'t': '7℃',
#   'hum': '65%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021717},
#  '2018021718': {'t': '6℃',
#   'hum': '70%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021718},
#  '2018021719': {'t': '5℃',
#   'hum': '74%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021719},
#  '2018021720': {'t': '5℃',
#   'hum': '74%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021720},
#  '2018021721': {'t': '5℃',
#   'hum': '74%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021721},
#  '2018021722': {'t': '5℃',
#   'hum': '80%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021722},
#  '2018021723': {'t': '5℃',
#   'hum': '80%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021723},
#  '2018021805': {'t': '7℃',
#   'hum': '78%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021805},
#  '2018021806': {'t': '7℃',
#   'hum': '78%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021806},
#  '2018021807': {'t': '7℃',
#   'hum': '83%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021807},
#  '2018021808': {'t': '8℃',
#   'hum': '78%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021808},
#  '2018021809': {'t': '8℃',
#   'hum': '79%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021809},
#  '2018021810': {'t': '10℃',
#   'hum': '73%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021810},
#  '2018021811': {'t': '10℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021811},
#  '2018021812': {'t': '11℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021812},
#  '2018021813': {'t': '10℃',
#   'hum': '75%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021813},
#  '2018021814': {'t': '10℃',
#   'hum': '77%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021814},
#  '2018021815': {'t': '9℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021815},
#  '2018021816': {'t': '8℃',
#   'hum': '88%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021816},
#  '2018021817': {'t': '8℃',
#   'hum': '88%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021817},
#  '2018021818': {'t': '7℃',
#   'hum': '92%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021818},
#  '2018021819': {'t': '7℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021819},
#  '2018021820': {'t': '7℃',
#   'hum': '95%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021820},
#  '2018021821': {'t': '7℃',
#   'hum': '95%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021821},
#  '2018021822': {'t': '7℃',
#   'hum': '96%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021822},
#  '2018021823': {'t': '7℃',
#   'hum': '96%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021823},
#  '2018021905': {'t': '6℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021905},
#  '2018021906': {'t': '6℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021906},
#  '2018021907': {'t': '7℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021907},
#  '2018021908': {'t': '7℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021908},
#  '2018021909': {'t': '7℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021909},
#  '2018021910': {'t': '7℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021910},
#  '2018021911': {'t': '8℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021911},
#  '2018021912': {'t': '8℃',
#   'hum': '96%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021912},
#  '2018021913': {'t': '7℃',
#   'hum': '96%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021913},
#  '2018021914': {'t': '7℃',
#   'hum': '95%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021914},
#  '2018021915': {'t': '7℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021915},
#  '2018021916': {'t': '6℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021916},
#  '2018021917': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021917},
#  '2018021918': {'t': '5℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021918},
#  '2018021919': {'t': '5℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021919},
#  '2018021920': {'t': '6℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021920},
#  '2018021921': {'t': '6℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021921},
#  '2018021922': {'t': '6℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021922},
#  '2018021923': {'t': '6℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021923},
#  '2018022005': {'t': '6℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022005},
#  '2018022006': {'t': '6℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022006},
#  '2018022007': {'t': '6℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022007},
#  '2018022008': {'t': '6℃',
#   'hum': '76%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022008},
#  '2018022009': {'t': '8℃',
#   'hum': '69%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022009},
#  '2018022010': {'t': '8℃',
#   'hum': '69%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022010},
#  '2018022011': {'t': '8℃',
#   'hum': '75%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022011},
#  '2018022012': {'t': '8℃',
#   'hum': '74%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022012},
#  '2018022013': {'t': '8℃',
#   'hum': '79%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022013},
#  '2018022014': {'t': '7℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022014},
#  '2018022015': {'t': '7℃',
#   'hum': '91%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022015},
#  '2018022016': {'t': '6℃',
#   'hum': '85%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022016},
#  '2018022017': {'t': '5℃',
#   'hum': '91%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022017},
#  '2018022018': {'t': '4℃',
#   'hum': '90%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022018},
#  '2018022019': {'t': '4℃',
#   'hum': '91%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022019},
#  '2018022020': {'t': '4℃',
#   'hum': '92%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022020},
#  '2018022021': {'t': '4℃',
#   'hum': '92%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022021},
#  '2018022022': {'t': '4℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022022},
#  '2018022023': {'t': '4℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022023},
#  '2018022105': {'t': '4℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022105},
#  '2018022106': {'t': '4℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022106},
#  '2018022107': {'t': '5℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022107},
#  '2018022108': {'t': '6℃',
#   'hum': '86%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022108},
#  '2018022109': {'t': '6℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022109},
#  '2018022110': {'t': '7℃',
#   'hum': '73%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022110},
#  '2018022111': {'t': '8℃',
#   'hum': '68%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022111},
#  '2018022112': {'t': '8℃',
#   'hum': '70%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022112},
#  '2018022113': {'t': '8℃',
#   'hum': '67%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022113},
#  '2018022114': {'t': '7℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022114},
#  '2018022115': {'t': '7℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022115},
#  '2018022116': {'t': '6℃',
#   'hum': '73%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022116},
#  '2018022117': {'t': '6℃',
#   'hum': '76%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022117},
#  '2018022118': {'t': '5℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '0级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022118},
#  '2018022119': {'t': '5℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022119},
#  '2018022120': {'t': '5℃',
#   'hum': '83%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022120},
#  '2018022121': {'t': '5℃',
#   'hum': '83%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022121},
#  '2018022122': {'t': '5℃',
#   'hum': '82%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022122},
#  '2018022123': {'t': '5℃',
#   'hum': '82%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022123},
#  '2018022205': {'t': '4℃',
#   'hum': '89%',
#   'weather': '阴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022205},
#  '2018022206': {'t': '4℃',
#   'hum': '89%',
#   'weather': '阴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022206},
#  '2018022207': {'t': '5℃',
#   'hum': '85%',
#   'weather': '阴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022207},
#  '2018022208': {'t': '6℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022208},
#  '2018022209': {'t': '8℃',
#   'hum': '64%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022209},
#  '2018022210': {'t': '8℃',
#   'hum': '62%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022210},
#  '2018022211': {'t': '8℃',
#   'hum': '59%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022211},
#  '2018022212': {'t': '8℃',
#   'hum': '65%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022212},
#  '2018022213': {'t': '9℃',
#   'hum': '57%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022213},
#  '2018022214': {'t': '9℃',
#   'hum': '53%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022214},
#  '2018022215': {'t': '9℃',
#   'hum': '55%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022215},
#  '2018022216': {'t': '9℃',
#   'hum': '56%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022216},
#  ...}

# %%
# 看是否存在缺失值
csv_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 7 columns):
# ID                  65538 non-null int64
# W_C_AREA_CODE       65538 non-null object
# TJ_TIME             65538 non-null object
# IN_TOTAL            65538 non-null int64
# OUT_TOTAL           65538 non-null int64
# REMARK              65538 non-null int64
# W_M_WAYKIND_NAME    65538 non-null object
# dtypes: int64(4), object(3)
# memory usage: 3.5+ MB

# %%
# 将数据整理成date -> data 的字典
# dataFrame: read data 2018/01/01-2018/04/25
csv_batch_data = csv_data
# values dataFrame->array  Transfer array data to dictionary:
print('csv_data shape:', csv_batch_data.shape)
# train_batch_data = csv_batch_data[list(range(3, 6))]  取3:5列
# dataFrame 取行
train_batch_data = csv_batch_data[1:]
#  按照机器类型，将数据分为两组
# 314684 row 之后只有machine1 数据
machine1_data = []
machine2_data = []
# data 为list： ID 0 , W_C_AREA_CODE 1, Time 2, In_total 3, Out_total 4.  DataFrame.values -> array
for data in train_batch_data.values:  
    if data[1] == '05-19-10':
        # list of array -> [ID 0 , W_C_AREA_CODE 1, Time 2, In_total 3, Out_total 4]
        machine1_data.append(data)
    elif data[1] == '04-17-03':
        machine2_data.append(data)
    else:
        print("machine type error!")
# Passenger flow =  In_total + Out_total
print('machine1_data shape:', len(machine1_data))
print('machine2_data shape:', len(machine2_data))
# Out:
# csv_data shape: (65538, 7)
# machine1_data shape: 32599
# machine2_data shape: 32938

# %% [markdown]
# ### 5.2.2 提取闸机数据，转换为小时的客流量数据

# %%
"""
统计小时划分的客流量数据 > data_set1({datehour:[date,weather,week,holiday,high_tmp,low_tmp,wind]}) and target_set1:{datehour:flow} 
"""
import pdb
# [Time 2, In_total 3, Out_total 4] -> machine_data: [Date 0, hour 1, In_total 3, Out_total 4] 
# data_set and target_set 按照日期-时段为key进行划分
# 小时统计算法：记录第一个点record = record(h0), 遍历，if date-hour not changed, update flow, else: dict[date-h_pre] = flow - record, update record = flow.
data_set1 = {}
data_set2= {}
target_set1 = {}
target_set2 = {}

# print(machine1_data) : [Date 0, hour 1, In_total 3, Out_total 4]

# %%
def get_hour_data(machine1_data, data_set1, target_set1):
    record = 0
    flow = 0
    flag_start = True
    date_start = True
    pre_date = 0
    for i in range(len(machine1_data)):
        machine1_data[i][0], machine1_data[i][1] = transfer_time(machine1_data[i][2])
        in_total = machine1_data[i][3]
        out_total = machine1_data[i][4]
        date = machine1_data[i][0]
        hour = machine1_data[i][1]
        if int(hour)>=0 and int(hour)<=4:
            continue
        if flag_start:
            key_start = date + hour
            flag_start = False
        if date_start:
            pre_date = date
            date_start = False
        key = date + hour #2019010100
        # In the same hour: update flow
        if key == key_start:
            flow = (in_total + out_total)
        else:
        # change to next hour:
            # change to next day: record --> 0
            if date != pre_date:
                pre_date = date
                target_set1[key_start] = flow - record
                data_set1[key_start] = json_data[key_start]   # key_start: pre key
                record = 0
                flow = in_total + out_total
            else:
                target_set1[key_start] = flow - record
                data_set1[key_start] = json_data[key_start]
                record = flow
            key_start = key

# %%
get_hour_data(machine1_data, data_set1, target_set1)
get_hour_data(machine2_data, data_set2, target_set2)
print(len(target_set1),len(target_set2))
# Out:
# 2184 2184

# %%
# Traversal data_set1 and Add Passenger-flow in target_set1 and target_set2 with same date-hour
# Use data_set1 and target_set as Input and Output raw data
target_set = {}
for key in target_set1:
    if key in target_set2:
        target_set[key] = target_set1[key] + target_set2[key]
print(len(target_set))
# Out:
# 2184

# %%
def plot_week(target_set):
    fig= plt.figure(figsize=(12,5))
    y = []
    x_data = list(target_set.keys())
    x = x_data[19:153]
    for key in x:
        y.append(target_set[key])
    y = np.array(y)
    x_data = np.linspace(0, 135, len(y))
    #x_data = np.array(x_data)
    plt.plot(x_data,y,'b-',lw=1)

# %%
# 输出一天Passenger Flow / h 实际值   --> machine 1
plot_week(target_set1)
plot_week(target_set2)
plot_week(target_set)

# %%
"""
Plot hour_flow figure:
"""
# 输出一天Passenger Flow / h 实际值  --> machine 2
fig= plt.figure(figsize=(12,5))
y = []
x_data = list(target_set.keys())
x = x_data[0:600]
for key in x:
    y.append(target_set[key])
y = np.array(y)
x_data = np.linspace(0, 500, len(y))
#x_data = np.array(x_data)
plt.plot(x_data,y,'g-',lw=1)

# %%
"""
Plot dict_holiday figure: 节假日情况分布 
"week day 0, holiday in law 1, make up for working 2，weekend 3 "
"""
# 输出一天Passenger Flow / h 实际值  --> machine 2
holiday = []
for value in json_data.values():
    holiday.append(value['holiday'])
fig= plt.figure(figsize=(12,5))
y = []
y = holiday
y = np.array(y)
x_data = np.linspace(0, 115, len(y))
#x_data = np.array(x_data)
plt.scatter(x_data,y)

# %%
# 两个machine的数据不对称，先放弃machine2， 对machine1的数据进行分析

# %% [markdown]
# 标准化： $X_t = \frac {X - mean} {std}$
# 计算客流量累加值为/1 hour 的时段值

# %% [markdown]
# ### 5.3 搭建神经网络预测模型

# %% [markdown]
# #### 5.3.1 网络输入数据标准化

# %%
data_set1.values()
# Out:
# dict_values([{'t': '2℃', 'hum': '91%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010105}, {'t': '2℃', 'hum': '91%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010106}, {'t': '2℃', 'hum': '94%', 'weather': '晴', 'wind': '0级', 'holiday': 1, 'week': 1, 'date': 2018010107}, {'t': '5℃', 'hum': '76%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010108}, {'t': '7℃', 'hum': '56%', 'weather': '晴', 'wind': '2级', 'holiday': 1, 'week': 1, 'date': 2018010109}, {'t': '9℃', 'hum': '36%', 'weather': '晴', 'wind': '2级', 'holiday': 1, 'week': 1, 'date': 2018010110}, {'t': '10℃', 'hum': '34%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010111}, {'t': '10℃', 'hum': '24%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010112}, {'t': '11℃', 'hum': '29%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010113}, {'t': '11℃', 'hum': '27%', 'weather': '晴', 'wind': '2级', 'holiday': 1, 'week': 1, 'date': 2018010114}, {'t': '11℃', 'hum': '30%', 'weather': '晴', 'wind': '2级', 'holiday': 1, 'week': 1, 'date': 2018010115}, {'t': '9℃', 'hum': '41%', 'weather': '晴', 'wind': '2级', 'holiday': 1, 'week': 1, 'date': 2018010116}, {'t': '7℃', 'hum': '54%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010117}, {'t': '6℃', 'hum': '66%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010118}, {'t': '5℃', 'hum': '72%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010119}, {'t': '6℃', 'hum': '70%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010120}, {'t': '6℃', 'hum': '70%', 'weather': '晴', 'wind': '1级', 'holiday': 1, 'week': 1, 'date': 2018010121}, {'t': '7℃', 'hum': '70%', 'weather': '多云', 'wind': '2级', 'holiday': 1, 'week': 1, 'date': 2018010122}, {'t': '7℃', 'hum': '70%', 'weather': '多云', 'wind': '2级', 'holiday': 1, 'week': 1, 'date': 2018010123}, {'t': '10℃', 'hum': '69%', 'weather': '多云', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010205}, {'t': '10℃', 'hum': '69%', 'weather': '多云', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010206}, {'t': '10℃', 'hum': '69%', 'weather': '多云', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010207}, {'t': '10℃', 'hum': '71%', 'weather': '多云', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010208}, {'t': '11℃', 'hum': '67%', 'weather': '多云', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010209}, {'t': '12℃', 'hum': '61%', 'weather': '多云', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010210}, {'t': '13℃', 'hum': '61%', 'weather': '多云', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010211}, {'t': '13℃', 'hum': '62%', 'weather': '多云', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010212}, {'t': '12℃', 'hum': '64%', 'weather': '多云', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010213}, {'t': '12℃', 'hum': '67%', 'weather': '阴', 'wind': '1级', 'holiday': 0, 'week': 2, 'date': 2018010214}, {'t': '12℃', 'hum': '71%', 'weather': '阴', 'wind': '1级', 'holiday': 0, 'week': 2, 'date': 2018010215}, {'t': '12℃', 'hum': '74%', 'weather': '阴', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010216}, {'t': '12℃', 'hum': '75%', 'weather': '阴', 'wind': '1级', 'holiday': 0, 'week': 2, 'date': 2018010217}, {'t': '11℃', 'hum': '77%', 'weather': '阴', 'wind': '1级', 'holiday': 0, 'week': 2, 'date': 2018010218}, {'t': '11℃', 'hum': '77%', 'weather': '阴', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010219}, {'t': '11℃', 'hum': '89%', 'weather': '阴', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010220}, {'t': '11℃', 'hum': '89%', 'weather': '阴', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010221}, {'t': '10℃', 'hum': '95%', 'weather': '阵雨', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010222}, {'t': '10℃', 'hum': '95%', 'weather': '阵雨', 'wind': '2级', 'holiday': 0, 'week': 2, 'date': 2018010223}, {'t': '7℃', 'hum': '92%', 'weather': '阴', 'wind': '2级', 'holiday': 0, 'wee ...

# %%
# data_set{datehour: {t:{int}, hum:{int}, weather:{label_encoder}, wind:{int}, holiday:{int}, week:{int}, date:{int},hour:{int}}}
# target_set{datehour: flow}
# dict_values -> obj -> list -> array
# >> data, target
x = []
dict_x = []
#enc.categories_ [array(['多云', '晴', '阴', '阵雨', '阵雪', '雨夹雪', '雾'], dtype='<U3')]
dict_weather={'晴':0, '多云':1,'阴':2, '雾':3,'阵雪':4,'阵雨':5,'雨夹雪':6}
weather = []
for value in data_set1.values():
    dict_x.append(value)
for value in dict_x:
    x.append(np.array(list(value.values())))
for value in x:
    weather.append(value[2])
weather = np.array(weather)
weather = weather.reshape(-1,1)
enc = OneHotEncoder(handle_unknown='ignore')
enc.fit(weather)
category = enc.categories_
weather = enc.transform(weather).toarray()
for i in range(len(x)):   
    x0 = int(x[i][0][:-1])# wind
    x1 = int(x[i][1][:-1])
    #     category = 0
    #     for j in range(len(weather[i])):
    #         category += j * weather[i][j]
    x2 = dict_weather[x[i][2]]
    x3 = int(x[i][3][:-1])
    x4 = int(x[i][4])
    x5 = int(x[i][5])
    x6 = int(x[i][6])
    x7 = int(x[i][6][-2:])
    x[i] = [x0,x1,x2,x3,x4,x5,x6,x7]
y = list(target_set.values())
data = np.array(x)
target = np.array(y)
mean = data.mean(axis=0)
# pdb.set_trace()
std = data.std(axis = 0)
# 数组中的每一个element都会减mean
data = (data - mean) / std
# target_set = (target_set - mean_y) / std_y

# %%
# 两个machine的数据不对称，先放弃machine2， 对machine1的数据进行分析
# >> target and data for input(train:test)
print(data.shape)
print(target.shape)
# Out:
# (2184, 8)
# (2184,)

# %% [markdown]
# ### Target variable
# Some analysis on target variable

# %%
plt.subplots(figsize=(12,9))
sns.distplot(target, fit=stats.norm)

# Get the fitted parameters used by the function

(mu, sigma) = stats.norm.fit(target)

# plot with the distribution

plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
plt.ylabel('Frequency')

#Probablity plot

fig = plt.figure()
stats.probplot(target, plot=plt)
plt.show()

# %% [markdown]
# #### Here we use log for target variable to make more normal distribution

# %% [markdown]
# #### 5.3.2 搭建网络框架

# %%
# input: data  Output: target

# %%
def build_model():
    model = Sequential()
    # 先将维度放大， 在高维空间中抽取特征  
    # Input: week, hour, date, weather
    model.add(Dense(128, activation='relu'))
    model.add(Dense(128, activation='relu'))    
    model.add(Dense(64, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(32, activation='relu'))    
    model.add(Dense(1))
    # 输出偏差矩阵 correspond to train_target
    model.compile(optimizer = RMSprop(), loss="mse", metrics=['mae'])
    return model

# %%
for i in range(len(target)):
    if target[i]<0:
        target[i] = 0

# %%
train_size = int(len(target) * 0.9)
train_data = data[ : train_size]
#print(train_data)
train_target = target[ : train_size]
test_data = data[train_size : ]
test_target = target[train_size : ]
print(len(train_data),len(test_data))
# Out:
# 1965 219

# %%
plt.figure(figsize=(15,8))    
x = np.linspace(0,2189,len(target))
plt.plot(x,target,'b-',lw=1)

# %% [markdown]
# # Correlation Analysis
# select features with correlation over 0.5

# %%
# t:{int}, hum:{int}, weather:{label_encoder}, wind:{int}, holiday:{int}, week:{int}, date:{int}
train = pd.DataFrame(np.c_[train_data,train_target],columns=['t','hum','weather','wind','holiday','week','date','hour','target'])

train.columns[train.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
plt.figure(figsize=(12,6))
sns.heatmap(train.isnull())
plt.show()

# %%
train_corr = train.select_dtypes(include = [np.number])
train_corr.shape
# Out:
# (1965, 9)

# %%
corr = train_corr.corr()
plt.subplots(figsize=(20,9))
sns.heatmap(corr,annot=True)

# %%
col = ['t','hum','weather','wind','holiday','week','date','hour','target'] 
sns.set(style= 'ticks')
sns.pairplot(train[col],height=3,kind='reg')

# %%
print("Find the most important features relative to target")
corr = train.corr()
corr.sort_values(['target'],ascending=False,inplace=True)
corr.target
# Out:
# Find the most important features relative to target
# target     1.000000
# t          0.356563
# wind       0.251369
# date       0.188718
# hour       0.151362
# week       0.007447
# holiday   -0.034089
# weather   -0.052107
# hum       -0.356297
# Name: target, dtype: float64

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
from scipy import stats
from time import perf_counter

# %% [markdown]
# [NN SVG](http://alexlenail.me/NN-SVG/index.html)

# %% [markdown]
# #### 5.3.3 训练神经网络

# %%
start_time = perf_counter()
num_epochs = 1000
all_scores = []
model = build_model()
# batch_size 训练进入的数据大小为1， verbose = 0 不输出训练数据
# Compile model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae'])
historys=model.fit(train_data, train_target, epochs = num_epochs, batch_size = 1, verbose = 2)
val_mse, val_mae = model.evaluate(test_data, test_target, verbose = 0)
all_scores.append(val_mae)
print("MSE:", val_mse,"MAE:",val_mae)
end_time = perf_counter()
trainingtime = end_time - start_time
print(trainingtime)
# Out:
# Epoch 1/1000
#  - 8s - loss: 130019519.8440 - mae: 9020.2363
# Epoch 2/1000
#  - 7s - loss: 90694157.5417 - mae: 7561.9854
# Epoch 3/1000
#  - 7s - loss: 73352791.9641 - mae: 6703.0425
# Epoch 4/1000
#  - 7s - loss: 45816306.6382 - mae: 5224.3047
# Epoch 5/1000
#  - 7s - loss: 37235374.0847 - mae: 4710.6987
# Epoch 6/1000
#  - 7s - loss: 34685423.2908 - mae: 4533.4390
# Epoch 7/1000
#  - 7s - loss: 32521182.8663 - mae: 4289.2539
# Epoch 8/1000
#  - 7s - loss: 30892621.5573 - mae: 4210.0195
# Epoch 9/1000
#  - 8s - loss: 27859322.7835 - mae: 3964.4861
# Epoch 10/1000
#  - 8s - loss: 26277408.6309 - mae: 3834.0200
# Epoch 11/1000
#  - 8s - loss: 24232247.7968 - mae: 3652.0249
# Epoch 12/1000
#  - 8s - loss: 23251846.5349 - mae: 3588.4297
# Epoch 13/1000
#  - 8s - loss: 22112479.2392 - mae: 3462.1265
# Epoch 14/1000
#  - 8s - loss: 20272691.8639 - mae: 3358.7795
# Epoch 15/1000
#  - 8s - loss: 19348970.7270 - mae: 3219.5940
# Epoch 16/1000
#  - 8s - loss: 18746141.0018 - mae: 3196.3499
# Epoch 17/1000
#  - 8s - loss: 17576507.5211 - mae: 3126.3015
# Epoch 18/1000
#  - 8s - loss: 16326254.4044 - mae: 2983.9907
# Epoch 19/1000
#  - 8s - loss: 16291018.1917 - mae: 2995.6301
# Epoch 20/1000
#  - 8s - loss: 15748819.9466 - mae: 2932.5164
# Epoch 21/1000
#  - 8s - loss: 14709804.2169 - mae: 2801.6106
# Epoch 22/1000
#  - 8s - loss: 14118194.8509 - mae: 2792.3352
# Epoch 23/1000
#  - 8s - loss: 13534967.7268 - mae: 2722.3000
# Epoch 24/1000
#  - 8s - loss: 13777534.4830 - mae: 2768.9934
# Epoch 25/1000
#  - 8s - loss: 12570921.6010 - mae: 2624.0781
# Epoch 26/1000
#  - 8s - loss: 11694539.9433 - mae: 2563.2527
# Epoch 27/1000
#  - 8s - loss: 12447399.3097 - mae: 2622.4412
# Epoch 28/1000
#  - 8s - loss: 10771429.9167 - mae: 2443.6074
# Epoch 29/1000
#  - 8s - loss: 11015033.7379 - mae: 2461.5520
# Epoch 30/1000
#  - 8s - loss: 10186527.0350 - mae: 2369.0955
# Epoch 31/1000
#  - 8s - loss: 11003556.1826 - mae: 2419.5703
# Epoch 32/1000
#  - 8s - loss: 9675981.0282 - mae: 2313.9541
# Epoch 33/1000
#  - 8s - loss: 9773635.1341 - mae: 2291.1079
# Epoch 34/1000
#  - 8s - loss: 9749536.2596 - mae: 2319.8462
# Epoch 35/1000
#  - 8s - loss: 9346211.3917 - mae: 2239.5193
# Epoch 36/1000
#  - 8s - loss: 8776168.3089 - mae: 2193.6003
# Epoch 37/1000
#  - 8s - loss: 8642896.5209 - mae: 2170.7312
# Epoch 38/1000
#  - 8s - loss: 8918351.1700 - mae: 2229.7527
# Epoch 39/1000
#  - 8s - loss: 8315260.2688 - mae: 2160.2410
# Epoch 40/1000
#  - 8s - loss: 8819995.0126 - mae: 2163.2668
# Epoch 41/1000
#  - 8s - loss: 7651396.3066 - mae: 2039.5896
# Epoch 42/1000
#  - 8s - loss: 8375938.9194 - mae: 2129.1658
# Epoch 43/1000
#  - 8s - loss: 7365944.5048 - mae: 2032.7853
# Epoch 44/1000
#  - 8s - loss: 7112105.8153 - mae: 1992.1704
# Epoch 45/1000
#  - 8s - loss: 7609238.3626 - mae: 2058.7776
# Epoch 46/1000
#  - 8s - loss: 6864056.3772 - mae: 1936.9124
# Epoch 47/1000
#  - 8s - loss: 7233304.6911 - mae: 1989.7721
# Epoch 48/1000
#  - 8s - loss: 7257601.3842 - mae: 1983.0515
# Epoch 49/1000
#  - 8s - loss: 6279448.0538 - mae: 1871.0410
# Epoch 50/1000
#  - 8s - loss: 7118262.8471 - mae: 1939.7534
# Epoch 51/1000
#  - 8s - loss: 6136131.2407 - mae: 1860.5349
# Epoch 52/1000
#  - 8s - loss: 6561106.3779 - mae: 1921.7327
# Epoch 53/1000
#  - 8s - loss: 6211906.4758 - mae: 1846.9869
# Epoch 54/1000
#  - 8s - loss: 6096132.4622 - mae: 1835.8958
# Epoch 55/1000
#  - 8s - loss: 6099890.8668 - mae: 1827.1094
# Epoch 56/1000
#  - 8s - loss: 5712834.8710 - mae: 1770.8228
# Epoch 57/1000
#  - 8s - loss: 5808071.0054 - mae: 1803.3337
# Epoch 58/1000
#  - 8s - loss: 5819965.9689 - mae: 1768.7611
# Epoch 59/1000
#  - 8s - loss: 5803270.8364 - mae: 1792.3453
# Epoch 60/1000
#  - 8s - loss: 5594796.4062 - mae: 1742.8322
# Epoch 61/1000
#  - 8s - loss: 5480539.1648 - mae: 1739.5760
# Epoch 62/1000
#  - 8s - loss: 5615261.2470 - mae: 1743.6884
# Epoch 63/1000
#  - 8s - loss: 5127260.3769 - mae: 1663.3170
# Epoch 64/1000
#  - 8s - loss: 5230814.7944 - mae: 1676.1445
# Epoch 65/1000
#  - 8s - loss: 5545030.9314 - mae: 1727.4592
# Epoch 66/1000
#  - 8s - loss: 5329044.9640 - mae: 1696.6488
# Epoch 67/1000
#  - 8s - loss: 5191044.7278 - mae: 1668.0417
# Epoch 68/1000
#  - 8s - loss: 4928349.4017 - mae: 1638.9309
# Epoch 69/1000
#  - 8s - loss: 4969708.5778 - mae: 1627.7909
# Epoch 70/1000
#  - 7s - loss: 4848829.6840 - mae: 1642.4589
# Epoch 71/1000
#  - 8s - loss: 5125940.4969 - mae: 1673.3423
# Epoch 72/1000
#  - 8s - loss: 4758331.3445 - mae: 1601.6665
# Epoch 73/1000
#  - 8s - loss: 4409231.9271 - mae: 1524.8839
# Epoch 74/1000
#  - 8s - loss: 4498634.6824 - mae: 1582.6344
# Epoch 75/1000
#  - 8s - loss: 4603108.9037 - mae: 1594.5070
# Epoch 76/1000
#  - 8s - loss: 4581069.7725 - mae: 1555.6151
# Epoch 77/1000
#  - 8s - loss: 4377986.2429 - mae: 1510.3370
# Epoch 78/1000
#  - 8s - loss: 4201138.4472 - mae: 1502.7795
# Epoch 79/1000
#  - 8s - loss: 4486382.4606 - mae: 1546.5295
# Epoch 80/1000
#  - 8s - loss: 4172346.6756 - mae: 1508.5590
# Epoch 81/1000
#  - 8s - loss: 4047310.6826 - mae: 1501.6222
# Epoch 82/1000
#  - 8s - loss: 4288858.9899 - mae: 1511.7246
# Epoch 83/1000
#  - 8s - loss: 4030240.5036 - mae: 1464.1006
# Epoch 84/1000
#  - 8s - loss: 4191536.1626 - mae: 1511.0438
# Epoch 85/1000
#  - 8s - loss: 4204831.1225 - mae: 1493.9025
# Epoch 86/1000
#  - 8s - loss: 4228002.0211 - mae: 1490.4442
# Epoch 87/1000
#  - 8s - loss: 4124127.1677 - mae: 1471.8180
# Epoch 88/1000
#  - 8s - loss: 4101225.0918 - mae: 1495.6660
# Epoch 89/1000
#  - 8s - loss: 3957133.7887 - mae: 1430.3053
# Epoch 90/1000
#  - 8s - loss: 3926661.6802 - mae: 1426.8267
# Epoch 91/1000
#  - 8s - loss: 3965680.0301 - mae: 1439.3494
# Epoch 92/1000
#  - 8s - loss: 4000373.4988 - mae: 1450.6754
# Epoch 93/1000
#  - 8s - loss: 3445577.6137 - mae: 1382.0336
# Epoch 94/1000
#  - 8s - loss: 3833781.3772 - mae: 1425.8574
# Epoch 95/1000
#  - 8s - loss: 4065417.0870 - mae: 1474.1151
# Epoch 96/1000
#  - 8s - loss: 3378040.0025 - mae: 1339.3485
# Epoch 97/1000
#  - 8s - loss: 3682131.2909 - mae: 1410.3917
# Epoch 98/1000
#  - 8s - loss: 3755169.4843 - mae: 1413.0106
# Epoch 99/1000
#  - 8s - loss: 3263360.3701 - mae: 1322.5476
# Epoch 100/1000
#  - 8s - loss: 3454399.5903 - mae: 1360.5970
# Epoch 101/1000
#  - 8s - loss: 3312530.5272 - mae: 1330.8337
# Epoch 102/1000
#  - 8s - loss: 3620942.0249 - mae: 1369.9611
# Epoch 103/1000
#  - 8s - loss: 3334285.1989 - mae: 1328.1909
# Epoch 104/1000
#  - 8s - loss: 3430391.4947 - mae: 1344.2030
# Epoch 105/1000
#  - 8s - loss: 3402212.3900 - mae: 1344.9532
# Epoch 106/1000
#  - 8s - loss: 3456134.7750 - mae: 1346.4620
# Epoch 107/1000
#  - 8s - loss: 3314981.4567 - mae: 1332.8550
# Epoch 108/1000
#  - 8s - loss: 3199073.9419 - mae: 1292.9381
# Epoch 109/1000
#  - 8s - loss: 3312384.8083 - mae: 1320.4402
# Epoch 110/1000
#  - 8s - loss: 3071693.8752 - mae: 1299.1497
# Epoch 111/1000
#  - 8s - loss: 3283706.3155 - mae: 1295.2738
# Epoch 112/1000
#  - 8s - loss: 3023662.8478 - mae: 1287.5959
# Epoch 113/1000
#  - 8s - loss: 3220241.8158 - mae: 1294.7959
# Epoch 114/1000
#  - 8s - loss: 2659103.8844 - mae: 1191.5394
# Epoch 115/1000
#  - 8s - loss: 2962456.3339 - mae: 1280.8699
# Epoch 116/1000
#  - 8s - loss: 3037722.0093 - mae: 1290.8789
# Epoch 117/1000
#  - 8s - loss: 3148958.8403 - mae: 1298.6235
# Epoch 118/1000
#  - 8s - loss: 2921865.4484 - mae: 1237.4019
# Epoch 119/1000
#  - 8s - loss: 3005774.9163 - mae: 1253.3862
# Epoch 120/1000
#  - 8s - loss: 2776961.3923 - mae: 1248.6603
# Epoch 121/1000
#  - 8s - loss: 2669643.8695 - mae: 1207.4751
# Epoch 122/1000
#  - 8s - loss: 2852239.8324 - mae: 1231.8737
# Epoch 123/1000
#  - 8s - loss: 2978695.2933 - mae: 1263.6021
# Epoch 124/1000
#  - 8s - loss: 2944140.2345 - mae: 1245.7212
# Epoch 125/1000
#  - 8s - loss: 2658534.0488 - mae: 1204.5590
# Epoch 126/1000
#  - 8s - loss: 2808332.2270 - mae: 1224.0824
# Epoch 127/1000
#  - 8s - loss: 2621102.8868 - mae: 1182.7896
# Epoch 128/1000
#  - 8s - loss: 2823193.8653 - mae: 1218.1655
# Epoch 129/1000
#  - 8s - loss: 2519090.2971 - mae: 1135.6915
# Epoch 130/1000
#  - 8s - loss: 2594885.9762 - mae: 1179.9700
# Epoch 131/1000
#  - 8s - loss: 2592185.1877 - mae: 1203.7587
# Epoch 132/1000
#  - 8s - loss: 2711548.8847 - mae: 1179.6169
# Epoch 133/1000
#  - 8s - loss: 2818418.8996 - mae: 1214.4562
# Epoch 134/1000
#  - 8s - loss: 2616239.4957 - mae: 1151.6234
# Epoch 135/1000
#  - 8s - loss: 2756060.6629 - mae: 1187.4459
# Epoch 136/1000
#  - 8s - loss: 2337215.1968 - mae: 1124.0842
# Epoch 137/1000
#  - 8s - loss: 2426020.3837 - mae: 1145.0673
# Epoch 138/1000
#  - 8s - loss: 2868977.5408 - mae: 1199.2000
# Epoch 139/1000
#  - 8s - loss: 2668651.7627 - mae: 1193.8594
# Epoch 140/1000
#  - 8s - loss: 2489641.1589 - mae: 1122.4167
# Epoch 141/1000
#  - 8s - loss: 2202167.0883 - mae: 1076.8605
# Epoch 142/1000
#  - 8s - loss: 2835021.1275 - mae: 1172.4225
# Epoch 143/1000
#  - 8s - loss: 2203373.2395 - mae: 1088.6569
# Epoch 144/1000
#  - 8s - loss: 2394975.4151 - mae: 1149.4681
# Epoch 145/1000
#  - 8s - loss: 2441659.2649 - mae: 1141.2804
# Epoch 146/1000
#  - 8s - loss: 2404784.6200 - mae: 1115.0756
# Epoch 147/1000
#  - 8s - loss: 2731337.8742 - mae: 1196.6477
# Epoch 148/1000
#  - 8s - loss: 2334440.6486 - mae: 1095.4205
# Epoch 149/1000
#  - 8s - loss: 2462711.1859 - mae: 1113.2979
# Epoch 150/1000
#  - 8s - loss: 2325064.6655 - mae: 1099.1328
# Epoch 151/1000
#  - 8s - loss: 2388140.0835 - mae: 1128.6803
# Epoch 152/1000
#  - 8s - loss: 2248841.5289 - mae: 1097.7944
# Epoch 153/1000
#  - 8s - loss: 2376361.1223 - mae: 1125.9568
# Epoch 154/1000
#  - 8s - loss: 2300679.3617 - mae: 1091.9524
# Epoch 155/1000
#  - 8s - loss: 2252620.1502 - mae: 1088.8129
# Epoch 156/1000
#  - 8s - loss: 2084416.3443 - mae: 1066.1902
# Epoch 157/1000
#  - 8s - loss: 2313422.4410 - mae: 1096.7826
# Epoch 158/1000
#  - 8s - loss: 2103609.3108 - mae: 1054.4802
# Epoch 159/1000
#  - 8s - loss: 2214495.1036 - mae: 1083.2772
# Epoch 160/1000
#  - 8s - loss: 2339789.0213 - mae: 1088.3677
# Epoch 161/1000
#  - 7s - loss: 2334487.1261 - mae: 1104.5745
# Epoch 162/1000
#  - 8s - loss: 2289825.8303 - mae: 1088.8267
# Epoch 163/1000
#  - 8s - loss: 2255350.3680 - mae: 1055.2657
# Epoch 164/1000
#  - 8s - loss: 2083795.6669 - mae: 1037.1799
# Epoch 165/1000
#  - 8s - loss: 2216068.5772 - mae: 1057.7035
# Epoch 166/1000
#  - 8s - loss: 2096380.2853 - mae: 1035.9818
# Epoch 167/1000
#  - 8s - loss: 2176889.6963 - mae: 1055.3167
# Epoch 168/1000
#  - 8s - loss: 2125130.4349 - mae: 1063.8372
# Epoch 169/1000
#  - 8s - loss: 1918480.7302 - mae: 1010.9804
# Epoch 170/1000
#  - 8s - loss: 2054837.8179 - mae: 1035.0599
# Epoch 171/1000
#  - 8s - loss: 2305590.6927 - mae: 1076.3706
# Epoch 172/1000
#  - 8s - loss: 2308402.6621 - mae: 1077.4878
# Epoch 173/1000
#  - 8s - loss: 1949995.8844 - mae: 1003.9338
# Epoch 174/1000
#  - 7s - loss: 2063569.0732 - mae: 1035.8041
# Epoch 175/1000
#  - 7s - loss: 1953500.7602 - mae: 1016.2271
# Epoch 176/1000
#  - 8s - loss: 1998870.5899 - mae: 1024.6320
# Epoch 177/1000
#  - 8s - loss: 2178609.2860 - mae: 1079.9528
# Epoch 178/1000
#  - 8s - loss: 2142045.5080 - mae: 1036.7352
# Epoch 179/1000
#  - 8s - loss: 1970813.5543 - mae: 1022.9211
# Epoch 180/1000
#  - 8s - loss: 2102429.3323 - mae: 1015.1352
# Epoch 181/1000
#  - 8s - loss: 2167770.1266 - mae: 1022.4387
# Epoch 182/1000
#  - 8s - loss: 1820079.4321 - mae: 993.8551
# Epoch 183/1000
#  - 8s - loss: 2270371.1246 - mae: 1096.3818
# Epoch 184/1000
#  - 8s - loss: 1830474.6994 - mae: 979.0875
# Epoch 185/1000
#  - 8s - loss: 1952371.8298 - mae: 998.2227
# Epoch 186/1000
#  - 8s - loss: 1894345.0235 - mae: 997.5730
# Epoch 187/1000
#  - 8s - loss: 2047527.8692 - mae: 1032.3519
# Epoch 188/1000
#  - 7s - loss: 2201176.3589 - mae: 1044.7980
# Epoch 189/1000
#  - 7s - loss: 1977334.6519 - mae: 1012.3791
# Epoch 190/1000
#  - 8s - loss: 1980683.6496 - mae: 1010.7577
# Epoch 191/1000
#  - 8s - loss: 2225920.6274 - mae: 1055.5226
# Epoch 192/1000
#  - 8s - loss: 1705697.7055 - mae: 960.4572
# Epoch 193/1000
#  - 8s - loss: 1824644.1906 - mae: 1000.4435
# Epoch 194/1000
#  - 8s - loss: 2118056.3664 - mae: 1060.0217
# Epoch 195/1000
#  - 8s - loss: 1937122.5908 - mae: 988.2924
# Epoch 196/1000
#  - 8s - loss: 1805031.1750 - mae: 969.1268
# Epoch 197/1000
#  - 8s - loss: 1802099.6851 - mae: 962.5874
# Epoch 198/1000
#  - 8s - loss: 2090499.1585 - mae: 1009.7642
# Epoch 199/1000
#  - 8s - loss: 1973607.5507 - mae: 994.1885
# Epoch 200/1000
#  - 8s - loss: 1893291.2271 - mae: 999.9500
# Epoch 201/1000
#  - 8s - loss: 1738222.6925 - mae: 939.9973
# Epoch 202/1000
#  - 8s - loss: 1809041.8271 - mae: 977.1371
# Epoch 203/1000
#  - 7s - loss: 2329903.9065 - mae: 1085.7462
# Epoch 204/1000
#  - 8s - loss: 1655145.2640 - mae: 927.6324
# Epoch 205/1000
#  - 8s - loss: 1827173.7845 - mae: 972.4678
# Epoch 206/1000
#  - 8s - loss: 1924574.3334 - mae: 1000.6310
# Epoch 207/1000
#  - 7s - loss: 1598875.9740 - mae: 912.8184
# Epoch 208/1000
#  - 8s - loss: 1925355.8243 - mae: 983.6802
# Epoch 209/1000
#  - 8s - loss: 1576341.1760 - mae: 921.9615
# Epoch 210/1000
#  - 8s - loss: 1752927.7851 - mae: 950.7303
# Epoch 211/1000
#  - 8s - loss: 1791267.6180 - mae: 950.2430
# Epoch 212/1000
#  - 8s - loss: 1650407.4030 - mae: 942.2893
# Epoch 213/1000
#  - 8s - loss: 1709934.2253 - mae: 950.5603
# Epoch 214/1000
#  - 8s - loss: 1675751.4892 - mae: 943.9419
# Epoch 215/1000
#  - 8s - loss: 1786042.2224 - mae: 954.3989
# Epoch 216/1000
#  - 8s - loss: 1645726.5466 - mae: 920.4573
# Epoch 217/1000
#  - 8s - loss: 2100937.8067 - mae: 1001.6700
# Epoch 218/1000
#  - 8s - loss: 1527823.3125 - mae: 904.8314
# Epoch 219/1000
#  - 8s - loss: 1562676.2853 - mae: 916.0350
# Epoch 220/1000
#  - 8s - loss: 2148182.5999 - mae: 1020.9462
# Epoch 221/1000
#  - 8s - loss: 1839912.2085 - mae: 966.8016
# Epoch 222/1000
#  - 8s - loss: 2010118.2652 - mae: 978.5107
# Epoch 223/1000
#  - 8s - loss: 1417352.1982 - mae: 851.4967
# Epoch 224/1000
#  - 8s - loss: 1647604.0243 - mae: 939.6193
# Epoch 225/1000
#  - 8s - loss: 1531350.9988 - mae: 899.3116
# Epoch 226/1000
#  - 8s - loss: 1722654.9860 - mae: 930.7863
# Epoch 227/1000
#  - 8s - loss: 1761852.1087 - mae: 944.1980
# Epoch 228/1000
#  - 7s - loss: 1463094.3550 - mae: 873.3732
# Epoch 229/1000
#  - 8s - loss: 1686323.7649 - mae: 941.2908
# Epoch 230/1000
#  - 8s - loss: 1565314.8218 - mae: 902.6376
# Epoch 231/1000
#  - 8s - loss: 1538759.9431 - mae: 892.3171
# Epoch 232/1000
#  - 8s - loss: 1535578.7667 - mae: 892.4808
# Epoch 233/1000
#  - 8s - loss: 1568909.4601 - mae: 918.6746
# Epoch 234/1000
#  - 8s - loss: 1869298.0810 - mae: 966.1677
# Epoch 235/1000
#  - 8s - loss: 1575558.2014 - mae: 899.6275
# Epoch 236/1000
#  - 8s - loss: 1518592.2959 - mae: 894.7547
# Epoch 237/1000
#  - 8s - loss: 1608254.3118 - mae: 915.5175
# Epoch 238/1000
#  - 8s - loss: 1415455.5134 - mae: 861.3774
# Epoch 239/1000
#  - 8s - loss: 1551606.4915 - mae: 896.4286
# Epoch 240/1000
#  - 8s - loss: 1690764.1842 - mae: 928.0178
# Epoch 241/1000
#  - 8s - loss: 1436313.9010 - mae: 872.9869
# Epoch 242/1000
#  - 8s - loss: 1495475.7475 - mae: 882.9743
# Epoch 243/1000
#  - 8s - loss: 1378007.9173 - mae: 847.5045
# Epoch 244/1000
#  - 8s - loss: 1483890.4693 - mae: 884.0359
# Epoch 245/1000
#  - 8s - loss: 1475395.6156 - mae: 888.5680
# Epoch 246/1000
#  - 8s - loss: 1556715.8481 - mae: 896.3789
# Epoch 247/1000
#  - 7s - loss: 1420509.0727 - mae: 881.4543
# Epoch 248/1000
#  - 8s - loss: 1635235.9749 - mae: 913.0714
# Epoch 249/1000
#  - 8s - loss: 1474720.4691 - mae: 875.2201
# Epoch 250/1000
#  - 8s - loss: 1429835.2840 - mae: 863.5346
# Epoch 251/1000
#  - 8s - loss: 1354504.2276 - mae: 861.0633
# Epoch 252/1000
#  - 8s - loss: 1421625.9909 - mae: 881.1185
# Epoch 253/1000
#  - 8s - loss: 1724017.2643 - mae: 929.1606
# Epoch 254/1000
#  - 8s - loss: 1270670.8051 - mae: 814.3755
# Epoch 255/1000
#  - 8s - loss: 1526505.5785 - mae: 895.1593
# Epoch 256/1000
#  - 8s - loss: 1211040.0666 - mae: 805.4838
# Epoch 257/1000
#  - 8s - loss: 1509577.1938 - mae: 883.1447
# Epoch 258/1000
#  - 8s - loss: 1386474.9086 - mae: 829.3369
# Epoch 259/1000
#  - 8s - loss: 1399398.4223 - mae: 852.0032
# Epoch 260/1000
#  - 8s - loss: 1453403.8778 - mae: 849.9557
# Epoch 261/1000
#  - 8s - loss: 1302907.1492 - mae: 832.6356
# Epoch 262/1000
#  - 8s - loss: 1405771.0960 - mae: 866.9386
# Epoch 263/1000
#  - 8s - loss: 1431913.9455 - mae: 860.5905
# Epoch 264/1000
#  - 8s - loss: 1415821.7734 - mae: 864.7111
# Epoch 265/1000
#  - 8s - loss: 1537202.3813 - mae: 868.1493
# Epoch 266/1000
#  - 8s - loss: 1450130.3287 - mae: 848.9854
# Epoch 267/1000
#  - 8s - loss: 1350509.7779 - mae: 832.0224
# Epoch 268/1000
#  - 8s - loss: 1361244.6001 - mae: 851.3590
# Epoch 269/1000
#  - 8s - loss: 1310549.2923 - mae: 837.6603
# Epoch 270/1000
#  - 8s - loss: 1338588.0111 - mae: 837.0571
# Epoch 271/1000
#  - 8s - loss: 1229225.4653 - mae: 813.0383
# Epoch 272/1000
#  - 8s - loss: 1375770.1950 - mae: 857.2595
# Epoch 273/1000
#  - 8s - loss: 1425480.7451 - mae: 850.1843
# Epoch 274/1000
#  - 8s - loss: 1170218.5173 - mae: 793.0630
# Epoch 275/1000
#  - 8s - loss: 1287652.1639 - mae: 824.5105
# Epoch 276/1000
#  - 8s - loss: 1557296.3081 - mae: 889.4067
# Epoch 277/1000
#  - 8s - loss: 1592148.0031 - mae: 883.2126
# Epoch 278/1000
#  - 8s - loss: 1189556.9996 - mae: 783.7865
# Epoch 279/1000
#  - 8s - loss: 1319310.9594 - mae: 835.6949
# Epoch 280/1000
#  - 8s - loss: 1227072.3805 - mae: 807.3320
# Epoch 281/1000
#  - 8s - loss: 1357451.3961 - mae: 812.4854
# Epoch 282/1000
#  - 8s - loss: 1254969.8253 - mae: 825.2773
# Epoch 283/1000
#  - 8s - loss: 1249498.6851 - mae: 829.2366
# Epoch 284/1000
#  - 8s - loss: 1398699.6335 - mae: 838.9711
# Epoch 285/1000
#  - 8s - loss: 1378528.4336 - mae: 826.1330
# Epoch 286/1000
#  - 8s - loss: 1114720.1524 - mae: 762.5945
# Epoch 287/1000
#  - 7s - loss: 1195617.2316 - mae: 803.1873
# Epoch 288/1000
#  - 7s - loss: 1312503.7071 - mae: 836.1881
# Epoch 289/1000
#  - 8s - loss: 1428784.8631 - mae: 832.1612
# Epoch 290/1000
#  - 8s - loss: 1361316.3660 - mae: 801.7286
# Epoch 291/1000
#  - 8s - loss: 1156931.1597 - mae: 778.9621
# Epoch 292/1000
#  - 8s - loss: 1178118.6056 - mae: 777.7411
# Epoch 293/1000
#  - 8s - loss: 1362749.6730 - mae: 839.2780
# Epoch 294/1000
#  - 8s - loss: 1290834.5297 - mae: 815.0480
# Epoch 295/1000
#  - 8s - loss: 1107717.7639 - mae: 756.7818
# Epoch 296/1000
#  - 8s - loss: 1721201.8576 - mae: 918.2253
# Epoch 297/1000
#  - 8s - loss: 1078612.8088 - mae: 763.3229
# Epoch 298/1000
#  - 8s - loss: 1072440.6812 - mae: 755.2488
# Epoch 299/1000
#  - 8s - loss: 1184119.0793 - mae: 791.8388
# Epoch 300/1000
#  - 8s - loss: 1273729.6058 - mae: 821.7672
# Epoch 301/1000
#  - 8s - loss: 1208015.6218 - mae: 784.6214
# Epoch 302/1000
#  - 8s - loss: 1049658.7020 - mae: 749.9414
# Epoch 303/1000
#  - 8s - loss: 1326767.5114 - mae: 826.1044
# Epoch 304/1000
#  - 8s - loss: 1090389.1050 - mae: 758.9860
# Epoch 305/1000
#  - 8s - loss: 1241467.5080 - mae: 794.9740
# Epoch 306/1000

# %%
val_mae/target_mean

# %%
import math
math.sqrt(25638855.11415525)

# %%
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (16, 12),
         'axes.labelsize': 24,
         'axes.titlesize':36,
         'xtick.labelsize':18,
         'ytick.labelsize':18}
pylab.rcParams.update(params)
history = historys
plt.figure(figsize=(16,12))
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['mae'])
#plt.plot(history.history['val_mae'])
#plt.title('Model Accuracy', fontsize=36)
plt.ylabel('MAE',fontsize=24)
plt.xlabel('Epoch',fontsize=24)
#plt.legend(['train', 'test'], loc='upper left') 
plt.show()
# summarize history for loss plt.plot(history.history['loss']) plt.plot(history.history['val_loss']) plt.title('model loss')

# %%
accuracy=[]
plt.figure(figsize=(16,12))
for value in history.history['mae']:
    accuracy.append(1-value/target_mean)
plt.plot(accuracy)
plt.ylabel('Accuracy',)
plt.xlabel('Epoch')
plt.show()

# %%
accuracy[-1]

# %%
# 输出一个一天/h的训练值与实际值
fig = plt.figure(figsize=(15,8))
y_pred = model.predict(train_data)
x_data = np.linspace(0,len(train_data),len(y_pred))
plt.scatter(x_data,train_target)
plt.plot(x_data,y_pred,'r-',lw=1)

# %% [markdown]
# #### 5.3.4 预测结果

# %%
# 输出一个客流量 / h 的预测值与实际值
fig = plt.figure(figsize=(12, 5))
y_pred = model.predict(test_data)
x_data = np.linspace(0,len(y_pred)/19 ,len(y_pred))
plt.scatter(x_data[0:200],test_target[0:200])
plt.plot(x_data[0:200],y_pred[0:200],'r-',lw=1)

# %%
1-val_mae/target_mean

# %%
data_set1

# %% [markdown]
# ## 6. 结论
#
# 通过对上海虹桥地铁进出站的客流量数据分析，发现客流量受到节假日，天气等因素的影响，本模型综合考虑以上影响因素，建立地铁客流量的预测模型。
#
# 情景分析结果表明，本预测算法能够有效的应用于地铁进出站的客流量预测情景。将来通过进一步对模型的改进和优化，能够支持公交、火车等交通方式的客流量预测。
#
# 届时将打造一个完整的大型交通枢纽客流量预测系统。为交通枢纽的运力决策和综合管理优化提供数据支持和政策建议。

# %% [markdown]
# # Data for other models
# # Evaluation

# %%
#Fit the model
X = pd.DataFrame(data, columns=['t','hum','weather','wind','holiday','week','date','hour'])
y = target
X_train = train_data
y_train = train_target
X_test = test_data
y_test = test_target

# %%
print(len(X_test),len(y_test))

# %%
target_mean = test_target.mean(axis=0)
target_mean

# %%
error_gbr = 2484.45/target_mean
error_gbr

# %%
error_rf = 3023.7/target_mean
error_rf

# %%
error_lr = 6826.34/target_mean
error_lr

# %%
#Score/Accuracy/MAE
def evaluation(model, y_pred):
    score = model.score(X_test, y_test)*100
    mae = metrics.mean_absolute_error(y_test, y_pred)
    mse = metrics.mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    print("Accuracy --> ", score)
    print('MAE:', mae)
    print('MSE:', mse)
    print('RMSE:', rmse)
    return {'score':score,'mae':mae,'mse':mse,'rmse':rmse}

# %%
#Score/Accuracy/MAE
def evaluation_train(model, X_train, y_train):
    score = model.score(X_train, y_train)*100
    y_pred_train = model.predict(X_train)
    mae = metrics.mean_absolute_error(y_train, y_pred_train)
    mse = metrics.mean_squared_error(y_train, y_pred_train)
    rmse = np.sqrt(metrics.mean_squared_error(y_train, y_pred_train))
    print("Accuracy --> ", score)
    print('MAE:', mae)
    print('MSE:', mse)
    print('RMSE:', rmse)
    return {'score':score,'mae':mae,'mse':mse,'rmse':rmse}

# %% [markdown]
# # Linear Regression

# %%
#Train the model
from sklearn import linear_model
regressor = linear_model.LinearRegression()
regressor.fit(X_train, y_train)

# %% [markdown]
# In case of multivariable linear regression, the regression model has to find the most optimal coefficients for all the attributes. To see what coefficients our regression model has chosen, execute the following script:

# %%
coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])
coeff_df

# %% [markdown]
# ## Making predictions

# %%
y_pred_lr = regressor.predict(X_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_lr})
df

# %%
plt.figure(figsize=(15,8))
plt.plot(y_pred_lr, 'o-r')
plt.plot(y_test,'o-b')
plt.show()

# %%
def plt_cmp(y_pred, y_test):
    plt.figure(figsize=(15,8))
    plt.plot(y_pred, 'o-r')
    plt.plot(y_test,'o-b')
    plt.show()

# %% [markdown]
# ## Evaluating the Algorithm
#
# The final step is to evaluate the performance of algorithm. We'll do this by finding the values for MAE, MSE and RMSE. Execute the following script:

# %%
#Score/Accuracy
#Return the coefficient of determination R^2 of the prediction.
evaluation(regressor,y_pred_lr)

# %% [markdown]
# # RandomForestRegression

# %%
#Train the model
from sklearn.ensemble import RandomForestRegressor
RF = RandomForestRegressor(n_estimators=50)

# %%
#Fit
RF.fit(X_train, y_train)

# %%
y_pred_rf = RF.predict(X_test)
plt_cmp(y_pred_rf, y_test)

# %%
evaluation(RF,y_pred_rf)

# %%
mae_rf = []
mse_rf = []
mae_train_rf = []
mse_train_rf = []
for n in range(1,500):
    rf_iter = RandomForestRegressor(n_estimators=n)
    rf_iter.fit(X_train, y_train)
    y_pred_rf_iter = rf_iter.predict(X_test)
    res_rf = evaluation(rf_iter,y_pred_rf_iter)
    mae_rf.append(res_rf['mae'])
    mse_rf.append(res_rf['mse'])
    res_train_rf = evaluation_train(rf_iter,X_train, y_train)
    mae_train_rf.append(res_train_rf['mae'])
    mse_train_rf.append(res_train_rf['mse'])

# %%
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (16, 12),
         'axes.labelsize': 24,
         'axes.titlesize':36,
         'xtick.labelsize':18,
         'ytick.labelsize':18}
pylab.rcParams.update(params)
plt.plot(mae_rf) 
plt.plot(mae_train_rf)
plt.legend(['test', 'train'], loc='upper right')
plt.ylabel('MAE',fontsize=24)
plt.xlabel('Number of Estimators',fontsize=24)

# %%
plt.plot(mse_rf)
plt.plot(mse_train_rf)
plt.ylabel('MSE',fontsize=24)
plt.xlabel('Number of Estimators',fontsize=24)

# %% [markdown]
# # GradientBoostingRegressor

# %% [markdown]
# Gradient boosting has become a big part of Kaggle competition winners’ toolkits. It was initially explored in earnest by Jerome Friedman in the paper Greedy Function Approximation: A Gradient Boosting Machine. In this post we’ll take a look at gradient boosting and its use in python with the scikit-learn library.
# Gradient boosting is a boosting ensemble method.
# Ensemble machine learning methods are ones in which a number of predictors are aggregated to form a final prediction, which has lower bias and variance than any of the individual predictors.
# Ensemble machine learning methods come in 2 different flavours – bagging and boosting.
# Bagging is a technique in which many predictors are trained independently of one another and then they are aggregated afterwards using an average (majority vote/mode, mean, weighted mean). Random forests are an example of bagging.
# Boosting is a technique in which the predictors are trained sequentially (the error of one stage is passed as input into the next stage).
# Gradient boosting produces an ensemble of decision trees that, on their own, are weak decision models. Let’s take a look at how this model works.
# We’ll start with some imports.

# %%
#Train the model
from sklearn.ensemble import GradientBoostingRegressor

# %%
params_gbr = {}
params_gbr['n_estimators'] = 1000
params_gbr['criterion'] = 'mse'
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 10),
         'axes.labelsize': 16,
         'axes.titlesize':14,
         'xtick.labelsize':12,
         'ytick.labelsize':12}
pylab.rcParams.update(params)
f, ax = plt.subplots(2, 2, figsize=(15, 10))
for idx, max_depth in enumerate([1, 2, 3, 5]):
    params_gbr['max_depth'] = max_depth

    gradient_boosting_regressor = GradientBoostingRegressor(**params_gbr)

    gradient_boosting_regressor.fit(X_train, y_train)
    subplot = ax[idx // 2][idx % 2]
    subplot.set_title('Gradient Boosting model (100 estimators, {} max tree splits)'.format(max_depth))
    x = np.linspace(0,200,len(y_test))
    subplot.scatter(x, y_test)
    subplot.plot(x, gradient_boosting_regressor.predict(X_test), color='r')
plt.show()

# %%
y_pred_gbr = gradient_boosting_regressor.predict(X_test)

# %%
evaluation(gradient_boosting_regressor,y_pred_gbr)

# %%
# Relation n_estimators with mae
# estimators from 1-200: train error and test error curve
mae = []
mse = []
mae_train = []
mse_train = []
params_gbr_iter = {}
for n in range(1,1000):
    params_gbr_iter['n_estimators'] = n
    params_gbr_iter['criterion'] = 'mse'
    params_gbr['max_depth'] = 5
    gradient_boosting_regressor = GradientBoostingRegressor(**params_gbr_iter)
    gradient_boosting_regressor.fit(X_train, y_train)
    y_pred_gbr_iter = gradient_boosting_regressor.predict(X_test)
    res = evaluation(gradient_boosting_regressor,y_pred_gbr_iter)
    mae.append(res['mae'])
    mse.append(res['mse'])
    res_train = evaluation_train(gradient_boosting_regressor,X_train, y_train)
    mae_train.append(res_train['mae'])
    mse_train.append(res_train['mse'])

# %%
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (16, 12),
         'axes.labelsize': 24,
         'axes.titlesize':36,
         'xtick.labelsize':18,
         'ytick.labelsize':18}
pylab.rcParams.update(params)
plt.plot(mae) 
plt.plot(mae_train)
plt.legend(['test', 'train'], loc='upper right')
plt.ylabel('MAE',fontsize=24)
plt.xlabel('Number of Estimators',fontsize=24)

# %%
plt.plot(mse)
plt.plot(mse_train)
plt.ylabel('MSE',fontsize=24)
plt.xlabel('Number of Estimators',fontsize=24)

# %% [markdown]
# We can see how increasing the both the estimators and the max depth, we get a better approximation of y but we can start to make the model somewhat prone to overfitting.
# Therefore it is imperative to make sure we are using validation splits/cross-validation to make sure we are not overfitting our Gradient Boosting models.

# %% [markdown]
# # RNN

# %%
import numpy as np
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
from tensorflow.python.framework import ops
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
def onehotkey(X): 
    integer_encoded = LabelEncoder().fit_transform(X)
    integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
    onehot_encoded = OneHotEncoder(sparse=False).fit_transform(integer_encoded)
    return onehot_encoded

# %%
tf.reset_default_graph()
np.random.seed(2)
tf.set_random_seed(2)

# Configuration on Global Variables
# 1. RNN Cell Configuration (normally num_neuron = state_size, but not necessary)
#num_neuron = 10

# 2. Recurrent Steps (Unfolding)
num_steps = 25 # number of truncated backprop steps ('n' in the discussion above)
pos_1=3
pos_2=20

# 3. Data Input/State/Output 
seq_size =   20000000
#seq_size = 200000000
state_size = 100
num_classes = 2 

# 4. Training (Mini-Batch, LearningRate, Dropout, ...)
batch_size = 400
learning_rate = 0.3

# %%
def gen_batch(seq_size, batch_size, num_steps): 
    X = np.random.choice([0,1], p=[0.5,0.5], size=seq_size)   
    pos1=4
    pos2=40
    plist=[0.65, 0.45, 0.25, 0.10]
    p2=np.zeros((2, 2))
    p2[1,1]=plist[0]
    p2[1,0]=plist[1]
    p2[0,1]=plist[2]
    p2[0,0]=plist[3]

    X = np.random.choice([0,1], p = [0.5, 0.5], size = seq_size)
    Prob = p2[np.roll(X,pos1), np.roll(X,pos2)]
    Y = (np.random.rand(len(X)) < Prob).astype(int)
    
    epoch_size = seq_size // (batch_size*num_steps)
    
    X.resize(batch_size, epoch_size, num_steps)
    Y.resize(batch_size, epoch_size, num_steps)
    
    for i in range(epoch_size):
        yield (X[:,i,:],Y[:,i,:])

# %%
# Input and Output_labeling (turn everything into a list for handling)
# num_class is assumed to be the same for input and output (not necessary)
# run_inputs list of num_steps tensors with shape [batch_size, num_classes]
# initial state 

x = tf.placeholder(tf.int32, [batch_size, num_steps], name='input_placeholder')
y = tf.placeholder(tf.int32, [batch_size, num_steps], name='labels_placeholder')
init_state = tf.zeros([batch_size, state_size])

rnn_inputs = tf.one_hot(x, num_classes)
print("rnn_inputs", rnn_inputs.get_shape())


cell = tf.nn.rnn_cell.BasicRNNCell(state_size)
rnn_outputs, final_state = tf.nn.dynamic_rnn(cell, rnn_inputs, initial_state=init_state, dtype="float32")

print("rnn_output", rnn_outputs.get_shape())
print("final_state", final_state.get_shape())

with tf.variable_scope('softmax'):
    W = tf.get_variable('W', [state_size, num_classes])
    b = tf.get_variable('b', [num_classes], initializer=tf.constant_initializer(0.0))


logits = tf.reshape(
            tf.matmul(tf.reshape(rnn_outputs, [-1, state_size]), W) + b,
            [batch_size, num_steps, num_classes])
print("logits", logits.get_shape())

losses = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
total_loss = tf.reduce_mean(losses)
train_step = tf.train.AdagradOptimizer(learning_rate).minimize(total_loss)

# %%
# Training the network 
def train_network(seq_size, num_steps, state_size, printout=10):
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        training_losses = []
               
        training_loss = 0
        training_state = np.zeros((batch_size, state_size))
        step = 0

        for (X, Y) in gen_batch(seq_size, batch_size, num_steps):
            training_loss_, training_state, _ = \
                sess.run([total_loss, final_state, train_step],
                              feed_dict={x:X, y:Y, init_state:training_state})
            training_loss += training_loss_
            if step % printout == 0 and step > 0:
                print("Step & Loss: ", step, training_loss/printout)
                training_losses.append(training_loss/printout)
                training_loss = 0
            step +=1
                
    return training_losses

training_losses = train_network(seq_size,num_steps,state_size, printout=200)
print('Num of Unfolding (num_steps) ', num_steps)
print('Num of Neurons in RNN Cell (state_size) ', state_size)
print('Sequence Length(seq_size) ', seq_size)
print('Batch,Steps,Epoch ', batch_size, num_steps, seq_size//(batch_size*num_steps))
plt.ylim(0.45, 0.68)
plt.plot(training_losses)

# %%
training_losses
