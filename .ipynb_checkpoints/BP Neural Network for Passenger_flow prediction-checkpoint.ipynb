# %% [markdown]
# # 枢纽客流量BP神经网络预测模型
#
#
# ## 1. 研究意义：
#
# 智慧交通是智慧城市的重要组成部分，提高公交车站点客流量预测的准确度是智慧公交的研究内容之一。大型现代化综合交通枢纽站汇集多种交通方式并伴有大规模客流集散、换乘等特点，采用科学的方法研究大型综合交通枢纽站的各个交通方式的客流量预测对公交运营部门的快速决策和综合管理提供及时准确的数据参考具有现实意义。
#
# 本算法模型有效的解决了交通枢纽各个交通方式短期客流量的预测问题， 对未来的小时客流量和5分钟客流量进行短期预测，能够有效的预测客流量爆发点和未来各个时段客流量的走势，为交通枢纽的运力分配策略提供数据支持。模型充分考虑了节假日、天气变化等因素对客流量的影响，能够提高对于特殊节日和天气影响下的客流量预测精度。
#
# 模型首先分析影响客流波动的因素（节假日、天气因素以及时间序列等），然后通过对比各类预测方法的优缺点，设计改进的BP神经网络算法进行短期客流量预测。
#
# ## 2.预期目标和现阶段的成果：
#
# 预测模型将提供对交通枢纽地铁、公交、火车等交通方式的客流量预测，实现客流量爆发预警功能，为枢纽的运力调配提供数据支持。同时，客流量的预测和分析，能够为优化枢纽的空间布置和人力分配提供政策建议。
#
# 目前，基于Keras深度学习库搭建的BP神经网络预测模型目前已完成对上海虹桥地铁进出站的客流量预测，小时客流量预测精度可以达到10%以下。能够有效的实现未来一周的客流量预测。未来通过对预测算法输入特征值的优化以及对部分特殊情况的规则提取和分析（比如特殊的节假日情况，突发事件等），算法的精度将得到进一步提高。
#
# 未来将打造一个完整的交通枢纽客流量预测系统，为交通枢纽的运力决策和综合管理优化提供数据支持和政策建议。该系统可以支持交通枢纽站的地铁、公交、火车等交通方式的客流量预测，届时需要拿到公交刷卡记录和火车站的进出站闸机历史csv数据。
#
#
# ## 3.模型功能：
#
# 模型能够有效预测未来一周枢纽内各个交通方式的客流量大小，提前为枢纽运力分配提供策略。模式采用有监督的机器学习方式，在未来随着训练（历史）数据的不断积累，能够实现自我调整和参数优化，不断提高预测的精度。
#
# 根据给定的输入参数：
# INPUT[日期(eg:20180901)，时段(eg:8)，节假日情况（周末or其他节假日), 天气情况（降雨），最高温度，风力]
#
# 输出未来客流量的预测值：
# OUTPUT[Passenger_flow / h]
#
# ## 4. 网络结构：
#
# 网络采用7维的特征值向量作为输入参数，两层64节点的隐含层，隐含层采用“relu”激活函数，输出层是1维的客流量数值。下面是网络的结构：
#
# INPUT[x1,x2...,x7] ->
# Hiddden layer1[64 Nodes, 'relu' activation function] -> Hidden layer2[64 Nodes,'relu]
# -> OUTPUT[Passenger_flow]
#
#
# ## 5.情景分析-上海虹桥地跌进出站客流分析：
#
# 本章节采用上海虹桥实际的地铁进出站客流数据进行建模和验证，分析算法模型对与客流量预测的可行性。本章详细的介绍了模型的搭建流程，包括运行环境的检查， 输入数据的处理分析以及预测模型的训练和结果预测。 模型构建的目录如下：
#
# 5.1. 环境检查
#     5.1.1 Python版本检查
#     5.1.2  基础包导入检查
#     5.1.3 检查安装版本
#
# 5.2. 客流量数据预处理和特征分析
#     5.2.1 读取数据
#     5.2.2 提取闸机数据，转换为小时的客流量数据
#             绘制 客流量 / 小时 统计图
#             绘制 节假日 / 日期 统计图
#
# 5.3. 搭建神经网络预测模型
#     5.3.1 网络输入数据标准化
#     5.3.2 搭建网络框架
#     5.3.3 训练神经网络
#     5.3.4 预测结果

# %% [markdown]
# ### 5.1 环境检查

# %% [markdown]
# #### 5.1.1 Python版本检查
# python 3 on anaconda

# %%
# !python3 --version
# Out:
# Python 3.7.5

# %% [raw]
# Anaconda 环境配置（mac）
# https://www.jianshu.com/p/b9eac8419c8d
# 需要的环境参数：export PATH=/Users/zhangfujiang/anaconda3/bin:$PATH，
# 配置环境变量：conda env create -f  /Users/zhangfujiang/virtual_platform_mac.yml
# Environment: jp_kernel on mackbook pro

# %% [markdown]
# #### 5.1.2  基础包导入检查

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
from scipy import stats

# %% [raw]
# 在终端运行
# pip install tensorflow and keras  源： -i https://pypi.tuna.tsinghua.edu.cn/simple

# %%
import tensorflow
import keras
print('tensorflow:', tensorflow.__version__)
print('keras:', keras.__version__)
# !python3 --version
# Out:
# tensorflow: 2.0.0
# keras: 2.3.1
# Python 3.7.5
# Using TensorFlow backend.

# %% [markdown]
# #### 5.1.3 检查安装版本

# %%
import numpy
print('numpy:', numpy.__version__)
import scipy
print("scipy:", scipy.__version__)
#import matplotlib as plt
#print('matplotlib:', matplotlib.__version__)
# Out:
# numpy: 1.17.3
# scipy: 1.2.1

# %% [markdown]
# ### 5.2 客流量数据预处理和特征分析

# %%
from keras.datasets import boston_housing
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import RMSprop
import numpy as np
import csv
import os
import random
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
# 把日期hash计算:"2018/1/1 0:00:26"--> 0=2018010100
# date 指标： 反映时间的变化
# >> date:"20180101" hour:"00"
def transfer_time(str):
    # str: "2018/1/1 0:00:26"
    data = str.split(' ')
    if len(data) == 1:
        date = data[0]
        hour = 0
        #pdb.set_trace()
    else:
        date = data[0]
        hour = data[1]
    try:
        temp_date = date.split('/')
        if len(temp_date[1]) == 1:
            temp_date[1] = '0' + temp_date[1]
        if len(temp_date[2]) == 1:
            temp_date[2] = '0' + temp_date[2]
        date = temp_date[0] + temp_date[1] + temp_date[2]
        temp_hour = hour.split(':')
        hour = temp_hour[0]
        if len(hour) < 2:
            hour = '0' + hour
    # return 日期和时段
    except Exception as e:
        print("Transfer to time exception:",date)
        print(e)
        hour = "00"
    return date, hour

# %% [markdown]
# #### 5.2.1 读取数据

# %%
# 读取data
# (train_data, train_target), (test_data, test_target) 获取
"""
csv_data: passenger flow
"""
csv_data = pd.read_csv('data.csv')

# %%
# data: {datehour: {t},wind, holiday, weather, datehour, hum, week}
with open('data.json', 'r') as f:
    json_data = json.load(f)

# %%
json_data
# Out:
# {'2018010105': {'t': '2℃',
#   'hum': '91%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010105},
#  '2018010106': {'t': '2℃',
#   'hum': '91%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010106},
#  '2018010107': {'t': '2℃',
#   'hum': '94%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010107},
#  '2018010108': {'t': '5℃',
#   'hum': '76%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010108},
#  '2018010109': {'t': '7℃',
#   'hum': '56%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010109},
#  '2018010110': {'t': '9℃',
#   'hum': '36%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010110},
#  '2018010111': {'t': '10℃',
#   'hum': '34%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010111},
#  '2018010112': {'t': '10℃',
#   'hum': '24%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010112},
#  '2018010113': {'t': '11℃',
#   'hum': '29%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010113},
#  '2018010114': {'t': '11℃',
#   'hum': '27%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010114},
#  '2018010115': {'t': '11℃',
#   'hum': '30%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010115},
#  '2018010116': {'t': '9℃',
#   'hum': '41%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010116},
#  '2018010117': {'t': '7℃',
#   'hum': '54%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010117},
#  '2018010118': {'t': '6℃',
#   'hum': '66%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010118},
#  '2018010119': {'t': '5℃',
#   'hum': '72%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010119},
#  '2018010120': {'t': '6℃',
#   'hum': '70%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010120},
#  '2018010121': {'t': '6℃',
#   'hum': '70%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010121},
#  '2018010122': {'t': '7℃',
#   'hum': '70%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010122},
#  '2018010123': {'t': '7℃',
#   'hum': '70%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018010123},
#  '2018010205': {'t': '10℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010205},
#  '2018010206': {'t': '10℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010206},
#  '2018010207': {'t': '10℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010207},
#  '2018010208': {'t': '10℃',
#   'hum': '71%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010208},
#  '2018010209': {'t': '11℃',
#   'hum': '67%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010209},
#  '2018010210': {'t': '12℃',
#   'hum': '61%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010210},
#  '2018010211': {'t': '13℃',
#   'hum': '61%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010211},
#  '2018010212': {'t': '13℃',
#   'hum': '62%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010212},
#  '2018010213': {'t': '12℃',
#   'hum': '64%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010213},
#  '2018010214': {'t': '12℃',
#   'hum': '67%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010214},
#  '2018010215': {'t': '12℃',
#   'hum': '71%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010215},
#  '2018010216': {'t': '12℃',
#   'hum': '74%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010216},
#  '2018010217': {'t': '12℃',
#   'hum': '75%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010217},
#  '2018010218': {'t': '11℃',
#   'hum': '77%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010218},
#  '2018010219': {'t': '11℃',
#   'hum': '77%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010219},
#  '2018010220': {'t': '11℃',
#   'hum': '89%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010220},
#  '2018010221': {'t': '11℃',
#   'hum': '89%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010221},
#  '2018010222': {'t': '10℃',
#   'hum': '95%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010222},
#  '2018010223': {'t': '10℃',
#   'hum': '95%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010223},
#  '2018010305': {'t': '7℃',
#   'hum': '92%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010305},
#  '2018010306': {'t': '7℃',
#   'hum': '92%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010306},
#  '2018010307': {'t': '8℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010307},
#  '2018010308': {'t': '8℃',
#   'hum': '89%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010308},
#  '2018010309': {'t': '8℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010309},
#  '2018010310': {'t': '8℃',
#   'hum': '92%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010310},
#  '2018010311': {'t': '8℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010311},
#  '2018010312': {'t': '8℃',
#   'hum': '80%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010312},
#  '2018010313': {'t': '8℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010313},
#  '2018010314': {'t': '7℃',
#   'hum': '81%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010314},
#  '2018010315': {'t': '7℃',
#   'hum': '77%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010315},
#  '2018010316': {'t': '7℃',
#   'hum': '78%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010316},
#  '2018010317': {'t': '6℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010317},
#  '2018010318': {'t': '5℃',
#   'hum': '89%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010318},
#  '2018010319': {'t': '5℃',
#   'hum': '90%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010319},
#  '2018010320': {'t': '5℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010320},
#  '2018010321': {'t': '5℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010321},
#  '2018010322': {'t': '4℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010322},
#  '2018010323': {'t': '4℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018010323},
#  '2018010405': {'t': '4℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010405},
#  '2018010406': {'t': '4℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010406},
#  '2018010407': {'t': '4℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010407},
#  '2018010408': {'t': '4℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010408},
#  '2018010409': {'t': '4℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010409},
#  '2018010410': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010410},
#  '2018010411': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010411},
#  '2018010412': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010412},
#  '2018010413': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010413},
#  '2018010414': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010414},
#  '2018010415': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010415},
#  '2018010416': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010416},
#  '2018010417': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010417},
#  '2018010418': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010418},
#  '2018010419': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010419},
#  '2018010420': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010420},
#  '2018010421': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010421},
#  '2018010422': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010422},
#  '2018010423': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018010423},
#  '2018010505': {'t': '3℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010505},
#  '2018010506': {'t': '3℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010506},
#  '2018010507': {'t': '3℃',
#   'hum': '92%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010507},
#  '2018010508': {'t': '4℃',
#   'hum': '88%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010508},
#  '2018010509': {'t': '4℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010509},
#  '2018010510': {'t': '5℃',
#   'hum': '74%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010510},
#  '2018010511': {'t': '5℃',
#   'hum': '73%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010511},
#  '2018010512': {'t': '5℃',
#   'hum': '66%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010512},
#  '2018010513': {'t': '5℃',
#   'hum': '64%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010513},
#  '2018010514': {'t': '5℃',
#   'hum': '66%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010514},
#  '2018010515': {'t': '4℃',
#   'hum': '67%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010515},
#  '2018010516': {'t': '4℃',
#   'hum': '67%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010516},
#  '2018010517': {'t': '4℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010517},
#  '2018010518': {'t': '3℃',
#   'hum': '69%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010518},
#  '2018010519': {'t': '3℃',
#   'hum': '69%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010519},
#  '2018010520': {'t': '2℃',
#   'hum': '79%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010520},
#  '2018010521': {'t': '2℃',
#   'hum': '79%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010521},
#  '2018010522': {'t': '1℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010522},
#  '2018010523': {'t': '1℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018010523},
#  '2018010605': {'t': '0℃',
#   'hum': '89%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010605},
#  '2018010606': {'t': '0℃',
#   'hum': '89%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010606},
#  '2018010607': {'t': '1℃',
#   'hum': '85%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010607},
#  '2018010608': {'t': '2℃',
#   'hum': '81%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010608},
#  '2018010609': {'t': '4℃',
#   'hum': '74%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010609},
#  '2018010610': {'t': '5℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010610},
#  '2018010611': {'t': '7℃',
#   'hum': '58%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010611},
#  '2018010612': {'t': '7℃',
#   'hum': '60%',
#   'weather': '阴',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010612},
#  '2018010613': {'t': '7℃',
#   'hum': '59%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010613},
#  '2018010614': {'t': '8℃',
#   'hum': '59%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010614},
#  '2018010615': {'t': '7℃',
#   'hum': '63%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010615},
#  '2018010616': {'t': '7℃',
#   'hum': '67%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010616},
#  '2018010617': {'t': '6℃',
#   'hum': '69%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010617},
#  '2018010618': {'t': '6℃',
#   'hum': '71%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010618},
#  '2018010619': {'t': '6℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010619},
#  '2018010620': {'t': '6℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010620},
#  '2018010621': {'t': '6℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010621},
#  '2018010622': {'t': '6℃',
#   'hum': '94%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010622},
#  '2018010623': {'t': '6℃',
#   'hum': '94%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018010623},
#  '2018010705': {'t': '8℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010705},
#  '2018010706': {'t': '8℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010706},
#  '2018010707': {'t': '8℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010707},
#  '2018010708': {'t': '8℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010708},
#  '2018010709': {'t': '9℃',
#   'hum': '98%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010709},
#  '2018010710': {'t': '9℃',
#   'hum': '98%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010710},
#  '2018010711': {'t': '10℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010711},
#  '2018010712': {'t': '10℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010712},
#  '2018010713': {'t': '10℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010713},
#  '2018010714': {'t': '9℃',
#   'hum': '96%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010714},
#  '2018010715': {'t': '8℃',
#   'hum': '96%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010715},
#  '2018010716': {'t': '6℃',
#   'hum': '95%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010716},
#  '2018010717': {'t': '6℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '3级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010717},
#  '2018010718': {'t': '5℃',
#   'hum': '94%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010718},
#  '2018010719': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010719},
#  '2018010720': {'t': '5℃',
#   'hum': '89%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010720},
#  '2018010721': {'t': '5℃',
#   'hum': '89%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010721},
#  '2018010722': {'t': '4℃',
#   'hum': '88%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010722},
#  '2018010723': {'t': '4℃',
#   'hum': '88%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018010723},
#  '2018010805': {'t': '3℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010805},
#  '2018010806': {'t': '3℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010806},
#  '2018010807': {'t': '3℃',
#   'hum': '83%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010807},
#  '2018010808': {'t': '3℃',
#   'hum': '82%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010808},
#  '2018010809': {'t': '3℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010809},
#  '2018010810': {'t': '3℃',
#   'hum': '78%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010810},
#  '2018010811': {'t': '3℃',
#   'hum': '71%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010811},
#  '2018010812': {'t': '3℃',
#   'hum': '70%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010812},
#  '2018010813': {'t': '3℃',
#   'hum': '67%',
#   'weather': '多云',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010813},
#  '2018010814': {'t': '3℃',
#   'hum': '65%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010814},
#  '2018010815': {'t': '3℃',
#   'hum': '64%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010815},
#  '2018010816': {'t': '4℃',
#   'hum': '65%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010816},
#  '2018010817': {'t': '3℃',
#   'hum': '63%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010817},
#  '2018010818': {'t': '3℃',
#   'hum': '66%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010818},
#  '2018010819': {'t': '2℃',
#   'hum': '53%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010819},
#  '2018010820': {'t': '1℃',
#   'hum': '54%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010820},
#  '2018010821': {'t': '1℃',
#   'hum': '54%',
#   'weather': '阴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010821},
#  '2018010822': {'t': '0℃',
#   'hum': '49%',
#   'weather': '多云',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010822},
#  '2018010823': {'t': '0℃',
#   'hum': '49%',
#   'weather': '多云',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018010823},
#  '2018010905': {'t': '0℃',
#   'hum': '57%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010905},
#  '2018010906': {'t': '0℃',
#   'hum': '57%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010906},
#  '2018010907': {'t': '0℃',
#   'hum': '57%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010907},
#  '2018010908': {'t': '2℃',
#   'hum': '47%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010908},
#  '2018010909': {'t': '3℃',
#   'hum': '42%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010909},
#  '2018010910': {'t': '4℃',
#   'hum': '38%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010910},
#  '2018010911': {'t': '5℃',
#   'hum': '33%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010911},
#  '2018010912': {'t': '5℃',
#   'hum': '30%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010912},
#  '2018010913': {'t': '5℃',
#   'hum': '27%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010913},
#  '2018010914': {'t': '5℃',
#   'hum': '27%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010914},
#  '2018010915': {'t': '6℃',
#   'hum': '28%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010915},
#  '2018010916': {'t': '5℃',
#   'hum': '33%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010916},
#  '2018010917': {'t': '4℃',
#   'hum': '36%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010917},
#  '2018010918': {'t': '4℃',
#   'hum': '39%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010918},
#  '2018010919': {'t': '3℃',
#   'hum': '45%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010919},
#  '2018010920': {'t': '1℃',
#   'hum': '57%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010920},
#  '2018010921': {'t': '1℃',
#   'hum': '57%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010921},
#  '2018010922': {'t': '3℃',
#   'hum': '48%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010922},
#  '2018010923': {'t': '3℃',
#   'hum': '48%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018010923},
#  '2018011005': {'t': '1℃',
#   'hum': '59%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011005},
#  '2018011006': {'t': '1℃',
#   'hum': '59%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011006},
#  '2018011007': {'t': '2℃',
#   'hum': '54%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011007},
#  '2018011008': {'t': '2℃',
#   'hum': '51%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011008},
#  '2018011009': {'t': '3℃',
#   'hum': '43%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011009},
#  '2018011010': {'t': '4℃',
#   'hum': '36%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011010},
#  '2018011011': {'t': '5℃',
#   'hum': '30%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011011},
#  '2018011012': {'t': '5℃',
#   'hum': '24%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011012},
#  '2018011013': {'t': '5℃',
#   'hum': '21%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011013},
#  '2018011014': {'t': '5℃',
#   'hum': '23%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011014},
#  '2018011015': {'t': '5℃',
#   'hum': '26%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011015},
#  '2018011016': {'t': '5℃',
#   'hum': '28%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011016},
#  '2018011017': {'t': '4℃',
#   'hum': '36%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011017},
#  '2018011018': {'t': '3℃',
#   'hum': '38%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011018},
#  '2018011019': {'t': '1℃',
#   'hum': '50%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011019},
#  '2018011020': {'t': '2℃',
#   'hum': '37%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011020},
#  '2018011021': {'t': '2℃',
#   'hum': '37%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011021},
#  '2018011022': {'t': '1℃',
#   'hum': '43%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011022},
#  '2018011023': {'t': '1℃',
#   'hum': '43%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011023},
#  '2018011105': {'t': '-3℃',
#   'hum': '80%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011105},
#  '2018011106': {'t': '-3℃',
#   'hum': '80%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011106},
#  '2018011107': {'t': '-3℃',
#   'hum': '79%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011107},
#  '2018011108': {'t': '1℃',
#   'hum': '49%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011108},
#  '2018011109': {'t': '3℃',
#   'hum': '37%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011109},
#  '2018011110': {'t': '3℃',
#   'hum': '27%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011110},
#  '2018011111': {'t': '4℃',
#   'hum': '24%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011111},
#  '2018011112': {'t': '5℃',
#   'hum': '25%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011112},
#  '2018011113': {'t': '5℃',
#   'hum': '23%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011113},
#  '2018011114': {'t': '5℃',
#   'hum': '25%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011114},
#  '2018011115': {'t': '5℃',
#   'hum': '33%',
#   'weather': '晴',
#   'wind': '5级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011115},
#  '2018011116': {'t': '5℃',
#   'hum': '24%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011116},
#  '2018011117': {'t': '4℃',
#   'hum': '31%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011117},
#  '2018011118': {'t': '3℃',
#   'hum': '39%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011118},
#  '2018011119': {'t': '3℃',
#   'hum': '39%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011119},
#  '2018011120': {'t': '1℃',
#   'hum': '52%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011120},
#  '2018011121': {'t': '1℃',
#   'hum': '52%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011121},
#  '2018011122': {'t': '0℃',
#   'hum': '58%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011122},
#  '2018011123': {'t': '0℃',
#   'hum': '58%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011123},
#  '2018011205': {'t': '-3℃',
#   'hum': '53%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011205},
#  '2018011206': {'t': '-3℃',
#   'hum': '53%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011206},
#  '2018011207': {'t': '-3℃',
#   'hum': '53%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011207},
#  '2018011208': {'t': '-1℃',
#   'hum': '45%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011208},
#  '2018011209': {'t': '0℃',
#   'hum': '41%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011209},
#  '2018011210': {'t': '0℃',
#   'hum': '37%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011210},
#  '2018011211': {'t': '1℃',
#   'hum': '28%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011211},
#  '2018011212': {'t': '2℃',
#   'hum': '29%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011212},
#  '2018011213': {'t': '2℃',
#   'hum': '25%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011213},
#  '2018011214': {'t': '3℃',
#   'hum': '24%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011214},
#  '2018011215': {'t': '3℃',
#   'hum': '23%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011215},
#  '2018011216': {'t': '2℃',
#   'hum': '24%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011216},
#  '2018011217': {'t': '0℃',
#   'hum': '26%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011217},
#  '2018011218': {'t': '0℃',
#   'hum': '34%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011218},
#  '2018011219': {'t': '-1℃',
#   'hum': '42%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011219},
#  '2018011220': {'t': '-3℃',
#   'hum': '60%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011220},
#  '2018011221': {'t': '-3℃',
#   'hum': '60%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011221},
#  '2018011222': {'t': '-4℃',
#   'hum': '72%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011222},
#  '2018011223': {'t': '-4℃',
#   'hum': '72%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011223},
#  '2018011305': {'t': '-6℃',
#   'hum': '88%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011305},
#  '2018011306': {'t': '-6℃',
#   'hum': '88%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011306},
#  '2018011307': {'t': '-5℃',
#   'hum': '89%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011307},
#  '2018011308': {'t': '0℃',
#   'hum': '56%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011308},
#  '2018011309': {'t': '2℃',
#   'hum': '40%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011309},
#  '2018011310': {'t': '4℃',
#   'hum': '32%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011310},
#  '2018011311': {'t': '5℃',
#   'hum': '30%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011311},
#  '2018011312': {'t': '5℃',
#   'hum': '39%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011312},
#  '2018011313': {'t': '5℃',
#   'hum': '37%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011313},
#  '2018011314': {'t': '6℃',
#   'hum': '35%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011314},
#  '2018011315': {'t': '5℃',
#   'hum': '36%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011315},
#  '2018011316': {'t': '4℃',
#   'hum': '38%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011316},
#  '2018011317': {'t': '3℃',
#   'hum': '46%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011317},
#  '2018011318': {'t': '3℃',
#   'hum': '56%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011318},
#  '2018011319': {'t': '3℃',
#   'hum': '60%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011319},
#  '2018011320': {'t': '2℃',
#   'hum': '57%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011320},
#  '2018011321': {'t': '2℃',
#   'hum': '57%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011321},
#  '2018011322': {'t': '2℃',
#   'hum': '62%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011322},
#  '2018011323': {'t': '2℃',
#   'hum': '62%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018011323},
#  '2018011405': {'t': '3℃',
#   'hum': '77%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011405},
#  '2018011406': {'t': '3℃',
#   'hum': '77%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011406},
#  '2018011407': {'t': '3℃',
#   'hum': '83%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011407},
#  '2018011408': {'t': '5℃',
#   'hum': '75%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011408},
#  '2018011409': {'t': '7℃',
#   'hum': '68%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011409},
#  '2018011410': {'t': '10℃',
#   'hum': '56%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011410},
#  '2018011411': {'t': '11℃',
#   'hum': '49%',
#   'weather': '多云',
#   'wind': '3级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011411},
#  '2018011412': {'t': '11℃',
#   'hum': '50%',
#   'weather': '多云',
#   'wind': '3级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011412},
#  '2018011413': {'t': '12℃',
#   'hum': '50%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011413},
#  '2018011414': {'t': '11℃',
#   'hum': '50%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011414},
#  '2018011415': {'t': '11℃',
#   'hum': '50%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011415},
#  '2018011416': {'t': '10℃',
#   'hum': '52%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011416},
#  '2018011417': {'t': '8℃',
#   'hum': '65%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011417},
#  '2018011418': {'t': '5℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011418},
#  '2018011419': {'t': '4℃',
#   'hum': '88%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011419},
#  '2018011420': {'t': '3℃',
#   'hum': '94%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011420},
#  '2018011421': {'t': '3℃',
#   'hum': '94%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011421},
#  '2018011422': {'t': '2℃',
#   'hum': '96%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011422},
#  '2018011423': {'t': '2℃',
#   'hum': '96%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 3,
#   'week': 7,
#   'date': 2018011423},
#  '2018011505': {'t': '0℃',
#   'hum': '97%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011505},
#  '2018011506': {'t': '0℃',
#   'hum': '97%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011506},
#  '2018011507': {'t': '1℃',
#   'hum': '98%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011507},
#  '2018011508': {'t': '6℃',
#   'hum': '98%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011508},
#  '2018011509': {'t': '10℃',
#   'hum': '68%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011509},
#  '2018011510': {'t': '13℃',
#   'hum': '47%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011510},
#  '2018011511': {'t': '15℃',
#   'hum': '38%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011511},
#  '2018011512': {'t': '15℃',
#   'hum': '37%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011512},
#  '2018011513': {'t': '16℃',
#   'hum': '36%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011513},
#  '2018011514': {'t': '16℃',
#   'hum': '43%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011514},
#  '2018011515': {'t': '15℃',
#   'hum': '52%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011515},
#  '2018011516': {'t': '14℃',
#   'hum': '68%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011516},
#  '2018011517': {'t': '12℃',
#   'hum': '75%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011517},
#  '2018011518': {'t': '11℃',
#   'hum': '86%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011518},
#  '2018011519': {'t': '10℃',
#   'hum': '91%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011519},
#  '2018011520': {'t': '9℃',
#   'hum': '94%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011520},
#  '2018011521': {'t': '9℃',
#   'hum': '94%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011521},
#  '2018011522': {'t': '9℃',
#   'hum': '96%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011522},
#  '2018011523': {'t': '9℃',
#   'hum': '96%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 1,
#   'date': 2018011523},
#  '2018011605': {'t': '11℃',
#   'hum': '98%',
#   'weather': '雾',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011605},
#  '2018011606': {'t': '11℃',
#   'hum': '98%',
#   'weather': '雾',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011606},
#  '2018011607': {'t': '11℃',
#   'hum': '98%',
#   'weather': '雾',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011607},
#  '2018011608': {'t': '11℃',
#   'hum': '98%',
#   'weather': '雾',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011608},
#  '2018011609': {'t': '12℃',
#   'hum': '98%',
#   'weather': '雾',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011609},
#  '2018011610': {'t': '12℃',
#   'hum': '98%',
#   'weather': '雾',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011610},
#  '2018011611': {'t': '13℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011611},
#  '2018011612': {'t': '14℃',
#   'hum': '69%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011612},
#  '2018011613': {'t': '14℃',
#   'hum': '66%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011613},
#  '2018011614': {'t': '13℃',
#   'hum': '73%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011614},
#  '2018011615': {'t': '13℃',
#   'hum': '71%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011615},
#  '2018011616': {'t': '13℃',
#   'hum': '66%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011616},
#  '2018011617': {'t': '12℃',
#   'hum': '75%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011617},
#  '2018011618': {'t': '12℃',
#   'hum': '78%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011618},
#  '2018011619': {'t': '11℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011619},
#  '2018011620': {'t': '10℃',
#   'hum': '85%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011620},
#  '2018011621': {'t': '10℃',
#   'hum': '85%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011621},
#  '2018011622': {'t': '10℃',
#   'hum': '86%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011622},
#  '2018011623': {'t': '10℃',
#   'hum': '86%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 2,
#   'date': 2018011623},
#  '2018011705': {'t': '8℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011705},
#  '2018011706': {'t': '8℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011706},
#  '2018011707': {'t': '8℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011707},
#  '2018011708': {'t': '8℃',
#   'hum': '77%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011708},
#  '2018011709': {'t': '9℃',
#   'hum': '74%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011709},
#  '2018011710': {'t': '11℃',
#   'hum': '65%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011710},
#  '2018011711': {'t': '11℃',
#   'hum': '63%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011711},
#  '2018011712': {'t': '12℃',
#   'hum': '58%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011712},
#  '2018011713': {'t': '12℃',
#   'hum': '56%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011713},
#  '2018011714': {'t': '12℃',
#   'hum': '57%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011714},
#  '2018011715': {'t': '12℃',
#   'hum': '59%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011715},
#  '2018011716': {'t': '11℃',
#   'hum': '62%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011716},
#  '2018011717': {'t': '10℃',
#   'hum': '68%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011717},
#  '2018011718': {'t': '9℃',
#   'hum': '72%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011718},
#  '2018011719': {'t': '8℃',
#   'hum': '83%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011719},
#  '2018011720': {'t': '7℃',
#   'hum': '84%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011720},
#  '2018011721': {'t': '7℃',
#   'hum': '84%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011721},
#  '2018011722': {'t': '7℃',
#   'hum': '83%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011722},
#  '2018011723': {'t': '7℃',
#   'hum': '83%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 3,
#   'date': 2018011723},
#  '2018011805': {'t': '7℃',
#   'hum': '86%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011805},
#  '2018011806': {'t': '7℃',
#   'hum': '86%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011806},
#  '2018011807': {'t': '7℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011807},
#  '2018011808': {'t': '8℃',
#   'hum': '72%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011808},
#  '2018011809': {'t': '8℃',
#   'hum': '71%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011809},
#  '2018011810': {'t': '9℃',
#   'hum': '67%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011810},
#  '2018011811': {'t': '10℃',
#   'hum': '61%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011811},
#  '2018011812': {'t': '10℃',
#   'hum': '59%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011812},
#  '2018011813': {'t': '10℃',
#   'hum': '64%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011813},
#  '2018011814': {'t': '9℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011814},
#  '2018011815': {'t': '9℃',
#   'hum': '72%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011815},
#  '2018011816': {'t': '8℃',
#   'hum': '72%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011816},
#  '2018011817': {'t': '8℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011817},
#  '2018011818': {'t': '8℃',
#   'hum': '68%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011818},
#  '2018011819': {'t': '8℃',
#   'hum': '69%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011819},
#  '2018011820': {'t': '8℃',
#   'hum': '70%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011820},
#  '2018011821': {'t': '8℃',
#   'hum': '70%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011821},
#  '2018011822': {'t': '8℃',
#   'hum': '68%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011822},
#  '2018011823': {'t': '8℃',
#   'hum': '68%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018011823},
#  '2018011905': {'t': '8℃',
#   'hum': '76%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011905},
#  '2018011906': {'t': '8℃',
#   'hum': '76%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011906},
#  '2018011907': {'t': '8℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011907},
#  '2018011908': {'t': '7℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011908},
#  '2018011909': {'t': '8℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011909},
#  '2018011910': {'t': '8℃',
#   'hum': '73%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011910},
#  '2018011911': {'t': '9℃',
#   'hum': '74%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011911},
#  '2018011912': {'t': '8℃',
#   'hum': '83%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011912},
#  '2018011913': {'t': '8℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011913},
#  '2018011914': {'t': '8℃',
#   'hum': '81%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011914},
#  '2018011915': {'t': '8℃',
#   'hum': '81%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011915},
#  '2018011916': {'t': '8℃',
#   'hum': '81%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011916},
#  '2018011917': {'t': '8℃',
#   'hum': '81%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011917},
#  '2018011918': {'t': '8℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011918},
#  '2018011919': {'t': '8℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011919},
#  '2018011920': {'t': '8℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011920},
#  '2018011921': {'t': '8℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011921},
#  '2018011922': {'t': '8℃',
#   'hum': '79%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011922},
#  '2018011923': {'t': '8℃',
#   'hum': '79%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 5,
#   'date': 2018011923},
#  '2018012005': {'t': '7℃',
#   'hum': '75%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012005},
#  '2018012006': {'t': '7℃',
#   'hum': '75%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012006},
#  '2018012007': {'t': '7℃',
#   'hum': '71%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012007},
#  '2018012008': {'t': '7℃',
#   'hum': '67%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012008},
#  '2018012009': {'t': '7℃',
#   'hum': '71%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012009},
#  '2018012010': {'t': '7℃',
#   'hum': '74%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012010},
#  '2018012011': {'t': '7℃',
#   'hum': '80%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012011},
#  '2018012012': {'t': '6℃',
#   'hum': '84%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012012},
#  '2018012013': {'t': '6℃',
#   'hum': '85%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 3,
#   'week': 6,
#   'date': 2018012013},
#  '2018012014': {'t': '6℃',
# ...
#   'wind': '2级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021607},
#  '2018021608': {'t': '4℃',
#   'hum': '92%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021608},
#  '2018021609': {'t': '4℃',
#   'hum': '90%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021609},
#  '2018021610': {'t': '4℃',
#   'hum': '88%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021610},
#  '2018021611': {'t': '4℃',
#   'hum': '87%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021611},
#  '2018021612': {'t': '5℃',
#   'hum': '87%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021612},
#  '2018021613': {'t': '6℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021613},
#  '2018021614': {'t': '5℃',
#   'hum': '83%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021614},
#  '2018021615': {'t': '5℃',
#   'hum': '79%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021615},
#  '2018021616': {'t': '6℃',
#   'hum': '78%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021616},
#  '2018021617': {'t': '5℃',
#   'hum': '81%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021617},
#  '2018021618': {'t': '5℃',
#   'hum': '83%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021618},
#  '2018021619': {'t': '5℃',
#   'hum': '83%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021619},
#  '2018021620': {'t': '5℃',
#   'hum': '77%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021620},
#  '2018021621': {'t': '5℃',
#   'hum': '77%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021621},
#  '2018021622': {'t': '4℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021622},
#  '2018021623': {'t': '4℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 5,
#   'date': 2018021623},
#  '2018021705': {'t': '0℃',
#   'hum': '97%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021705},
#  '2018021706': {'t': '0℃',
#   'hum': '97%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021706},
#  '2018021707': {'t': '1℃',
#   'hum': '97%',
#   'weather': '晴',
#   'wind': '0级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021707},
#  '2018021708': {'t': '5℃',
#   'hum': '77%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021708},
#  '2018021709': {'t': '6℃',
#   'hum': '62%',
#   'weather': '晴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021709},
#  '2018021710': {'t': '8℃',
#   'hum': '61%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021710},
#  '2018021711': {'t': '9℃',
#   'hum': '59%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021711},
#  '2018021712': {'t': '10℃',
#   'hum': '50%',
#   'weather': '晴',
#   'wind': '3级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021712},
#  '2018021713': {'t': '10℃',
#   'hum': '52%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021713},
#  '2018021714': {'t': '10℃',
#   'hum': '51%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021714},
#  '2018021715': {'t': '10℃',
#   'hum': '51%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021715},
#  '2018021716': {'t': '8℃',
#   'hum': '55%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021716},
#  '2018021717': {'t': '7℃',
#   'hum': '65%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021717},
#  '2018021718': {'t': '6℃',
#   'hum': '70%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021718},
#  '2018021719': {'t': '5℃',
#   'hum': '74%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021719},
#  '2018021720': {'t': '5℃',
#   'hum': '74%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021720},
#  '2018021721': {'t': '5℃',
#   'hum': '74%',
#   'weather': '晴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021721},
#  '2018021722': {'t': '5℃',
#   'hum': '80%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021722},
#  '2018021723': {'t': '5℃',
#   'hum': '80%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 6,
#   'date': 2018021723},
#  '2018021805': {'t': '7℃',
#   'hum': '78%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021805},
#  '2018021806': {'t': '7℃',
#   'hum': '78%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021806},
#  '2018021807': {'t': '7℃',
#   'hum': '83%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021807},
#  '2018021808': {'t': '8℃',
#   'hum': '78%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021808},
#  '2018021809': {'t': '8℃',
#   'hum': '79%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021809},
#  '2018021810': {'t': '10℃',
#   'hum': '73%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021810},
#  '2018021811': {'t': '10℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021811},
#  '2018021812': {'t': '11℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021812},
#  '2018021813': {'t': '10℃',
#   'hum': '75%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021813},
#  '2018021814': {'t': '10℃',
#   'hum': '77%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021814},
#  '2018021815': {'t': '9℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021815},
#  '2018021816': {'t': '8℃',
#   'hum': '88%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021816},
#  '2018021817': {'t': '8℃',
#   'hum': '88%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021817},
#  '2018021818': {'t': '7℃',
#   'hum': '92%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021818},
#  '2018021819': {'t': '7℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021819},
#  '2018021820': {'t': '7℃',
#   'hum': '95%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021820},
#  '2018021821': {'t': '7℃',
#   'hum': '95%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021821},
#  '2018021822': {'t': '7℃',
#   'hum': '96%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021822},
#  '2018021823': {'t': '7℃',
#   'hum': '96%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 7,
#   'date': 2018021823},
#  '2018021905': {'t': '6℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021905},
#  '2018021906': {'t': '6℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021906},
#  '2018021907': {'t': '7℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021907},
#  '2018021908': {'t': '7℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021908},
#  '2018021909': {'t': '7℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021909},
#  '2018021910': {'t': '7℃',
#   'hum': '97%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021910},
#  '2018021911': {'t': '8℃',
#   'hum': '97%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021911},
#  '2018021912': {'t': '8℃',
#   'hum': '96%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021912},
#  '2018021913': {'t': '7℃',
#   'hum': '96%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021913},
#  '2018021914': {'t': '7℃',
#   'hum': '95%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021914},
#  '2018021915': {'t': '7℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021915},
#  '2018021916': {'t': '6℃',
#   'hum': '94%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021916},
#  '2018021917': {'t': '5℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021917},
#  '2018021918': {'t': '5℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021918},
#  '2018021919': {'t': '5℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021919},
#  '2018021920': {'t': '6℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021920},
#  '2018021921': {'t': '6℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021921},
#  '2018021922': {'t': '6℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021922},
#  '2018021923': {'t': '6℃',
#   'hum': '82%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 1,
#   'date': 2018021923},
#  '2018022005': {'t': '6℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022005},
#  '2018022006': {'t': '6℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022006},
#  '2018022007': {'t': '6℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022007},
#  '2018022008': {'t': '6℃',
#   'hum': '76%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022008},
#  '2018022009': {'t': '8℃',
#   'hum': '69%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022009},
#  '2018022010': {'t': '8℃',
#   'hum': '69%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022010},
#  '2018022011': {'t': '8℃',
#   'hum': '75%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022011},
#  '2018022012': {'t': '8℃',
#   'hum': '74%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022012},
#  '2018022013': {'t': '8℃',
#   'hum': '79%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022013},
#  '2018022014': {'t': '7℃',
#   'hum': '88%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022014},
#  '2018022015': {'t': '7℃',
#   'hum': '91%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022015},
#  '2018022016': {'t': '6℃',
#   'hum': '85%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022016},
#  '2018022017': {'t': '5℃',
#   'hum': '91%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022017},
#  '2018022018': {'t': '4℃',
#   'hum': '90%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022018},
#  '2018022019': {'t': '4℃',
#   'hum': '91%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022019},
#  '2018022020': {'t': '4℃',
#   'hum': '92%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022020},
#  '2018022021': {'t': '4℃',
#   'hum': '92%',
#   'weather': '阵雨',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022021},
#  '2018022022': {'t': '4℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022022},
#  '2018022023': {'t': '4℃',
#   'hum': '93%',
#   'weather': '阵雨',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 2,
#   'date': 2018022023},
#  '2018022105': {'t': '4℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022105},
#  '2018022106': {'t': '4℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022106},
#  '2018022107': {'t': '5℃',
#   'hum': '91%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022107},
#  '2018022108': {'t': '6℃',
#   'hum': '86%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022108},
#  '2018022109': {'t': '6℃',
#   'hum': '81%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022109},
#  '2018022110': {'t': '7℃',
#   'hum': '73%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022110},
#  '2018022111': {'t': '8℃',
#   'hum': '68%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022111},
#  '2018022112': {'t': '8℃',
#   'hum': '70%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022112},
#  '2018022113': {'t': '8℃',
#   'hum': '67%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022113},
#  '2018022114': {'t': '7℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022114},
#  '2018022115': {'t': '7℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022115},
#  '2018022116': {'t': '6℃',
#   'hum': '73%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022116},
#  '2018022117': {'t': '6℃',
#   'hum': '76%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022117},
#  '2018022118': {'t': '5℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '0级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022118},
#  '2018022119': {'t': '5℃',
#   'hum': '84%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022119},
#  '2018022120': {'t': '5℃',
#   'hum': '83%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022120},
#  '2018022121': {'t': '5℃',
#   'hum': '83%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022121},
#  '2018022122': {'t': '5℃',
#   'hum': '82%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022122},
#  '2018022123': {'t': '5℃',
#   'hum': '82%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 1,
#   'week': 3,
#   'date': 2018022123},
#  '2018022205': {'t': '4℃',
#   'hum': '89%',
#   'weather': '阴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022205},
#  '2018022206': {'t': '4℃',
#   'hum': '89%',
#   'weather': '阴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022206},
#  '2018022207': {'t': '5℃',
#   'hum': '85%',
#   'weather': '阴',
#   'wind': '0级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022207},
#  '2018022208': {'t': '6℃',
#   'hum': '72%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022208},
#  '2018022209': {'t': '8℃',
#   'hum': '64%',
#   'weather': '阴',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022209},
#  '2018022210': {'t': '8℃',
#   'hum': '62%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022210},
#  '2018022211': {'t': '8℃',
#   'hum': '59%',
#   'weather': '阴',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022211},
#  '2018022212': {'t': '8℃',
#   'hum': '65%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022212},
#  '2018022213': {'t': '9℃',
#   'hum': '57%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022213},
#  '2018022214': {'t': '9℃',
#   'hum': '53%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022214},
#  '2018022215': {'t': '9℃',
#   'hum': '55%',
#   'weather': '多云',
#   'wind': '1级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022215},
#  '2018022216': {'t': '9℃',
#   'hum': '56%',
#   'weather': '多云',
#   'wind': '2级',
#   'holiday': 0,
#   'week': 4,
#   'date': 2018022216},
#  ...}

# %%
# 看是否存在缺失值
csv_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 7 columns):
# ID                  65538 non-null int64
# W_C_AREA_CODE       65538 non-null object
# TJ_TIME             65538 non-null object
# IN_TOTAL            65538 non-null int64
# OUT_TOTAL           65538 non-null int64
# REMARK              65538 non-null int64
# W_M_WAYKIND_NAME    65538 non-null object
# dtypes: int64(4), object(3)
# memory usage: 3.5+ MB

# %%
# 将数据整理成date -> data 的字典
# dataFrame: read data 2018/01/01-2018/04/25
csv_batch_data = csv_data
# values dataFrame->array  Transfer array data to dictionary:
print('csv_data shape:', csv_batch_data.shape)
# train_batch_data = csv_batch_data[list(range(3, 6))]  取3:5列
# dataFrame 取行
train_batch_data = csv_batch_data[1:]
#  按照机器类型，将数据分为两组
# 314684 row 之后只有machine1 数据
machine1_data = []
machine2_data = []
# data 为list： ID 0 , W_C_AREA_CODE 1, Time 2, In_total 3, Out_total 4.  DataFrame.values -> array
for data in train_batch_data.values:  
    if data[1] == '05-19-10':
        # list of array -> [ID 0 , W_C_AREA_CODE 1, Time 2, In_total 3, Out_total 4]
        machine1_data.append(data)
    elif data[1] == '04-17-03':
        machine2_data.append(data)
    else:
        print("machine type error!")
# Passenger flow =  In_total + Out_total
print('machine1_data shape:', len(machine1_data))
print('machine2_data shape:', len(machine2_data))
# Out:
# csv_data shape: (65538, 7)
# machine1_data shape: 32599
# machine2_data shape: 32938

# %% [markdown]
# ### 5.2.2 提取闸机数据，转换为小时的客流量数据

# %%
"""
统计小时划分的客流量数据 > data_set1({datehour:[date,weather,week,holiday,high_tmp,low_tmp,wind]}) and target_set1:{datehour:flow} 
"""
import pdb
# [Time 2, In_total 3, Out_total 4] -> machine_data: [Date 0, hour 1, In_total 3, Out_total 4] 
# data_set and target_set 按照日期-时段为key进行划分
# 小时统计算法：记录第一个点record = record(h0), 遍历，if date-hour not changed, update flow, else: dict[date-h_pre] = flow - record, update record = flow.
data_set1 = {}
data_set2= {}
target_set1 = {}
target_set2 = {}

# print(machine1_data) : [Date 0, hour 1, In_total 3, Out_total 4]

# %%
def get_hour_data(machine1_data, data_set1, target_set1):
    record = 0
    flow = 0
    flag_start = True
    date_start = True
    pre_date = 0
    for i in range(len(machine1_data)):
        machine1_data[i][0], machine1_data[i][1] = transfer_time(machine1_data[i][2])
        in_total = machine1_data[i][3]
        out_total = machine1_data[i][4]
        date = machine1_data[i][0]
        hour = machine1_data[i][1]
        if int(hour)>=0 and int(hour)<=4:
            continue
        if flag_start:
            key_start = date + hour
            flag_start = False
        if date_start:
            pre_date = date
            date_start = False
        key = date + hour
        # In the same hour: update flow
        if key == key_start:
            flow = (in_total + out_total)
        else:
        # change to next hour:
            # change to next day: record --> 0
            if date != pre_date:
                pre_date = date
                target_set1[key_start] = flow - record
                data_set1[key_start] = json_data[key_start]   # key_start: pre key
                record = 0
            else:
                target_set1[key_start] = flow - record
                data_set1[key_start] = json_data[key_start]
                record = flow
            key_start = key

# %%
get_hour_data(machine1_data, data_set1, target_set1)
get_hour_data(machine2_data, data_set2, target_set2)
print(len(target_set1),len(target_set2))
# Out:
# 2184 2184

# %%
# Traversal data_set1 and Add Passenger-flow in target_set1 and target_set2 with same date-hour
# Use data_set1 and target_set as Input and Output raw data
target_set = {}
for key in target_set1:
    if key in target_set2:
        target_set[key] = target_set1[key] + target_set2[key]
print(len(target_set))
# Out:
# 2184

# %%
def plot_week(target_set):
    fig= plt.figure(figsize=(12,5))
    y = []
    x_data = list(target_set.keys())
    x = x_data[19:153]
    for key in x:
        y.append(target_set[key])
    y = np.array(y)
    x_data = np.linspace(0, 135, len(y))
    #x_data = np.array(x_data)
    plt.plot(x_data,y,'b-',lw=1)

# %%
# 输出一天Passenger Flow / h 实际值   --> machine 1
plot_week(target_set1)
plot_week(target_set2)
plot_week(target_set)

# %%
"""
Plot hour_flow figure:
"""
# 输出一天Passenger Flow / h 实际值  --> machine 2
fig= plt.figure(figsize=(12,5))
y = []
x_data = list(target_set.keys())
x = x_data[0:600]
for key in x:
    y.append(target_set[key])
y = np.array(y)
x_data = np.linspace(0, 500, len(y))
#x_data = np.array(x_data)
plt.plot(x_data,y,'g-',lw=1)

# %%
"""
Plot dict_holiday figure: 节假日情况分布 
"week day 0, holiday in law 1, make up for working 2，weekend 3 "
"""
# 输出一天Passenger Flow / h 实际值  --> machine 2
holiday = []
for value in json_data.values():
    holiday.append(value['holiday'])
fig= plt.figure(figsize=(12,5))
y = []
y = holiday
y = np.array(y)
x_data = np.linspace(0, 115, len(y))
#x_data = np.array(x_data)
plt.scatter(x_data,y)

# %%
# 两个machine的数据不对称，先放弃machine2， 对machine1的数据进行分析

# %% [markdown]
# 标准化： $X_t = \frac {X - mean} {std}$
# 计算客流量累加值为/1 hour 的时段值

# %% [markdown]
# ### 5.3 搭建神经网络预测模型

# %% [markdown]
# #### 5.3.1 网络输入数据标准化

# %%
# data_set{datehour: {t:{int}, hum:{int}, weather:{label_encoder}, wind:{int}, holiday:{int}, week:{int}, date:{int}}}
# target_set{datehour: flow}
# dict_values -> obj -> list -> array
# >> data, target
x = []
dict_x = []
for value in data_set1.values():
    dict_x.append(value)
for value in dict_x:
    x.append(np.array(list(value.values())))   
for value in x:
    x[0] = # wind
y = list(target_set.values())
# pdb.set_trace()
data = np.array(x)
target = np.array(y)
# pdb.set_trace()
mean = data.mean(axis=0)
# pdb.set_trace()
std = data.std(axis = 0)
# 数组中的每一个element都会减mean
data = (data - mean) / std
# target_set = (target_set - mean_y) / std_y
# Out:
# --Return--
# > <ipython-input-95-75ba65dd7168>(11)<module>()->None
# -> pdb.set_trace()
# (Pdb) x
# [array(['2℃', '91%', '晴', '1级', '1', '1', '2018010105'], dtype='<U10'), array(['2℃', '91%', '晴', '1级', '1', '1', '2018010106'], dtype='<U10'), array(['2℃', '94%', '晴', '0级', '1', '1', '2018010107'], dtype='<U10'), array(['5℃', '76%', '晴', '1级', '1', '1', '2018010108'], dtype='<U10'), array(['7℃', '56%', '晴', '2级', '1', '1', '2018010109'], dtype='<U10'), array(['9℃', '36%', '晴', '2级', '1', '1', '2018010110'], dtype='<U10'), array(['10℃', '34%', '晴', '1级', '1', '1', '2018010111'], dtype='<U10'), array(['10℃', '24%', '晴', '1级', '1', '1', '2018010112'], dtype='<U10'), array(['11℃', '29%', '晴', '1级', '1', '1', '2018010113'], dtype='<U10'), array(['11℃', '27%', '晴', '2级', '1', '1', '2018010114'], dtype='<U10'), array(['11℃', '30%', '晴', '2级', '1', '1', '2018010115'], dtype='<U10'), array(['9℃', '41%', '晴', '2级', '1', '1', '2018010116'], dtype='<U10'), array(['7℃', '54%', '晴', '1级', '1', '1', '2018010117'], dtype='<U10'), array(['6℃', '66%', '晴', '1级', '1', '1', '2018010118'], dtype='<U10'), array(['5℃', '72%', '晴', '1级', '1', '1', '2018010119'], dtype='<U10'), array(['6℃', '70%', '晴', '1级', '1', '1', '2018010120'], dtype='<U10'), array(['6℃', '70%', '晴', '1级', '1', '1', '2018010121'], dtype='<U10'), array(['7℃', '70%', '多云', '2级', '1', '1', '2018010122'], dtype='<U10'), array(['7℃', '70%', '多云', '2级', '1', '1', '2018010123'], dtype='<U10'), array(['10℃', '69%', '多云', '2级', '0', '2', '2018010205'], dtype='<U10'), array(['10℃', '69%', '多云', '2级', '0', '2', '2018010206'], dtype='<U10'), array(['10℃', '69%', '多云', '2级', '0', '2', '2018010207'], dtype='<U10'), array(['10℃', '71%', '多云', '2级', '0', '2', '2018010208'], dtype='<U10'), array(['11℃', '67%', '多云', '2级', '0', '2', '2018010209'], dtype='<U10'), array(['12℃', '61%', '多云', '2级', '0', '2', '2018010210'], dtype='<U10'), array(['13℃', '61%', '多云', '2级', '0', '2', '2018010211'], dtype='<U10'), array(['13℃', '62%', '多云', '2级', '0', '2', '2018010212'], dtype='<U10'), array(['12℃', '64%', '多云', '2级', '0', '2', '2018010213'], dtype='<U10'), array(['12℃', '67%', '阴', '1级', '0', '2', '2018010214'], dtype='<U10'), array(['12℃', '71%', '阴', '1级', '0', '2', '2018010215'], dtype='<U10'), array(['12℃', '74%', '阴', '2级', '0', '2', '2018010216'], dtype='<U10'), array(['12℃', '75%', '阴', '1级', '0', '2', '2018010217'], dtype='<U10'), array(['11℃', '77%', '阴', '1级', '0', '2', '2018010218'], dtype='<U10'), array(['11℃', '77%', '阴', '2级', '0', '2', '2018010219'], dtype='<U10'), array(['11℃', '89%', '阴', '2级', '0', '2', '2018010220'], dtype='<U10'), array(['11℃', '89%', '阴', '2级', '0', '2', '2018010221'], dtype='<U10'), array(['10℃', '95%', '阵雨', '2级', '0', '2', '2018010222'], dtype='<U10'), array(['10℃', '95%', '阵雨', '2级', '0', '2', '2018010223'], dtype='<U10'), array(['7℃', '92%', '阴', '2级', '0', '3', '2018010305'], dtype='<U10'), array(['7℃', '92%', '阴', '2级', '0', '3', '2018010306'], dtype='<U10'), array(['8℃', '91%', '阴', '2级', '0', '3', '2018010307'], dtype='<U10'), array(['8℃', '89%', '阴', '1级', '0', '3', '2018010308'], dtype='<U10'), array(['8℃', '94%', '阵雨', '2级', '0', '3', '2018010309'], dtype='<U10'), array(['8℃', '92%', '阵雨', '2级', '0', '3', '2018010310'], dtype='<U10'), array(['8℃', '88%', '阵雨', '3级', '0', '3', '2018010311'], dtype='<U10'), array(['8℃', '80%', '阴', '2级', '0', '3', '2018010312'], dtype='<U10'), array(['8℃', '81%', '阴', '2级', '0', '3', '2018010313'], dtype='<U10'), array(['7℃', '81%', '阵雨', '2级', '0', '3', '2018010314'], dtype='<U10'), array(['7℃', '77%', '阵雨', '2级', '0', '3', '2018010315'], dtype='<U10'), array(['7℃', '78%', '阴', '2级', '0', '3', '2018010316'], dtype='<U10'), array(['6℃', '81%', '阴', '2级', '0', '3', '2018010317'], dtype='<U10'), array(['5℃', '89%', '阵雨', '2级', '0', '3', '2018010318'], dtype='<U10'), array(['5℃', '90%', '阵雨', '2级', '0', '3', '2018010319'], dtype='<U10'), array(['5℃', '88%', '阵雨', '2级', '0', '3', '2018010320'], dtype='<U10'), array(['5℃', '88%', '阵雨', '2级', '0', '3', '2018010321'], dtype='<U10'), array(['4℃', '91%', '阴', '1级', '0', '3', '201801 ...
# (Pdb) quit
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-95-75ba65dd7168> in <module>
#       9 for value in dict_x:
#      10     x.append(np.array(list(value.values())))
# ---> 11 pdb.set_trace()
#      12 y = list(target_set.values())
#      13 # pdb.set_trace()
#
# /opt/anaconda3/envs/jp_kernel/lib/python3.7/bdb.py in trace_dispatch(self, frame, event, arg)
#      90             return self.dispatch_call(frame, arg)
#      91         if event == 'return':
# ---> 92             return self.dispatch_return(frame, arg)
#      93         if event == 'exception':
#      94             return self.dispatch_exception(frame, arg)
#
# /opt/anaconda3/envs/jp_kernel/lib/python3.7/bdb.py in dispatch_return(self, frame, arg)
#     152             finally:
#     153                 self.frame_returning = None
# --> 154             if self.quitting: raise BdbQuit
#     155             # The user issued a 'next' or 'until' command.
#     156             if self.stopframe is frame and self.stoplineno != -1:
#
# BdbQuit:

# %%
print(len(target))
# Out:
# 12619

# %%
# 两个machine的数据不对称，先放弃machine2， 对machine1的数据进行分析
print(data.shape)
print(target.shape)
print(len(target_set1))
print(len(target_set2))
# Out:
# (12619, 7)
# (12619,)
# 12619
# 12757

# %% [markdown]
# ### Target variable
# Some analysis on target variable

# %%
plt.subplots(figsize=(12,9))
sns.distplot(target, fit=stats.norm)

# Get the fitted parameters used by the function

(mu, sigma) = stats.norm.fit(target)

# plot with the distribution

plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
plt.ylabel('Frequency')

#Probablity plot

fig = plt.figure()
stats.probplot(target, plot=plt)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-568c8472ab79> in <module>
#       1 plt.subplots(figsize=(12,9))
# ----> 2 sns.distplot(target, fit=stats.norm)
#       3
#       4 # Get the fitted parameters used by the function
#       5
#
# NameError: name 'target' is not defined

# %%
## Filter out the

# %% [markdown]
# This target varibale is right skewed. Now, we need to tranform this variable and make it normal distribution.
#
# For more information about that [click here](http://whatis.techtarget.com/definition/skewness)

# %% [markdown]
# #### Here we use log for target variable to make more normal distribution

# %%
#we use log function which is in numpy
target = np.log1p(target)

#Check again for more normal distribution

plt.subplots(figsize=(12,9))
sns.distplot(target, fit=stats.norm)

# Get the fitted parameters used by the function

(mu, sigma) = stats.norm.fit(target)

# plot with the distribution

plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
plt.ylabel('Frequency')

#Probablity plot

fig = plt.figure()
stats.probplot(target, plot=plt)
plt.show()

# %% [markdown]
# #### 5.3.2 搭建网络框架

# %%
def build_model():
    model = Sequential()
    # 先将维度放大， 在高维空间中抽取特征  
    # Input: week, hour, date, weather
    model.add(Dense(64, input_shape = (7,),activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1))
    # 输出偏差矩阵 correspond to train_target
    model.compile(optimizer = RMSprop(), loss="mse", metrics=['mae'])
    return model

# %% [raw]
#  交叉检验，将数据分成n个集合 1 个验证， n-1个训练集
#  fold n = 5 / 10
#  求的模型的平均得分
#  防止一次训练产生过拟合
#  评价模型综合的情况
#  构造交叉检验的模型

# %%
num_epochs = 5000
all_scores = []

# %%
train_size = int(len(target_set1) * 0.9)
train_data = data[ : train_size]
#print(train_data)
train_target = target[ : train_size]
test_data = data[train_size : ]
test_target = target[train_size : ]

# %% [markdown]
# #### 5.3.3 训练神经网络

# %%
model = build_model()
# batch_size 训练进入的数据大小为1， verbose = 0 不输出训练数据
model.fit(train_data, train_target, epochs = num_epochs, batch_size = 4000 , verbose = 2)
val_mse, val_mae = model.evaluate(test_data, test_target, verbose = 0)
all_scores.append(val_mae)
print("MSE:", val_mse,"MAE:",val_mae)

# %%
# 输出一个一天/h的训练值与实际值
fig = plt.figure(figsize=(12,5))
y_pred = model.predict(train_data)
x_data = np.linspace(0,len(train_data),len(y_pred))
plt.scatter(x_data,train_target)
plt.plot(x_data,y_pred,'r-',lw=1)

# %% [markdown]
# #### 5.3.4 预测结果

# %%
# 输出一个客流量 / h 的预测值与实际值
fig = plt.figure(figsize=(12, 5))
y_pred = model.predict(test_data)
x_data = np.linspace(0,len(y_pred)/24 ,len(y_pred))
plt.scatter(x_data[0:200],test_target[0:200])
plt.plot(x_data[0:200],y_pred[0:200],'r-',lw=1)

# %% [markdown]
# ## 6. 结论
#
# 通过对上海虹桥地铁进出站的客流量数据分析，发现客流量受到节假日，天气等因素的影响，本模型综合考虑以上影响因素，建立地铁客流量的预测模型。
#
# 情景分析结果表明，本预测算法能够有效的应用于地铁进出站的客流量预测情景。将来通过进一步对模型的改进和优化，能够支持公交、火车等交通方式的客流量预测。
#
# 届时将打造一个完整的大型交通枢纽客流量预测系统。为交通枢纽的运力决策和综合管理优化提供数据支持和政策建议。
